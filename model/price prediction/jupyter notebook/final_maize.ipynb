# %% [markdown]
# Import modul and library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_excel("https://docs.google.com/spreadsheets/d/1-8vsYPr51RebtCjltJuibWgST4e_0Fu7/export?format=xlsx")

# %%
df.head(5)
# Out:
#    Unnamed: 0  Sl no. District Name        Market Name Commodity    Variety  \
# 0           0    4883      Sholapur  Kurdwadi(Modnimb)     Maize  Deshi Red
# 1           1   10993      Mandsaur           Mandsaur     Maize      Other
# 2           2    9566     Alirajpur              Jobat     Maize      Other
# 3           3   12611       Bharuch           Jambusar     Maize      Other
# 4           4    2256      Dhamtari             Boraee     Maize     Medium
#
#   Grade  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0   FAQ                   1490.0                   1638.0
# 1   FAQ                   1143.0                   1410.0
# 2   FAQ                   1100.0                   1250.0
# 3   FAQ                   1650.0                   1850.0
# 4   FAQ                   1500.0                   1500.0
#
#    Modal Price (Rs./Quintal) Price Date
# 0                     1550.0 2021-03-15
# 1                     1275.0 2021-03-15
# 2                     1200.0 2021-03-15
# 3                     1750.0 2021-03-15
# 4                     1500.0 2021-03-15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94472 entries, 0 to 94471
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 94472 non-null  int64
#  1   Sl no.                     94472 non-null  int64
#  2   District Name              94472 non-null  object
#  3   Market Name                94472 non-null  object
#  4   Commodity                  94472 non-null  object
#  5   Variety                    94472 non-null  object
#  6   Grade                      94472 non-null  object
#  7   Min Price (Rs./Quintal)    94472 non-null  int64
#  8   Max Price (Rs./Quintal)    94472 non-null  int64
#  9   Modal Price (Rs./Quintal)  94472 non-null  float64
#  10  Price Date                 94472 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 7.9+ MB

# %% [markdown]
# dari semua varietas, grade, kelompokkan menjadi satu dan hitung rata-ratanya

# %%
grouped_df0 = df.groupby('Price Date')['Modal Price (Rs./Quintal)'].mean()

# %%
grouped_df0
# Out:
# Price Date
# 2021-03-15    1416.689655
# 2021-03-16    1412.607407
# 2021-03-17    1400.908046
# 2021-03-18    1385.739437
# 2021-03-19    1405.914110
#                  ...
# 2024-10-27    2327.269939
# 2024-10-28    2224.602906
# 2024-10-29    2260.205298
# 2024-10-30    2322.557078
# 2024-10-31    2446.771084
# Name: Modal Price (Rs./Quintal), Length: 1327, dtype: float64

# %%
type(grouped_df0)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Download grouped_df untuk digunakan pada saat deployment

# %%
#grouped_df.to_excel('grouped_prices_banana.xlsx', sheet_name='Prices')

# %% [markdown]
# Tinjau grafik harga dari harga komoditas tersebut untuk melihat trend secara kasat mata

# %%
# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(grouped_df0.index, grouped_df0, label='Modal Price', color='blue')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Define the split time
split1 = 8*2*30
split2 = 16*2*30

# Get the train set
time_train = grouped_df0.index[:split1]
x_train = grouped_df0[:split1]

# Get the validation set
time_valid = grouped_df0.index[split1:split2]
x_valid = grouped_df0[split1:split2]

# Get the test set
time_test = grouped_df0.index[split2:]
x_test = grouped_df0[split2:]

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the data and transform it
x_train_scaled = scaler.fit_transform(x_train.values.reshape(-1,1))
x_val_scaled = scaler.transform(x_valid.values.reshape(-1,1))
x_test_scaled = scaler.transform(x_test.values.reshape(-1,1))

# Convert the scaled data back into a DataFrame for easier reading
x_train_scaled_df = pd.DataFrame(x_train_scaled, columns=[x_train.name],index=x_train.index)
x_val_scaled_df = pd.DataFrame(x_val_scaled,  columns=[x_valid.name],index=x_valid.index)
x_test_scaled_df = pd.DataFrame(x_test_scaled,  columns=[x_test.name],index=x_test.index)

# %%
# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(time_valid, x_valid, label='Modal Price', color='blue')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# #Naive Forecast

# %%
series = np.array(grouped_df0)

# %%
series = scaler.transform(series.reshape(-1,1))

# %%
# Generate the naive forecast
split_time = split2
naive_forecast = series[split_time-1 :-1]

# Define time step
time_step = 100

# Print values
print(f'ground truth at time step {time_step}: {x_test_scaled[time_step]}')
print(f'prediction at time step {time_step + 1}: {naive_forecast[time_step +1]}')
# Out:
# ground truth at time step 100: [2.17244887]
# prediction at time step 101: [2.17244887]

# %%
len(x_test_scaled)
# Out:
# 607

# %%
len(naive_forecast)
# Out:
# 367

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
#results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index, naive_forecast, label='Predicted Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index, x_test_scaled, label='True Value', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
print("MSE:", mse(x_test_scaled, naive_forecast).numpy())
print("MAE:", mae(x_test_scaled, naive_forecast).numpy())

naive_mse = mse(x_test_scaled, naive_forecast).numpy()
naive_mae = mae(x_test_scaled, naive_forecast).numpy()
# Out:
# MSE: 0.07927721
# MAE: 0.19326262

# %%
# Parameters
window_size = 30
batch_size = 32

# %%
def windowed_dataset(series, window_size, batch_size):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    #dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size)

    # Optimize the dataset for training
    dataset = dataset.cache().prefetch(1)

    return dataset

# %%
# Generate the dataset windows
x_train_windowed = windowed_dataset(x_train_scaled, window_size, batch_size)
x_val_windowed = windowed_dataset(x_val_scaled, window_size, batch_size)

# %%
# Print properties of a single batch
for windows in x_train_windowed.take(1):
  print(f'data type: {type(windows)}')
  print(f'number of elements in the tuple: {len(windows)}')
  print(f'shape of first element: {windows[0].shape}')
  print(f'shape of second element: {windows[1].shape}')
# Out:
# data type: <class 'tuple'>
# number of elements in the tuple: 2
# shape of first element: (32, 30, 1)
# shape of second element: (32, 1)

# %% [markdown]
# #RNN

# %%
# Build the Model
model_tune = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.SimpleRNN(40, return_sequences=True),
    tf.keras.layers.SimpleRNN(40),
    tf.keras.layers.Dense(1),
])

# Print the model summary
model_tune.summary()
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_20 (SimpleRNN)            │ (None, 30, 40)              │           1,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_21 (SimpleRNN)            │ (None, 40)                  │           3,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 1)                   │              41 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,961 (19.38 KB)
#  Trainable params: 4,961 (19.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model_tune.fit(x_train_windowed, validation_data=x_val_windowed, epochs=200, callbacks=[lr_schedule])
# Out:
# Epoch 1/200
#      13/Unknown 2s 14ms/step - loss: 0.0448
# /usr/lib/python3.10/contextlib.py:153: UserWarning:
#
# Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 1.0000e-08
# Epoch 2/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 1.1220e-08
# Epoch 3/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 1.2589e-08
# Epoch 4/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 1.4125e-08
# Epoch 5/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 1.5849e-08
# Epoch 6/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 1.7783e-08
# Epoch 7/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 1.9953e-08
# Epoch 8/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 2.2387e-08
# Epoch 9/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 2.5119e-08
# Epoch 10/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 2.8184e-08
# Epoch 11/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 3.1623e-08
# Epoch 12/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 3.5481e-08
# Epoch 13/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 3.9811e-08
# Epoch 14/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0477 - val_loss: 0.1495 - learning_rate: 4.4668e-08
# Epoch 15/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0477 - val_loss: 0.1494 - learning_rate: 5.0119e-08
# Epoch 16/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0477 - val_loss: 0.1494 - learning_rate: 5.6234e-08
# Epoch 17/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0477 - val_loss: 0.1494 - learning_rate: 6.3096e-08
# Epoch 18/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0477 - val_loss: 0.1494 - learning_rate: 7.0795e-08
# Epoch 19/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0477 - val_loss: 0.1494 - learning_rate: 7.9433e-08
# Epoch 20/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0477 - val_loss: 0.1494 - learning_rate: 8.9125e-08
# Epoch 21/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0477 - val_loss: 0.1493 - learning_rate: 1.0000e-07
# Epoch 22/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0477 - val_loss: 0.1493 - learning_rate: 1.1220e-07
# Epoch 23/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0477 - val_loss: 0.1493 - learning_rate: 1.2589e-07
# Epoch 24/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0477 - val_loss: 0.1492 - learning_rate: 1.4125e-07
# Epoch 25/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0477 - val_loss: 0.1492 - learning_rate: 1.5849e-07
# Epoch 26/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0477 - val_loss: 0.1492 - learning_rate: 1.7783e-07
# Epoch 27/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0476 - val_loss: 0.1491 - learning_rate: 1.9953e-07
# Epoch 28/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0476 - val_loss: 0.1490 - learning_rate: 2.2387e-07
# Epoch 29/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0476 - val_loss: 0.1490 - learning_rate: 2.5119e-07
# Epoch 30/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0476 - val_loss: 0.1489 - learning_rate: 2.8184e-07
# Epoch 31/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0476 - val_loss: 0.1488 - learning_rate: 3.1623e-07
# Epoch 32/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0476 - val_loss: 0.1487 - learning_rate: 3.5481e-07
# Epoch 33/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0475 - val_loss: 0.1486 - learning_rate: 3.9811e-07
# Epoch 34/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0475 - val_loss: 0.1485 - learning_rate: 4.4668e-07
# Epoch 35/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0475 - val_loss: 0.1484 - learning_rate: 5.0119e-07
# Epoch 36/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0475 - val_loss: 0.1483 - learning_rate: 5.6234e-07
# Epoch 37/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0474 - val_loss: 0.1481 - learning_rate: 6.3096e-07
# Epoch 38/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0474 - val_loss: 0.1479 - learning_rate: 7.0795e-07
# Epoch 39/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0473 - val_loss: 0.1477 - learning_rate: 7.9433e-07
# Epoch 40/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0473 - val_loss: 0.1475 - learning_rate: 8.9125e-07
# Epoch 41/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0472 - val_loss: 0.1473 - learning_rate: 1.0000e-06
# Epoch 42/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0472 - val_loss: 0.1470 - learning_rate: 1.1220e-06
# Epoch 43/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0471 - val_loss: 0.1467 - learning_rate: 1.2589e-06
# Epoch 44/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0470 - val_loss: 0.1463 - learning_rate: 1.4125e-06
# Epoch 45/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0469 - val_loss: 0.1459 - learning_rate: 1.5849e-06
# Epoch 46/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0468 - val_loss: 0.1455 - learning_rate: 1.7783e-06
# Epoch 47/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0467 - val_loss: 0.1450 - learning_rate: 1.9953e-06
# Epoch 48/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0466 - val_loss: 0.1445 - learning_rate: 2.2387e-06
# Epoch 49/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0465 - val_loss: 0.1439 - learning_rate: 2.5119e-06
# Epoch 50/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0463 - val_loss: 0.1432 - learning_rate: 2.8184e-06
# Epoch 51/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0462 - val_loss: 0.1425 - learning_rate: 3.1623e-06
# Epoch 52/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0460 - val_loss: 0.1417 - learning_rate: 3.5481e-06
# Epoch 53/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0458 - val_loss: 0.1408 - learning_rate: 3.9811e-06
# Epoch 54/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0455 - val_loss: 0.1398 - learning_rate: 4.4668e-06
# Epoch 55/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0453 - val_loss: 0.1387 - learning_rate: 5.0119e-06
# Epoch 56/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0450 - val_loss: 0.1375 - learning_rate: 5.6234e-06
# Epoch 57/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0447 - val_loss: 0.1362 - learning_rate: 6.3096e-06
# Epoch 58/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0443 - val_loss: 0.1347 - learning_rate: 7.0795e-06
# Epoch 59/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0440 - val_loss: 0.1331 - learning_rate: 7.9433e-06
# Epoch 60/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0436 - val_loss: 0.1314 - learning_rate: 8.9125e-06
# Epoch 61/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0431 - val_loss: 0.1295 - learning_rate: 1.0000e-05
# Epoch 62/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0426 - val_loss: 0.1274 - learning_rate: 1.1220e-05
# Epoch 63/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0421 - val_loss: 0.1252 - learning_rate: 1.2589e-05
# Epoch 64/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0415 - val_loss: 0.1228 - learning_rate: 1.4125e-05
# Epoch 65/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0409 - val_loss: 0.1203 - learning_rate: 1.5849e-05
# Epoch 66/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0402 - val_loss: 0.1175 - learning_rate: 1.7783e-05
# Epoch 67/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0395 - val_loss: 0.1147 - learning_rate: 1.9953e-05
# Epoch 68/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0388 - val_loss: 0.1116 - learning_rate: 2.2387e-05
# Epoch 69/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0380 - val_loss: 0.1084 - learning_rate: 2.5119e-05
# Epoch 70/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0372 - val_loss: 0.1051 - learning_rate: 2.8184e-05
# Epoch 71/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0364 - val_loss: 0.1016 - learning_rate: 3.1623e-05
# Epoch 72/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0356 - val_loss: 0.0981 - learning_rate: 3.5481e-05
# Epoch 73/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0347 - val_loss: 0.0945 - learning_rate: 3.9811e-05
# Epoch 74/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0339 - val_loss: 0.0909 - learning_rate: 4.4668e-05
# Epoch 75/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0331 - val_loss: 0.0873 - learning_rate: 5.0119e-05
# Epoch 76/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0323 - val_loss: 0.0838 - learning_rate: 5.6234e-05
# Epoch 77/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0315 - val_loss: 0.0804 - learning_rate: 6.3096e-05
# Epoch 78/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0307 - val_loss: 0.0771 - learning_rate: 7.0795e-05
# Epoch 79/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0300 - val_loss: 0.0740 - learning_rate: 7.9433e-05
# Epoch 80/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0292 - val_loss: 0.0712 - learning_rate: 8.9125e-05
# Epoch 81/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0285 - val_loss: 0.0685 - learning_rate: 1.0000e-04
# Epoch 82/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0278 - val_loss: 0.0660 - learning_rate: 1.1220e-04
# Epoch 83/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0271 - val_loss: 0.0638 - learning_rate: 1.2589e-04
# Epoch 84/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0264 - val_loss: 0.0618 - learning_rate: 1.4125e-04
# Epoch 85/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0258 - val_loss: 0.0600 - learning_rate: 1.5849e-04
# Epoch 86/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0251 - val_loss: 0.0584 - learning_rate: 1.7783e-04
# Epoch 87/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0246 - val_loss: 0.0570 - learning_rate: 1.9953e-04
# Epoch 88/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0240 - val_loss: 0.0557 - learning_rate: 2.2387e-04
# Epoch 89/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0235 - val_loss: 0.0546 - learning_rate: 2.5119e-04
# Epoch 90/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0230 - val_loss: 0.0535 - learning_rate: 2.8184e-04
# Epoch 91/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0225 - val_loss: 0.0526 - learning_rate: 3.1623e-04
# Epoch 92/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0220 - val_loss: 0.0518 - learning_rate: 3.5481e-04
# Epoch 93/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0215 - val_loss: 0.0510 - learning_rate: 3.9811e-04
# Epoch 94/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0210 - val_loss: 0.0502 - learning_rate: 4.4668e-04
# Epoch 95/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0205 - val_loss: 0.0494 - learning_rate: 5.0119e-04
# Epoch 96/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0200 - val_loss: 0.0486 - learning_rate: 5.6234e-04
# Epoch 97/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0194 - val_loss: 0.0477 - learning_rate: 6.3096e-04
# Epoch 98/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0189 - val_loss: 0.0468 - learning_rate: 7.0795e-04
# Epoch 99/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0184 - val_loss: 0.0459 - learning_rate: 7.9433e-04
# Epoch 100/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0180 - val_loss: 0.0449 - learning_rate: 8.9125e-04
# Epoch 101/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0175 - val_loss: 0.0439 - learning_rate: 0.0010
# Epoch 102/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0172 - val_loss: 0.0430 - learning_rate: 0.0011
# Epoch 103/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0168 - val_loss: 0.0421 - learning_rate: 0.0013
# Epoch 104/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0165 - val_loss: 0.0413 - learning_rate: 0.0014
# Epoch 105/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0163 - val_loss: 0.0405 - learning_rate: 0.0016
# Epoch 106/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0160 - val_loss: 0.0397 - learning_rate: 0.0018
# Epoch 107/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0158 - val_loss: 0.0390 - learning_rate: 0.0020
# Epoch 108/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0156 - val_loss: 0.0383 - learning_rate: 0.0022
# Epoch 109/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0155 - val_loss: 0.0376 - learning_rate: 0.0025
# Epoch 110/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0159 - val_loss: 0.0371 - learning_rate: 0.0028
# Epoch 111/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0191 - val_loss: 0.0359 - learning_rate: 0.0032
# Epoch 112/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0359 - val_loss: 0.0319 - learning_rate: 0.0035
# Epoch 113/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0941 - val_loss: 0.0513 - learning_rate: 0.0040
# Epoch 114/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3176 - val_loss: 0.1437 - learning_rate: 0.0045
# Epoch 115/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1726 - val_loss: 0.1952 - learning_rate: 0.0050
# Epoch 116/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1661 - val_loss: 0.0606 - learning_rate: 0.0056
# Epoch 117/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2168 - val_loss: 0.0470 - learning_rate: 0.0063
# Epoch 118/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1500 - val_loss: 0.0686 - learning_rate: 0.0071
# Epoch 119/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0607 - val_loss: 0.0515 - learning_rate: 0.0079
# Epoch 120/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1921 - val_loss: 0.2889 - learning_rate: 0.0089
# Epoch 121/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3091 - val_loss: 0.0388 - learning_rate: 0.0100
# Epoch 122/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1654 - val_loss: 0.1343 - learning_rate: 0.0112
# Epoch 123/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1707 - val_loss: 0.0602 - learning_rate: 0.0126
# Epoch 124/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2563 - val_loss: 0.0612 - learning_rate: 0.0141
# Epoch 125/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0553 - val_loss: 0.0996 - learning_rate: 0.0158
# Epoch 126/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0933 - val_loss: 0.6421 - learning_rate: 0.0178
# Epoch 127/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5182 - val_loss: 0.8506 - learning_rate: 0.0200
# Epoch 128/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.6306 - val_loss: 0.3263 - learning_rate: 0.0224
# Epoch 129/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5620 - val_loss: 0.3637 - learning_rate: 0.0251
# Epoch 130/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.8207 - val_loss: 1.1238 - learning_rate: 0.0282
# Epoch 131/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.5364 - val_loss: 0.7044 - learning_rate: 0.0316
# Epoch 132/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.7969 - val_loss: 0.3702 - learning_rate: 0.0355
# Epoch 133/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 2.4595 - val_loss: 0.9200 - learning_rate: 0.0398
# Epoch 134/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.8331 - val_loss: 1.7158 - learning_rate: 0.0447
# Epoch 135/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.1356 - val_loss: 2.0110 - learning_rate: 0.0501
# Epoch 136/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2895 - val_loss: 0.7832 - learning_rate: 0.0562
# Epoch 137/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.0145 - val_loss: 2.7839 - learning_rate: 0.0631
# Epoch 138/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1113 - val_loss: 3.0014 - learning_rate: 0.0708
# Epoch 139/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.4946 - val_loss: 4.2753 - learning_rate: 0.0794
# Epoch 140/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.8720 - val_loss: 6.5598 - learning_rate: 0.0891
# Epoch 141/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.3176 - val_loss: 7.0972 - learning_rate: 0.1000
# Epoch 142/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 9.9645 - val_loss: 13.1702 - learning_rate: 0.1122
# Epoch 143/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.9337 - val_loss: 0.7879 - learning_rate: 0.1259
# Epoch 144/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 10.6509 - val_loss: 5.5475 - learning_rate: 0.1413
# Epoch 145/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 14.8851 - val_loss: 18.5052 - learning_rate: 0.1585
# Epoch 146/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.9387 - val_loss: 7.7859 - learning_rate: 0.1778
# Epoch 147/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.4761 - val_loss: 13.7326 - learning_rate: 0.1995
# Epoch 148/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.4243 - val_loss: 9.4663 - learning_rate: 0.2239
# Epoch 149/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 25.6491 - val_loss: 31.5837 - learning_rate: 0.2512
# Epoch 150/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 18.9370 - val_loss: 6.0564 - learning_rate: 0.2818
# Epoch 151/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 21.2043 - val_loss: 24.8288 - learning_rate: 0.3162
# Epoch 152/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 25.6888 - val_loss: 12.1017 - learning_rate: 0.3548
# Epoch 153/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 22.1590 - val_loss: 30.9135 - learning_rate: 0.3981
# Epoch 154/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 16.0269 - val_loss: 17.6454 - learning_rate: 0.4467
# Epoch 155/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 39.1550 - val_loss: 38.2574 - learning_rate: 0.5012
# Epoch 156/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 53.4501 - val_loss: 69.1868 - learning_rate: 0.5623
# Epoch 157/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.5277 - val_loss: 66.2443 - learning_rate: 0.6310
# Epoch 158/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 71.9634 - val_loss: 101.4543 - learning_rate: 0.7079
# Epoch 159/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 63.3405 - val_loss: 117.2798 - learning_rate: 0.7943
# Epoch 160/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 39.3094 - val_loss: 88.8186 - learning_rate: 0.8913
# Epoch 161/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 103.0527 - val_loss: 5.7947 - learning_rate: 1.0000
# Epoch 162/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 83.4632 - val_loss: 22.4866 - learning_rate: 1.1220
# Epoch 163/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 54.5097 - val_loss: 163.8350 - learning_rate: 1.2589
# Epoch 164/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 104.5926 - val_loss: 34.9747 - learning_rate: 1.4125
# Epoch 165/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 66.9893 - val_loss: 164.2263 - learning_rate: 1.5849
# Epoch 166/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 124.6367 - val_loss: 40.5801 - learning_rate: 1.7783
# Epoch 167/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 69.3243 - val_loss: 299.9157 - learning_rate: 1.9953
# Epoch 168/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 154.4908 - val_loss: 93.5096 - learning_rate: 2.2387
# Epoch 169/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 227.8339 - val_loss: 40.5706 - learning_rate: 2.5119
# Epoch 170/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 55.3872 - val_loss: 9.7158 - learning_rate: 2.8184
# Epoch 171/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 291.1685 - val_loss: 175.9018 - learning_rate: 3.1623
# Epoch 172/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 739.1807 - val_loss: 203.5362 - learning_rate: 3.5481
# Epoch 173/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 823.3689 - val_loss: 602.7461 - learning_rate: 3.9811
# Epoch 174/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1022.1412 - val_loss: 599.3973 - learning_rate: 4.4668
# Epoch 175/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 897.5482 - val_loss: 185.1296 - learning_rate: 5.0119
# Epoch 176/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1210.8169 - val_loss: 300.4376 - learning_rate: 5.6234
# Epoch 177/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 960.2505 - val_loss: 271.4756 - learning_rate: 6.3096
# Epoch 178/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1396.3257 - val_loss: 730.9385 - learning_rate: 7.0795
# Epoch 179/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1261.1904 - val_loss: 791.6871 - learning_rate: 7.9433
# Epoch 180/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1653.3555 - val_loss: 129.3524 - learning_rate: 8.9125
# Epoch 181/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1809.4296 - val_loss: 708.4081 - learning_rate: 10.0000
# Epoch 182/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1931.1638 - val_loss: 1676.9948 - learning_rate: 11.2202
# Epoch 183/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2651.5425 - val_loss: 871.1939 - learning_rate: 12.5893
# Epoch 184/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2658.6741 - val_loss: 249.8717 - learning_rate: 14.1254
# Epoch 185/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2878.6362 - val_loss: 2318.6011 - learning_rate: 15.8489
# Epoch 186/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3279.2087 - val_loss: 1879.9850 - learning_rate: 17.7828
# Epoch 187/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3560.5735 - val_loss: 1807.0333 - learning_rate: 19.9526
# Epoch 188/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3229.7698 - val_loss: 3254.5935 - learning_rate: 22.3872
# Epoch 189/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4693.2012 - val_loss: 4091.1426 - learning_rate: 25.1189
# Epoch 190/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5279.3291 - val_loss: 2042.8118 - learning_rate: 28.1838
# Epoch 191/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8687.9434 - val_loss: 5900.7354 - learning_rate: 31.6228
# Epoch 192/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7989.2690 - val_loss: 69.2729 - learning_rate: 35.4813
# Epoch 193/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7385.3809 - val_loss: 3236.9275 - learning_rate: 39.8107
# Epoch 194/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7192.3599 - val_loss: 1038.2395 - learning_rate: 44.6684
# Epoch 195/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11086.1113 - val_loss: 9271.9209 - learning_rate: 50.1187
# Epoch 196/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 11626.8203 - val_loss: 1336.3857 - learning_rate: 56.2341
# Epoch 197/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 10111.7441 - val_loss: 4525.3569 - learning_rate: 63.0957
# Epoch 198/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 11887.9570 - val_loss: 8978.6377 - learning_rate: 70.7946
# Epoch 199/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 14440.1260 - val_loss: 2799.5818 - learning_rate: 79.4328
# Epoch 200/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 15469.1123 - val_loss: 5008.4028 - learning_rate: 89.1251

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(200) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the training loss in log scale
plt.semilogx(lrs, history.history["loss"], label="Training Loss")

# Plot the validation loss in log scale
plt.semilogx(lrs, history.history["val_loss"], label="Validation Loss")

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-1, 0, 1])

# Add a legend
plt.legend()

# Add labels and title
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Training and Validation Loss vs. Learning Rate")

# Show the plot
plt.show()

# %%
model_RNN=1

# %%
# Build the model
from tensorflow.keras.layers import Bidirectional, SimpleRNN, Dense
model_RNN = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size,1)),
    tf.keras.layers.SimpleRNN(50, return_sequences=True),
    tf.keras.layers.SimpleRNN(50),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1),
])

# Set the learning rate
learning_rate = 1e-3

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model_RNN.compile(loss=tf.keras.losses.Huber(),
                  optimizer=optimizer,
                  metrics=["mae"])

# EarlyStopping callback with patience
early_stopping = EarlyStopping(
    monitor="val_loss",     # Monitor validation loss
    patience=5,             # Wait 5 epochs for improvement
    mode="min",             # Stop when val_loss is minimized
    verbose=1               # Print when training stops early
)

# Train the model with EarlyStopping
history = model_RNN.fit(
    x_train_windowed,
    validation_data=x_val_windowed,
    epochs=100,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.4067 - mae: 0.7747 - val_loss: 0.0781 - val_mae: 0.3318
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1073 - mae: 0.3742 - val_loss: 0.0707 - val_mae: 0.3109
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3273 - mae: 0.7234 - val_loss: 0.1946 - val_mae: 0.5428
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2169 - mae: 0.5586 - val_loss: 0.0722 - val_mae: 0.3187
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0557 - mae: 0.2643 - val_loss: 0.1030 - val_mae: 0.3799
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0556 - mae: 0.2782 - val_loss: 0.0677 - val_mae: 0.3036
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0952 - mae: 0.3671 - val_loss: 0.0566 - val_mae: 0.2780
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0229 - mae: 0.1609 - val_loss: 0.0661 - val_mae: 0.3025
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0313 - mae: 0.1986 - val_loss: 0.0625 - val_mae: 0.2901
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0363 - mae: 0.2084 - val_loss: 0.0463 - val_mae: 0.2465
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0237 - mae: 0.1611 - val_loss: 0.0480 - val_mae: 0.2526
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0219 - mae: 0.1651 - val_loss: 0.0508 - val_mae: 0.2583
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0214 - mae: 0.1556 - val_loss: 0.0446 - val_mae: 0.2390
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0232 - mae: 0.1585 - val_loss: 0.0437 - val_mae: 0.2375
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0184 - mae: 0.1461 - val_loss: 0.0459 - val_mae: 0.2443
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0191 - mae: 0.1511 - val_loss: 0.0451 - val_mae: 0.2404
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0201 - mae: 0.1473 - val_loss: 0.0423 - val_mae: 0.2317
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0182 - mae: 0.1394 - val_loss: 0.0433 - val_mae: 0.2360
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0176 - mae: 0.1451 - val_loss: 0.0443 - val_mae: 0.2384
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0177 - mae: 0.1397 - val_loss: 0.0422 - val_mae: 0.2313
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0184 - mae: 0.1402 - val_loss: 0.0417 - val_mae: 0.2302
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0166 - mae: 0.1366 - val_loss: 0.0428 - val_mae: 0.2340
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0167 - mae: 0.1393 - val_loss: 0.0425 - val_mae: 0.2322
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0172 - mae: 0.1361 - val_loss: 0.0410 - val_mae: 0.2277
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0167 - mae: 0.1338 - val_loss: 0.0415 - val_mae: 0.2298
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0160 - mae: 0.1358 - val_loss: 0.0421 - val_mae: 0.2315
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0161 - mae: 0.1342 - val_loss: 0.0412 - val_mae: 0.2281
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0165 - mae: 0.1335 - val_loss: 0.0407 - val_mae: 0.2270
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0157 - mae: 0.1316 - val_loss: 0.0413 - val_mae: 0.2294
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0156 - mae: 0.1334 - val_loss: 0.0413 - val_mae: 0.2290
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0158 - mae: 0.1312 - val_loss: 0.0405 - val_mae: 0.2263
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0158 - mae: 0.1306 - val_loss: 0.0406 - val_mae: 0.2272
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0152 - mae: 0.1306 - val_loss: 0.0411 - val_mae: 0.2287
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0152 - mae: 0.1306 - val_loss: 0.0407 - val_mae: 0.2272
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0155 - mae: 0.1297 - val_loss: 0.0402 - val_mae: 0.2259
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0151 - mae: 0.1285 - val_loss: 0.0406 - val_mae: 0.2275
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0149 - mae: 0.1294 - val_loss: 0.0408 - val_mae: 0.2279
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0150 - mae: 0.1284 - val_loss: 0.0403 - val_mae: 0.2261
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0151 - mae: 0.1282 - val_loss: 0.0402 - val_mae: 0.2262
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0147 - mae: 0.1276 - val_loss: 0.0406 - val_mae: 0.2276
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0146 - mae: 0.1279 - val_loss: 0.0405 - val_mae: 0.2270
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0148 - mae: 0.1273 - val_loss: 0.0401 - val_mae: 0.2258
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0147 - mae: 0.1268 - val_loss: 0.0402 - val_mae: 0.2267
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0144 - mae: 0.1269 - val_loss: 0.0405 - val_mae: 0.2274
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0145 - mae: 0.1266 - val_loss: 0.0402 - val_mae: 0.2263
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0146 - mae: 0.1265 - val_loss: 0.0400 - val_mae: 0.2259
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0143 - mae: 0.1259 - val_loss: 0.0402 - val_mae: 0.2270
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0142 - mae: 0.1262 - val_loss: 0.0403 - val_mae: 0.2270
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0143 - mae: 0.1258 - val_loss: 0.0400 - val_mae: 0.2259
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0143 - mae: 0.1256 - val_loss: 0.0400 - val_mae: 0.2262
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0141 - mae: 0.1254 - val_loss: 0.0402 - val_mae: 0.2270
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0141 - mae: 0.1255 - val_loss: 0.0401 - val_mae: 0.2265
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0141 - mae: 0.1252 - val_loss: 0.0398 - val_mae: 0.2258
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0140 - mae: 0.1249 - val_loss: 0.0400 - val_mae: 0.2264
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0139 - mae: 0.1249 - val_loss: 0.0401 - val_mae: 0.2267
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0139 - mae: 0.1248 - val_loss: 0.0399 - val_mae: 0.2260
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0140 - mae: 0.1246 - val_loss: 0.0398 - val_mae: 0.2259
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0138 - mae: 0.1243 - val_loss: 0.0399 - val_mae: 0.2265
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0137 - mae: 0.1244 - val_loss: 0.0399 - val_mae: 0.2264
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0138 - mae: 0.1243 - val_loss: 0.0397 - val_mae: 0.2258
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0138 - mae: 0.1241 - val_loss: 0.0397 - val_mae: 0.2261
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0136 - mae: 0.1239 - val_loss: 0.0398 - val_mae: 0.2265
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0136 - mae: 0.1239 - val_loss: 0.0397 - val_mae: 0.2260
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0137 - mae: 0.1238 - val_loss: 0.0396 - val_mae: 0.2257
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0136 - mae: 0.1236 - val_loss: 0.0397 - val_mae: 0.2262
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0135 - mae: 0.1235 - val_loss: 0.0397 - val_mae: 0.2262
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0135 - mae: 0.1234 - val_loss: 0.0396 - val_mae: 0.2258
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0135 - mae: 0.1233 - val_loss: 0.0395 - val_mae: 0.2258
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0134 - mae: 0.1231 - val_loss: 0.0396 - val_mae: 0.2262
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0134 - mae: 0.1230 - val_loss: 0.0396 - val_mae: 0.2260
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0134 - mae: 0.1229 - val_loss: 0.0394 - val_mae: 0.2257
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0134 - mae: 0.1228 - val_loss: 0.0395 - val_mae: 0.2259
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0133 - mae: 0.1226 - val_loss: 0.0395 - val_mae: 0.2261
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0133 - mae: 0.1226 - val_loss: 0.0394 - val_mae: 0.2258
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0133 - mae: 0.1225 - val_loss: 0.0393 - val_mae: 0.2257
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0133 - mae: 0.1223 - val_loss: 0.0394 - val_mae: 0.2259
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0132 - mae: 0.1222 - val_loss: 0.0394 - val_mae: 0.2259
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0132 - mae: 0.1221 - val_loss: 0.0393 - val_mae: 0.2256
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0132 - mae: 0.1220 - val_loss: 0.0393 - val_mae: 0.2257
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0131 - mae: 0.1219 - val_loss: 0.0393 - val_mae: 0.2259
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0131 - mae: 0.1218 - val_loss: 0.0392 - val_mae: 0.2257
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0131 - mae: 0.1217 - val_loss: 0.0392 - val_mae: 0.2255
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0131 - mae: 0.1216 - val_loss: 0.0392 - val_mae: 0.2257
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0130 - mae: 0.1215 - val_loss: 0.0392 - val_mae: 0.2257
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0130 - mae: 0.1214 - val_loss: 0.0391 - val_mae: 0.2255
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0130 - mae: 0.1213 - val_loss: 0.0391 - val_mae: 0.2255
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0130 - mae: 0.1212 - val_loss: 0.0391 - val_mae: 0.2256
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0129 - mae: 0.1211 - val_loss: 0.0391 - val_mae: 0.2256
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0129 - mae: 0.1210 - val_loss: 0.0390 - val_mae: 0.2254
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0129 - mae: 0.1209 - val_loss: 0.0390 - val_mae: 0.2255
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0129 - mae: 0.1208 - val_loss: 0.0390 - val_mae: 0.2255
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0129 - mae: 0.1207 - val_loss: 0.0389 - val_mae: 0.2254
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0129 - mae: 0.1206 - val_loss: 0.0389 - val_mae: 0.2253
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0128 - mae: 0.1205 - val_loss: 0.0389 - val_mae: 0.2254
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0128 - mae: 0.1204 - val_loss: 0.0389 - val_mae: 0.2254
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0128 - mae: 0.1203 - val_loss: 0.0388 - val_mae: 0.2252
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0128 - mae: 0.1202 - val_loss: 0.0388 - val_mae: 0.2252
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0127 - mae: 0.1201 - val_loss: 0.0388 - val_mae: 0.2253
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0127 - mae: 0.1200 - val_loss: 0.0387 - val_mae: 0.2252
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0127 - mae: 0.1199 - val_loss: 0.0387 - val_mae: 0.2251

# %%
# Initialize a list
forecast = []

# Use the model to predict data points per window size
for time in range(len(grouped_df0)-split2-window_size):
  forecast.append(model_RNN.predict(x_test_scaled[time:time + window_size][np.newaxis], verbose=0))

# Slice the points that are aligned with the validation set
#forecast = forecast[split_time - window_size:]

# Compare number of elements in the predictions and the validation set
print(f'length of the forecast list: {len(forecast)}')
print(f'shape of the validation set: {x_test.shape}')
# Out:
# length of the forecast list: 337
# shape of the validation set: (367,)

# %%
# Preview shapes after using the conversion and squeeze methods
print(f'shape after converting to numpy array: {np.array(forecast).shape}')
print(f'shape after squeezing: {np.array(forecast).squeeze().shape}')

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()
# Out:
# shape after converting to numpy array: (337, 1, 1)
# shape after squeezing: (337,)

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)), label='True Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(results_reshaped), label='Predicted', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
true_values = x_test_scaled_df.values[30:].reshape(-1, 1)
predicted_values = results_reshaped

print("MSE:", mse(true_values, predicted_values).numpy())
print("MAE:", mae(true_values, predicted_values).numpy())

rnn_mse = mse(true_values, predicted_values).numpy()
rnn_mae = mae(true_values, predicted_values).numpy()
# Out:
# MSE: 0.9142491
# MAE: 0.73742104

# %% [markdown]
# #LSTM

# %%
# Build the Model
model_tune1 = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
])

# Print the model summary
model_tune1.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional_4 (Bidirectional)      │ (None, 30, 64)              │           8,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 30, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_5 (Bidirectional)      │ (None, 64)                  │          24,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 33,601 (131.25 KB)
#  Trainable params: 33,601 (131.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune1.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model_tune1.fit(x_train_windowed, validation_data=x_val_windowed, epochs=200, callbacks=[lr_schedule])
# Out:
# Epoch 1/200
#      11/Unknown 7s 82ms/step - loss: 0.3488
# /usr/lib/python3.10/contextlib.py:153: UserWarning:
#
# Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 333ms/step - loss: 0.3520 - val_loss: 3.3106 - learning_rate: 1.0000e-08
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.3529 - val_loss: 3.3106 - learning_rate: 1.1220e-08
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.3526 - val_loss: 3.3106 - learning_rate: 1.2589e-08
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3534 - val_loss: 3.3106 - learning_rate: 1.4125e-08
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.3524 - val_loss: 3.3106 - learning_rate: 1.5849e-08
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.3511 - val_loss: 3.3106 - learning_rate: 1.7783e-08
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.3530 - val_loss: 3.3106 - learning_rate: 1.9953e-08
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.3559 - val_loss: 3.3106 - learning_rate: 2.2387e-08
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.3511 - val_loss: 3.3106 - learning_rate: 2.5119e-08
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.3527 - val_loss: 3.3106 - learning_rate: 2.8184e-08
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.3534 - val_loss: 3.3105 - learning_rate: 3.1623e-08
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3530 - val_loss: 3.3105 - learning_rate: 3.5481e-08
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.3539 - val_loss: 3.3105 - learning_rate: 3.9811e-08
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3511 - val_loss: 3.3105 - learning_rate: 4.4668e-08
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.3539 - val_loss: 3.3105 - learning_rate: 5.0119e-08
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.3529 - val_loss: 3.3105 - learning_rate: 5.6234e-08
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.3518 - val_loss: 3.3105 - learning_rate: 6.3096e-08
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.3509 - val_loss: 3.3105 - learning_rate: 7.0795e-08
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.3535 - val_loss: 3.3104 - learning_rate: 7.9433e-08
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3522 - val_loss: 3.3104 - learning_rate: 8.9125e-08
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.3537 - val_loss: 3.3104 - learning_rate: 1.0000e-07
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.3525 - val_loss: 3.3104 - learning_rate: 1.1220e-07
# Epoch 23/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3510 - val_loss: 3.3103 - learning_rate: 1.2589e-07
# Epoch 24/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.3531 - val_loss: 3.3103 - learning_rate: 1.4125e-07
# Epoch 25/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3512 - val_loss: 3.3102 - learning_rate: 1.5849e-07
# Epoch 26/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.3566 - val_loss: 3.3102 - learning_rate: 1.7783e-07
# Epoch 27/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3524 - val_loss: 3.3101 - learning_rate: 1.9953e-07
# Epoch 28/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3528 - val_loss: 3.3101 - learning_rate: 2.2387e-07
# Epoch 29/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.3559 - val_loss: 3.3100 - learning_rate: 2.5119e-07
# Epoch 30/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.3503 - val_loss: 3.3099 - learning_rate: 2.8184e-07
# Epoch 31/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.3530 - val_loss: 3.3099 - learning_rate: 3.1623e-07
# Epoch 32/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.3526 - val_loss: 3.3098 - learning_rate: 3.5481e-07
# Epoch 33/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.3517 - val_loss: 3.3097 - learning_rate: 3.9811e-07
# Epoch 34/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.3526 - val_loss: 3.3095 - learning_rate: 4.4668e-07
# Epoch 35/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.3496 - val_loss: 3.3094 - learning_rate: 5.0119e-07
# Epoch 36/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3536 - val_loss: 3.3093 - learning_rate: 5.6234e-07
# Epoch 37/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.3536 - val_loss: 3.3091 - learning_rate: 6.3096e-07
# Epoch 38/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.3499 - val_loss: 3.3089 - learning_rate: 7.0795e-07
# Epoch 39/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.3499 - val_loss: 3.3087 - learning_rate: 7.9433e-07
# Epoch 40/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.3516 - val_loss: 3.3085 - learning_rate: 8.9125e-07
# Epoch 41/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.3515 - val_loss: 3.3082 - learning_rate: 1.0000e-06
# Epoch 42/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3530 - val_loss: 3.3079 - learning_rate: 1.1220e-06
# Epoch 43/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.3529 - val_loss: 3.3076 - learning_rate: 1.2589e-06
# Epoch 44/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.3525 - val_loss: 3.3072 - learning_rate: 1.4125e-06
# Epoch 45/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.3522 - val_loss: 3.3068 - learning_rate: 1.5849e-06
# Epoch 46/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.3530 - val_loss: 3.3063 - learning_rate: 1.7783e-06
# Epoch 47/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.3544 - val_loss: 3.3058 - learning_rate: 1.9953e-06
# Epoch 48/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.3519 - val_loss: 3.3052 - learning_rate: 2.2387e-06
# Epoch 49/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3526 - val_loss: 3.3045 - learning_rate: 2.5119e-06
# Epoch 50/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3499 - val_loss: 3.3037 - learning_rate: 2.8184e-06
# Epoch 51/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.3504 - val_loss: 3.3029 - learning_rate: 3.1623e-06
# Epoch 52/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.3504 - val_loss: 3.3019 - learning_rate: 3.5481e-06
# Epoch 53/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3508 - val_loss: 3.3009 - learning_rate: 3.9811e-06
# Epoch 54/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.3488 - val_loss: 3.2997 - learning_rate: 4.4668e-06
# Epoch 55/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3505 - val_loss: 3.2984 - learning_rate: 5.0119e-06
# Epoch 56/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3508 - val_loss: 3.2969 - learning_rate: 5.6234e-06
# Epoch 57/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.3481 - val_loss: 3.2952 - learning_rate: 6.3096e-06
# Epoch 58/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.3454 - val_loss: 3.2933 - learning_rate: 7.0795e-06
# Epoch 59/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.3474 - val_loss: 3.2912 - learning_rate: 7.9433e-06
# Epoch 60/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.3456 - val_loss: 3.2888 - learning_rate: 8.9125e-06
# Epoch 61/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.3456 - val_loss: 3.2862 - learning_rate: 1.0000e-05
# Epoch 62/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.3433 - val_loss: 3.2832 - learning_rate: 1.1220e-05
# Epoch 63/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3447 - val_loss: 3.2798 - learning_rate: 1.2589e-05
# Epoch 64/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3427 - val_loss: 3.2761 - learning_rate: 1.4125e-05
# Epoch 65/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.3420 - val_loss: 3.2719 - learning_rate: 1.5849e-05
# Epoch 66/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3395 - val_loss: 3.2672 - learning_rate: 1.7783e-05
# Epoch 67/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.3402 - val_loss: 3.2619 - learning_rate: 1.9953e-05
# Epoch 68/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.3366 - val_loss: 3.2560 - learning_rate: 2.2387e-05
# Epoch 69/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.3368 - val_loss: 3.2493 - learning_rate: 2.5119e-05
# Epoch 70/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3336 - val_loss: 3.2419 - learning_rate: 2.8184e-05
# Epoch 71/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.3300 - val_loss: 3.2335 - learning_rate: 3.1623e-05
# Epoch 72/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.3301 - val_loss: 3.2241 - learning_rate: 3.5481e-05
# Epoch 73/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.3284 - val_loss: 3.2136 - learning_rate: 3.9811e-05
# Epoch 74/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.3254 - val_loss: 3.2019 - learning_rate: 4.4668e-05
# Epoch 75/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.3196 - val_loss: 3.1887 - learning_rate: 5.0119e-05
# Epoch 76/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.3185 - val_loss: 3.1739 - learning_rate: 5.6234e-05
# Epoch 77/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.3143 - val_loss: 3.1574 - learning_rate: 6.3096e-05
# Epoch 78/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.3084 - val_loss: 3.1389 - learning_rate: 7.0795e-05
# Epoch 79/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.3032 - val_loss: 3.1182 - learning_rate: 7.9433e-05
# Epoch 80/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.2957 - val_loss: 3.0950 - learning_rate: 8.9125e-05
# Epoch 81/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.2911 - val_loss: 3.0691 - learning_rate: 1.0000e-04
# Epoch 82/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.2850 - val_loss: 3.0401 - learning_rate: 1.1220e-04
# Epoch 83/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2750 - val_loss: 3.0077 - learning_rate: 1.2589e-04
# Epoch 84/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.2675 - val_loss: 2.9716 - learning_rate: 1.4125e-04
# Epoch 85/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.2596 - val_loss: 2.9312 - learning_rate: 1.5849e-04
# Epoch 86/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.2461 - val_loss: 2.8863 - learning_rate: 1.7783e-04
# Epoch 87/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.2377 - val_loss: 2.8362 - learning_rate: 1.9953e-04
# Epoch 88/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.2261 - val_loss: 2.7804 - learning_rate: 2.2387e-04
# Epoch 89/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.2144 - val_loss: 2.7183 - learning_rate: 2.5119e-04
# Epoch 90/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.1996 - val_loss: 2.6492 - learning_rate: 2.8184e-04
# Epoch 91/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.1856 - val_loss: 2.5729 - learning_rate: 3.1623e-04
# Epoch 92/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1703 - val_loss: 2.4887 - learning_rate: 3.5481e-04
# Epoch 93/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.1555 - val_loss: 2.3959 - learning_rate: 3.9811e-04
# Epoch 94/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.1400 - val_loss: 2.2947 - learning_rate: 4.4668e-04
# Epoch 95/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.1245 - val_loss: 2.1854 - learning_rate: 5.0119e-04
# Epoch 96/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.1108 - val_loss: 2.0689 - learning_rate: 5.6234e-04
# Epoch 97/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0990 - val_loss: 1.9478 - learning_rate: 6.3096e-04
# Epoch 98/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0882 - val_loss: 1.8243 - learning_rate: 7.0795e-04
# Epoch 99/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0802 - val_loss: 1.7038 - learning_rate: 7.9433e-04
# Epoch 100/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0757 - val_loss: 1.5900 - learning_rate: 8.9125e-04
# Epoch 101/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0748 - val_loss: 1.4882 - learning_rate: 0.0010
# Epoch 102/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0758 - val_loss: 1.3997 - learning_rate: 0.0011
# Epoch 103/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0761 - val_loss: 1.3287 - learning_rate: 0.0013
# Epoch 104/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0787 - val_loss: 1.2707 - learning_rate: 0.0014
# Epoch 105/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0782 - val_loss: 1.2211 - learning_rate: 0.0016
# Epoch 106/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0782 - val_loss: 1.1780 - learning_rate: 0.0018
# Epoch 107/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0778 - val_loss: 1.1373 - learning_rate: 0.0020
# Epoch 108/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0759 - val_loss: 1.0941 - learning_rate: 0.0022
# Epoch 109/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0758 - val_loss: 1.0509 - learning_rate: 0.0025
# Epoch 110/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0741 - val_loss: 1.0032 - learning_rate: 0.0028
# Epoch 111/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0726 - val_loss: 0.9460 - learning_rate: 0.0032
# Epoch 112/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0700 - val_loss: 0.8928 - learning_rate: 0.0035
# Epoch 113/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0700 - val_loss: 0.8369 - learning_rate: 0.0040
# Epoch 114/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0685 - val_loss: 0.7785 - learning_rate: 0.0045
# Epoch 115/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0667 - val_loss: 0.7176 - learning_rate: 0.0050
# Epoch 116/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0656 - val_loss: 0.6638 - learning_rate: 0.0056
# Epoch 117/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0645 - val_loss: 0.6077 - learning_rate: 0.0063
# Epoch 118/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0631 - val_loss: 0.5596 - learning_rate: 0.0071
# Epoch 119/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0623 - val_loss: 0.5138 - learning_rate: 0.0079
# Epoch 120/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0602 - val_loss: 0.4735 - learning_rate: 0.0089
# Epoch 121/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0599 - val_loss: 0.4471 - learning_rate: 0.0100
# Epoch 122/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0596 - val_loss: 0.4059 - learning_rate: 0.0112
# Epoch 123/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0570 - val_loss: 0.3814 - learning_rate: 0.0126
# Epoch 124/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0564 - val_loss: 0.3515 - learning_rate: 0.0141
# Epoch 125/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0553 - val_loss: 0.3153 - learning_rate: 0.0158
# Epoch 126/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0531 - val_loss: 0.2792 - learning_rate: 0.0178
# Epoch 127/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0555 - val_loss: 0.2429 - learning_rate: 0.0200
# Epoch 128/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0533 - val_loss: 0.2174 - learning_rate: 0.0224
# Epoch 129/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0509 - val_loss: 0.1809 - learning_rate: 0.0251
# Epoch 130/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.0504 - val_loss: 0.1459 - learning_rate: 0.0282
# Epoch 131/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0548 - val_loss: 0.1539 - learning_rate: 0.0316
# Epoch 132/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0737 - val_loss: 0.3869 - learning_rate: 0.0355
# Epoch 133/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.1387 - val_loss: 1.5250 - learning_rate: 0.0398
# Epoch 134/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.3052 - val_loss: 0.4910 - learning_rate: 0.0447
# Epoch 135/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.5506 - val_loss: 1.3511 - learning_rate: 0.0501
# Epoch 136/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.1330 - val_loss: 0.6132 - learning_rate: 0.0562
# Epoch 137/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0971 - val_loss: 0.5858 - learning_rate: 0.0631
# Epoch 138/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1097 - val_loss: 0.7338 - learning_rate: 0.0708
# Epoch 139/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.2935 - val_loss: 0.6795 - learning_rate: 0.0794
# Epoch 140/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.3747 - val_loss: 0.5280 - learning_rate: 0.0891
# Epoch 141/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.5761 - val_loss: 0.3345 - learning_rate: 0.1000
# Epoch 142/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.8402 - val_loss: 0.1698 - learning_rate: 0.1122
# Epoch 143/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 1.4118 - val_loss: 0.4110 - learning_rate: 0.1259
# Epoch 144/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 1.8354 - val_loss: 0.7431 - learning_rate: 0.1413
# Epoch 145/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.9724 - val_loss: 0.2334 - learning_rate: 0.1585
# Epoch 146/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.9181 - val_loss: 2.3217 - learning_rate: 0.1778
# Epoch 147/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.4915 - val_loss: 0.4142 - learning_rate: 0.1995
# Epoch 148/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.5070 - val_loss: 0.1798 - learning_rate: 0.2239
# Epoch 149/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 2.0955 - val_loss: 0.1030 - learning_rate: 0.2512
# Epoch 150/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1992 - val_loss: 0.2651 - learning_rate: 0.2818
# Epoch 151/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.5314 - val_loss: 1.3693 - learning_rate: 0.3162
# Epoch 152/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 1.2509 - val_loss: 0.6104 - learning_rate: 0.3548
# Epoch 153/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.7372 - val_loss: 2.2628 - learning_rate: 0.3981
# Epoch 154/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.8725 - val_loss: 2.6291 - learning_rate: 0.4467
# Epoch 155/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.3696 - val_loss: 0.3433 - learning_rate: 0.5012
# Epoch 156/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.7087 - val_loss: 0.2582 - learning_rate: 0.5623
# Epoch 157/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 2.5289 - val_loss: 2.8579 - learning_rate: 0.6310
# Epoch 158/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.4687 - val_loss: 0.1718 - learning_rate: 0.7079
# Epoch 159/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 1.5526 - val_loss: 0.6813 - learning_rate: 0.7943
# Epoch 160/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 1.2107 - val_loss: 0.6958 - learning_rate: 0.8913
# Epoch 161/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.8424 - val_loss: 0.2227 - learning_rate: 1.0000
# Epoch 162/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 1.6083 - val_loss: 1.9314 - learning_rate: 1.1220
# Epoch 163/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.7834 - val_loss: 2.0398 - learning_rate: 1.2589
# Epoch 164/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 1.0846 - val_loss: 0.2406 - learning_rate: 1.4125
# Epoch 165/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 2.4240 - val_loss: 0.1996 - learning_rate: 1.5849
# Epoch 166/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 1.0842 - val_loss: 0.1662 - learning_rate: 1.7783
# Epoch 167/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 1.6884 - val_loss: 1.2357 - learning_rate: 1.9953
# Epoch 168/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 2.7234 - val_loss: 0.1645 - learning_rate: 2.2387
# Epoch 169/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 3.5498 - val_loss: 1.7446 - learning_rate: 2.5119
# Epoch 170/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 7.6578 - val_loss: 11.5946 - learning_rate: 2.8184
# Epoch 171/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 6.9821 - val_loss: 13.6886 - learning_rate: 3.1623
# Epoch 172/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 10.4871 - val_loss: 21.1508 - learning_rate: 3.5481
# Epoch 173/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 13.2280 - val_loss: 17.7905 - learning_rate: 3.9811
# Epoch 174/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 12.5559 - val_loss: 3.9734 - learning_rate: 4.4668
# Epoch 175/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 10.1619 - val_loss: 30.2255 - learning_rate: 5.0119
# Epoch 176/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 19.4595 - val_loss: 24.1577 - learning_rate: 5.6234
# Epoch 177/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 20.1400 - val_loss: 9.9497 - learning_rate: 6.3096
# Epoch 178/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 33.9018 - val_loss: 104.1315 - learning_rate: 7.0795
# Epoch 179/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 73.1778 - val_loss: 55.9028 - learning_rate: 7.9433
# Epoch 180/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 37.6705 - val_loss: 85.8320 - learning_rate: 8.9125
# Epoch 181/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 62.4270 - val_loss: 28.0917 - learning_rate: 10.0000
# Epoch 182/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 19.6107 - val_loss: 6.5100 - learning_rate: 11.2202
# Epoch 183/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 46.0974 - val_loss: 38.3006 - learning_rate: 12.5893
# Epoch 184/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 75.4844 - val_loss: 100.4379 - learning_rate: 14.1254
# Epoch 185/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 90.0216 - val_loss: 37.8942 - learning_rate: 15.8489
# Epoch 186/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 48.7549 - val_loss: 156.1692 - learning_rate: 17.7828
# Epoch 187/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 86.7889 - val_loss: 17.8730 - learning_rate: 19.9526
# Epoch 188/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 184.6305 - val_loss: 61.7860 - learning_rate: 22.3872
# Epoch 189/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 90.0051 - val_loss: 72.6745 - learning_rate: 25.1189
# Epoch 190/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 63.2593 - val_loss: 45.1523 - learning_rate: 28.1838
# Epoch 191/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 256.4987 - val_loss: 709.0199 - learning_rate: 31.6228
# Epoch 192/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 570.4266 - val_loss: 718.7305 - learning_rate: 35.4813
# Epoch 193/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 566.2291 - val_loss: 480.6403 - learning_rate: 39.8107
# Epoch 194/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 548.2336 - val_loss: 149.3644 - learning_rate: 44.6684
# Epoch 195/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 582.8936 - val_loss: 227.3210 - learning_rate: 50.1187
# Epoch 196/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 431.2841 - val_loss: 373.5146 - learning_rate: 56.2341
# Epoch 197/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 499.2450 - val_loss: 250.3032 - learning_rate: 63.0957
# Epoch 198/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 281.0939 - val_loss: 239.0130 - learning_rate: 70.7946
# Epoch 199/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 663.5071 - val_loss: 1083.6971 - learning_rate: 79.4328
# Epoch 200/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 827.9810 - val_loss: 1044.3032 - learning_rate: 89.1251

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(200) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the training loss in log scale
plt.semilogx(lrs, history.history["loss"], label="Training Loss")

# Plot the validation loss in log scale
plt.semilogx(lrs, history.history["val_loss"], label="Validation Loss")

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-1, 0, 1])

# Add a legend
plt.legend()

# Add labels and title
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Training and Validation Loss vs. Learning Rate")

# Show the plot
plt.show()

# %% [raw]
# model_LSTM=1

# %%
# Reset states generated by Keras
#tf.keras.backend.clear_session()

# Build the model
model_LSTM = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
])

# Set the learning rate
learning_rate = 1e-3

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model_LSTM.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# EarlyStopping callback with patience
early_stopping = EarlyStopping(
    monitor="val_loss",     # Monitor validation loss
    patience=5,             # Wait 5 epochs for improvement
    mode="min",             # Stop when val_loss is minimized
    verbose=1               # Print when training stops early
)

# Train the model with EarlyStopping
history = model_LSTM.fit(
    x_train_windowed,
    validation_data=x_val_windowed,
    epochs=100,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - loss: 0.2910 - mae: 0.6688 - val_loss: 2.8347 - val_mae: 3.3347
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2384 - mae: 0.5999 - val_loss: 2.5243 - val_mae: 3.0243
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1754 - mae: 0.5071 - val_loss: 2.1899 - val_mae: 2.6899
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1263 - mae: 0.4229 - val_loss: 1.8880 - val_mae: 2.3880
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0957 - mae: 0.3570 - val_loss: 1.6394 - val_mae: 2.1390
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0805 - mae: 0.3130 - val_loss: 1.4515 - val_mae: 1.9496
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0755 - mae: 0.2945 - val_loss: 1.3185 - val_mae: 1.8143
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0753 - mae: 0.2922 - val_loss: 1.2286 - val_mae: 1.7218
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.0763 - mae: 0.2947 - val_loss: 1.1685 - val_mae: 1.6595
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.0770 - mae: 0.2966 - val_loss: 1.1277 - val_mae: 1.6168
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.0770 - mae: 0.2970 - val_loss: 1.0979 - val_mae: 1.5856
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0764 - mae: 0.2961 - val_loss: 1.0739 - val_mae: 1.5603
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0756 - mae: 0.2946 - val_loss: 1.0525 - val_mae: 1.5378
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0747 - mae: 0.2927 - val_loss: 1.0322 - val_mae: 1.5165
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0739 - mae: 0.2909 - val_loss: 1.0125 - val_mae: 1.4957
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0731 - mae: 0.2892 - val_loss: 0.9932 - val_mae: 1.4751
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0723 - mae: 0.2876 - val_loss: 0.9742 - val_mae: 1.4549
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0716 - mae: 0.2861 - val_loss: 0.9556 - val_mae: 1.4351
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0710 - mae: 0.2847 - val_loss: 0.9377 - val_mae: 1.4159
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0703 - mae: 0.2834 - val_loss: 0.9205 - val_mae: 1.3973
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0697 - mae: 0.2820 - val_loss: 0.9038 - val_mae: 1.3793
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0691 - mae: 0.2808 - val_loss: 0.8877 - val_mae: 1.3619
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0686 - mae: 0.2796 - val_loss: 0.8722 - val_mae: 1.3450
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0681 - mae: 0.2785 - val_loss: 0.8572 - val_mae: 1.3286
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0676 - mae: 0.2775 - val_loss: 0.8426 - val_mae: 1.3126
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0671 - mae: 0.2765 - val_loss: 0.8286 - val_mae: 1.2972
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0666 - mae: 0.2755 - val_loss: 0.8150 - val_mae: 1.2823
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0662 - mae: 0.2746 - val_loss: 0.8018 - val_mae: 1.2677
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0658 - mae: 0.2736 - val_loss: 0.7890 - val_mae: 1.2536
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0654 - mae: 0.2727 - val_loss: 0.7766 - val_mae: 1.2399
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0650 - mae: 0.2719 - val_loss: 0.7646 - val_mae: 1.2266
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0646 - mae: 0.2710 - val_loss: 0.7530 - val_mae: 1.2136
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0643 - mae: 0.2703 - val_loss: 0.7417 - val_mae: 1.2012
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0639 - mae: 0.2695 - val_loss: 0.7307 - val_mae: 1.1890
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0636 - mae: 0.2688 - val_loss: 0.7201 - val_mae: 1.1771
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0633 - mae: 0.2680 - val_loss: 0.7098 - val_mae: 1.1656
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0630 - mae: 0.2673 - val_loss: 0.6997 - val_mae: 1.1545
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0628 - mae: 0.2667 - val_loss: 0.6900 - val_mae: 1.1437
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0625 - mae: 0.2661 - val_loss: 0.6805 - val_mae: 1.1332
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0622 - mae: 0.2655 - val_loss: 0.6714 - val_mae: 1.1229
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0620 - mae: 0.2649 - val_loss: 0.6624 - val_mae: 1.1129
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0618 - mae: 0.2644 - val_loss: 0.6537 - val_mae: 1.1031
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0615 - mae: 0.2638 - val_loss: 0.6453 - val_mae: 1.0936
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0613 - mae: 0.2633 - val_loss: 0.6371 - val_mae: 1.0844
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0611 - mae: 0.2628 - val_loss: 0.6291 - val_mae: 1.0753
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0609 - mae: 0.2623 - val_loss: 0.6213 - val_mae: 1.0665
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0607 - mae: 0.2618 - val_loss: 0.6137 - val_mae: 1.0579
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0605 - mae: 0.2614 - val_loss: 0.6063 - val_mae: 1.0495
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0604 - mae: 0.2609 - val_loss: 0.5991 - val_mae: 1.0414
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.0602 - mae: 0.2605 - val_loss: 0.5920 - val_mae: 1.0334
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.0600 - mae: 0.2601 - val_loss: 0.5852 - val_mae: 1.0256
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0599 - mae: 0.2597 - val_loss: 0.5785 - val_mae: 1.0180
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0597 - mae: 0.2592 - val_loss: 0.5719 - val_mae: 1.0105
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0596 - mae: 0.2589 - val_loss: 0.5656 - val_mae: 1.0032
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0594 - mae: 0.2585 - val_loss: 0.5593 - val_mae: 0.9960
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0593 - mae: 0.2582 - val_loss: 0.5532 - val_mae: 0.9890
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0591 - mae: 0.2579 - val_loss: 0.5472 - val_mae: 0.9821
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0590 - mae: 0.2577 - val_loss: 0.5414 - val_mae: 0.9754
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0589 - mae: 0.2574 - val_loss: 0.5357 - val_mae: 0.9688
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0588 - mae: 0.2571 - val_loss: 0.5300 - val_mae: 0.9623
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0586 - mae: 0.2568 - val_loss: 0.5246 - val_mae: 0.9560
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0585 - mae: 0.2566 - val_loss: 0.5192 - val_mae: 0.9498
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0584 - mae: 0.2564 - val_loss: 0.5139 - val_mae: 0.9438
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0583 - mae: 0.2561 - val_loss: 0.5087 - val_mae: 0.9378
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0582 - mae: 0.2559 - val_loss: 0.5036 - val_mae: 0.9320
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0581 - mae: 0.2557 - val_loss: 0.4986 - val_mae: 0.9262
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0580 - mae: 0.2554 - val_loss: 0.4937 - val_mae: 0.9206
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0579 - mae: 0.2552 - val_loss: 0.4889 - val_mae: 0.9151
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0578 - mae: 0.2549 - val_loss: 0.4842 - val_mae: 0.9097
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0577 - mae: 0.2547 - val_loss: 0.4796 - val_mae: 0.9043
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0576 - mae: 0.2545 - val_loss: 0.4750 - val_mae: 0.8991
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0575 - mae: 0.2543 - val_loss: 0.4705 - val_mae: 0.8939
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0574 - mae: 0.2540 - val_loss: 0.4660 - val_mae: 0.8889
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0573 - mae: 0.2538 - val_loss: 0.4617 - val_mae: 0.8839
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0572 - mae: 0.2536 - val_loss: 0.4574 - val_mae: 0.8790
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0571 - mae: 0.2534 - val_loss: 0.4531 - val_mae: 0.8741
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0571 - mae: 0.2531 - val_loss: 0.4490 - val_mae: 0.8693
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0570 - mae: 0.2529 - val_loss: 0.4449 - val_mae: 0.8646
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0569 - mae: 0.2527 - val_loss: 0.4408 - val_mae: 0.8599
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0568 - mae: 0.2525 - val_loss: 0.4368 - val_mae: 0.8553
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0567 - mae: 0.2523 - val_loss: 0.4328 - val_mae: 0.8507
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0567 - mae: 0.2521 - val_loss: 0.4289 - val_mae: 0.8462
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0566 - mae: 0.2518 - val_loss: 0.4251 - val_mae: 0.8417
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0565 - mae: 0.2516 - val_loss: 0.4213 - val_mae: 0.8372
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0564 - mae: 0.2514 - val_loss: 0.4175 - val_mae: 0.8328
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0564 - mae: 0.2512 - val_loss: 0.4138 - val_mae: 0.8285
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0563 - mae: 0.2510 - val_loss: 0.4101 - val_mae: 0.8242
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.0562 - mae: 0.2508 - val_loss: 0.4065 - val_mae: 0.8199
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.0561 - mae: 0.2506 - val_loss: 0.4029 - val_mae: 0.8157
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0561 - mae: 0.2504 - val_loss: 0.3993 - val_mae: 0.8116
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0560 - mae: 0.2502 - val_loss: 0.3958 - val_mae: 0.8075
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0559 - mae: 0.2500 - val_loss: 0.3923 - val_mae: 0.8034
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0559 - mae: 0.2498 - val_loss: 0.3889 - val_mae: 0.7993
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0558 - mae: 0.2496 - val_loss: 0.3854 - val_mae: 0.7952
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0557 - mae: 0.2494 - val_loss: 0.3821 - val_mae: 0.7912
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0557 - mae: 0.2492 - val_loss: 0.3787 - val_mae: 0.7872
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0556 - mae: 0.2490 - val_loss: 0.3754 - val_mae: 0.7832
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0555 - mae: 0.2489 - val_loss: 0.3721 - val_mae: 0.7792
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0555 - mae: 0.2487 - val_loss: 0.3688 - val_mae: 0.7752
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0554 - mae: 0.2486 - val_loss: 0.3656 - val_mae: 0.7713

# %%
type(x_test_scaled)
# Out:
# numpy.ndarray

# %%
# Initialize a list
forecast = []

# Use the model to predict data points per window size
for time in range(len(grouped_df0)-split2-window_size):
  forecast.append(model_LSTM.predict(x_test_scaled[time:time + window_size][np.newaxis], verbose=0))

# Slice the points that are aligned with the validation set
#forecast = forecast[split_time - window_size:]

# Compare number of elements in the predictions and the validation set
print(f'length of the forecast list: {len(forecast)}')
print(f'shape of the validation set: {x_test.shape}')
# Out:
# length of the forecast list: 577
# shape of the validation set: (607,)

# %%
# Preview shapes after using the conversion and squeeze methods
print(f'shape after converting to numpy array: {np.array(forecast).shape}')
print(f'shape after squeezing: {np.array(forecast).squeeze().shape}')

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()
# Out:
# shape after converting to numpy array: (577, 1, 1)
# shape after squeezing: (577,)

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)), label='True Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(results_reshaped), label='Predicted', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
import plotly.express as px
import pandas as pd

# Prepare a DataFrame for Plotly
plot_df = pd.DataFrame({
    'Price Date': x_test_scaled_df.index[30:],
    'True Value': scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)).flatten(),
    'Predicted': scaler.inverse_transform(results.reshape(-1, 1)).flatten()
})

# Create an interactive plot
fig = px.line(
    plot_df,
    x='Price Date',
    y=['True Value', 'Predicted'],
    labels={'value': 'Modal Price (Rs./Quintal)', 'variable': 'Legend'},
    title='Modal Price Over Time'
)

# Update layout for better aesthetics
fig.update_layout(
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="843f11ba-105a-4f43-9654-adad20fe8bb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("843f11ba-105a-4f43-9654-adad20fe8bb1")) {                    Plotly.newPlot(                        "843f11ba-105a-4f43-9654-adad20fe8bb1",                        [{"hovertemplate":"Legend=True Value\u003cbr\u003ePrice Date=%{x}\u003cbr\u003eModal Price (Rs.\u002fQuintal)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True Value","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"True Value","showlegend":true,"x":["2023-04-04T00:00:00","2023-04-05T00:00:00","2023-04-06T00:00:00","2023-04-07T00:00:00","2023-04-08T00:00:00","2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-04-29T00:00:00","2023-04-30T00:00:00","2023-05-01T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-06T00:00:00","2023-05-07T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-13T00:00:00","2023-05-14T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-20T00:00:00","2023-05-21T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-27T00:00:00","2023-05-28T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-03T00:00:00","2023-06-04T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-10T00:00:00","2023-06-11T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-17T00:00:00","2023-06-18T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-24T00:00:00","2023-06-25T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-29T00:00:00","2023-06-30T00:00:00","2023-07-01T00:00:00","2023-07-02T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00","2023-08-18T00:00:00","2023-08-19T00:00:00","2023-08-20T00:00:00","2023-08-21T00:00:00","2023-08-22T00:00:00","2023-08-23T00:00:00"," ...

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
true_values = x_test_scaled_df.values[30:].reshape(-1, 1)
predicted_values = results_reshaped

print("MSE:", mse(true_values, predicted_values).numpy())
print("MAE:", mae(true_values, predicted_values).numpy())

lstm_mse = mse(true_values, predicted_values).numpy()
lstm_mae = mae(true_values, predicted_values).numpy()
# Out:
# MSE: 3.1855125
# MAE: 1.3508818

# %%
model_name = ['rnn', 'lstm']
lst_mse = [rnn_mse, lstm_mse]
lst_mae = [rnn_mae, lstm_mae]

for i in range(len(model_name)):
    print(f'MSE dari {model_name[i]} adalah {lst_mse[i]}')
    print(f'MAE dari {model_name[i]} adalah {lst_mae[i]}')

smallest_mse = np.argmin(lst_mse)
smallest_mae = np.argmin(lst_mae)

print(f'Model terbaik adalah {model_name[smallest_mse]} berdasarkan MSE terkecil')
print(f'Model terbaik adalah {model_name[smallest_mae]} berdasarkan MAE terkecil')
# Out:
# MSE dari rnn adalah 1.6585520505905151
# MAE dari rnn adalah 0.8506267666816711
# MSE dari lstm adalah 3.1855125427246094
# MAE dari lstm adalah 1.350881814956665
# Model terbaik adalah rnn berdasarkan MSE terkecil
# Model terbaik adalah rnn berdasarkan MAE terkecil

# %% [markdown]
# Forecast

# %%
numpy_grouped_df=grouped_df0.to_numpy()

# %%
numpy_grouped_df_scaled = scaler.transform(numpy_grouped_df.reshape(-1,1))

# %%
days = 240

# %%
len(numpy_grouped_df)/240
# Out:
# 5.529166666666667

# %% [markdown]
# Plot ulang RNN

# %%
# Initialize lists for forecast
days = 240
forecast = []
result_forecast = numpy_grouped_df_scaled[-240:].tolist()  # Use the last 30 values as the starting point

# Flatten result_forecast if it contains nested lists
# Assuming numpy_grouped_df_scaled[-30:] is a 2D array or list of lists
result_forecast = [item[0] if isinstance(item, list) else float(item) for item in result_forecast]

# Forecast for 365 days
for _ in range(days):
    # Prepare input for the model
    input_data = np.array(result_forecast[-240:]).reshape(1, 240, 1)  # Reshape correctly

    # Predict and extract the scalar value
    prediksi = model_RNN.predict(input_data)[0][0]  # Extract scalar from prediction array

    # Append the prediction
    forecast.append(prediksi)  # For final forecast output
    result_forecast.append(prediksi)  # For generating subsequent predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
last_30_df = pd.DataFrame(numpy_grouped_df[-240:], columns=[grouped_df0.name],index=grouped_df0[-240:].index)

# %%
# Assume forecast contains the 30 predicted values
import pandas as pd

# Create a new datetime index for the next 30 days
new_dates = pd.date_range(start=last_30_df.index[-1] + pd.Timedelta(days=1), periods=days)

# Create a new DataFrame with the forecasted values
forecast_df = pd.DataFrame({'Modal Price (Rs./Quintal)': (scaler.inverse_transform(np.array(forecast).reshape(-1,1)).flatten())}, index=new_dates)

# Concatenate the existing DataFrame with the forecasted DataFrame
extended_df = pd.concat([last_30_df, forecast_df])

# Display the extended DataFrame
print(len(extended_df))
# Out:
# 480

# %%
import plotly.graph_objects as go
import pandas as pd

# Concatenate the actual and forecast DataFrames into a single DataFrame
combined_df = pd.concat([last_30_df, forecast_df])

# Create a figure
fig = go.Figure()


# Add a trace for the combined actual and forecast data (continuous line)
fig.add_trace(go.Scatter(
    x=extended_df.index,  # Use the combined index of both actual and forecast
    y=extended_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='Predicted Price',  # Label for combined data
    line=dict(color='red')  # Blue color for the forecasted data
))

# Add a trace for the last 30 actual values
fig.add_trace(go.Scatter(
    x=last_30_df.index,  # Only the index for the last 30 actual values
    y=last_30_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='True Price',  # Label for the last 30 actual data
    line=dict(color='blue')  # Green color for actual data
))


# Update layout for better aesthetics
fig.update_layout(
    title='Modal Price Over Time',
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="087aec8c-707b-47d1-9837-68469c3df16f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("087aec8c-707b-47d1-9837-68469c3df16f")) {                    Plotly.newPlot(                        "087aec8c-707b-47d1-9837-68469c3df16f",                        [{"line":{"color":"red"},"mode":"lines","name":"Predicted Price","x":["2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-24T00:00:00","2024-05-25T00:00:00","2024-05-26T00:00:00","2024-05-27T00:00:00","2024-05-28T00:00:00","2024-05-29T00:00:00","2024-05-30T00:00:00","2024-05-31T00:00:00","2024-06-01T00:00:00","2024-06-02T00:00:00","2024-06-03T00:00:00","2024-06-04T00:00:00","2024-06-05T00:00:00","2024-06-06T00:00:00","2024-06-07T00:00:00","2024-06-08T00:00:00","2024-06-09T00:00:00","2024-06-10T00:00:00","2024-06-11T00:00:00","2024-06-12T00:00:00","2024-06-13T00:00:00","2024-06-14T00:00:00","2024-06-15T00:00:00","2024-06-16T00:00:00","2024-06-17T00:00:00","2024-06-18T00:00:00","2024-06-19T00:00:00","2024-06-20T00:00:00","2024-06-21T00:00:00","2024-06-22T00:00:00","2024-06-23T00:00:00","2024-06-24T00:00:00","2024-06-25T00:00:00","2024-06-26T00:00:00","2024-06-27T00:00:00","2024-06-28T00:00:00","2024-06-29T00:00:00","2024-06-30T00:00:00","2024-07-01T00:00:00","2024-07-02T00:00:00","2024-07-03T00:00:00","2024-07-04T00:00:00","2024-07-05T00:00:00","2024-07-06T00:00:00","2024-07-07T00:00:00","2024-07-08T00:00:00","2024-07-09T00:00:00","2024-07-10T00:00:00","2024-07-11T00:00:00","2024-07-12T00:00:00","2024-07-13T00:00:00","2024-07-14T00:00:00","2024-07-15T00:00:00","2024-07-16T00:00:00","2024-07-17T00:00:00","2024-07-18T00:00:00","2024-07-19T00:00:00","2024-07-20T00:00:00","2024-07-21T00:00:00","2024-07-22T00:00:00","2024-07-23T00:00:00","2024-07-24T00:00:00","2024-07-25T00:00:00","2024-07-26T00:00:00","2024-07-27T00:00:00","2024-07-28T00:00:00","2024-07-29T00:00:00","2024-07-30T00:00:00","2024-07-31T00:00:00","2024-08-01T00:00:00","2024-08-02T00:00:00","2024-08-03T00:00:00","2024-08-04T00:00:00","2024-08-05T00:00:00"," ...

# %% [markdown]
# Plot ulang LSTM

# %%
# Initialize lists for forecast
days = 1*240
forecast = []
result_forecast = numpy_grouped_df_scaled[-1*240:].tolist()  # Use the last 30 values as the starting point

# Flatten result_forecast if it contains nested lists
# Assuming numpy_grouped_df_scaled[-30:] is a 2D array or list of lists
result_forecast = [item[0] if isinstance(item, list) else float(item) for item in result_forecast]

# Forecast for 365 days
for _ in range(days):
    # Prepare input for the model
    input_data = np.array(result_forecast[-1*240:]).reshape(1, 1*240, 1)  # Reshape correctly

    # Predict and extract the scalar value
    prediksi = model_LSTM.predict(input_data)[0][0]  # Extract scalar from prediction array

    # Append the prediction
    forecast.append(prediksi)  # For final forecast output
    result_forecast.append(prediksi)  # For generating subsequent predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
last_30_df = pd.DataFrame(numpy_grouped_df[-240:], columns=[grouped_df0.name],index=grouped_df0[-240:].index)

# %%
# Assume forecast contains the 30 predicted values
import pandas as pd

# Create a new datetime index for the next 30 days
new_dates = pd.date_range(start=last_30_df.index[-1] + pd.Timedelta(days=1), periods=days)

# Create a new DataFrame with the forecasted values
forecast_df = pd.DataFrame({'Modal Price (Rs./Quintal)': (scaler.inverse_transform(np.array(forecast).reshape(-1,1)).flatten())}, index=new_dates)

# Concatenate the existing DataFrame with the forecasted DataFrame
extended_df = pd.concat([last_30_df, forecast_df])

# Display the extended DataFrame
print(len(extended_df))
# Out:
# 480

# %%
import plotly.graph_objects as go
import pandas as pd

# Concatenate the actual and forecast DataFrames into a single DataFrame
combined_df = pd.concat([last_30_df, forecast_df])

# Create a figure
fig = go.Figure()


# Add a trace for the combined actual and forecast data (continuous line)
fig.add_trace(go.Scatter(
    x=extended_df.index,  # Use the combined index of both actual and forecast
    y=extended_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='Predicted Price',  # Label for combined data
    line=dict(color='red')  # Blue color for the forecasted data
))

# Add a trace for the last 30 actual values
fig.add_trace(go.Scatter(
    x=last_30_df.index,  # Only the index for the last 30 actual values
    y=last_30_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='True Price',  # Label for the last 30 actual data
    line=dict(color='blue')  # Green color for actual data
))


# Update layout for better aesthetics
fig.update_layout(
    title='Modal Price Over Time',
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4d37bc23-bcb8-414d-a0d3-351c8bba4bef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d37bc23-bcb8-414d-a0d3-351c8bba4bef")) {                    Plotly.newPlot(                        "4d37bc23-bcb8-414d-a0d3-351c8bba4bef",                        [{"line":{"color":"red"},"mode":"lines","name":"Predicted Price","x":["2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-24T00:00:00","2024-05-25T00:00:00","2024-05-26T00:00:00","2024-05-27T00:00:00","2024-05-28T00:00:00","2024-05-29T00:00:00","2024-05-30T00:00:00","2024-05-31T00:00:00","2024-06-01T00:00:00","2024-06-02T00:00:00","2024-06-03T00:00:00","2024-06-04T00:00:00","2024-06-05T00:00:00","2024-06-06T00:00:00","2024-06-07T00:00:00","2024-06-08T00:00:00","2024-06-09T00:00:00","2024-06-10T00:00:00","2024-06-11T00:00:00","2024-06-12T00:00:00","2024-06-13T00:00:00","2024-06-14T00:00:00","2024-06-15T00:00:00","2024-06-16T00:00:00","2024-06-17T00:00:00","2024-06-18T00:00:00","2024-06-19T00:00:00","2024-06-20T00:00:00","2024-06-21T00:00:00","2024-06-22T00:00:00","2024-06-23T00:00:00","2024-06-24T00:00:00","2024-06-25T00:00:00","2024-06-26T00:00:00","2024-06-27T00:00:00","2024-06-28T00:00:00","2024-06-29T00:00:00","2024-06-30T00:00:00","2024-07-01T00:00:00","2024-07-02T00:00:00","2024-07-03T00:00:00","2024-07-04T00:00:00","2024-07-05T00:00:00","2024-07-06T00:00:00","2024-07-07T00:00:00","2024-07-08T00:00:00","2024-07-09T00:00:00","2024-07-10T00:00:00","2024-07-11T00:00:00","2024-07-12T00:00:00","2024-07-13T00:00:00","2024-07-14T00:00:00","2024-07-15T00:00:00","2024-07-16T00:00:00","2024-07-17T00:00:00","2024-07-18T00:00:00","2024-07-19T00:00:00","2024-07-20T00:00:00","2024-07-21T00:00:00","2024-07-22T00:00:00","2024-07-23T00:00:00","2024-07-24T00:00:00","2024-07-25T00:00:00","2024-07-26T00:00:00","2024-07-27T00:00:00","2024-07-28T00:00:00","2024-07-29T00:00:00","2024-07-30T00:00:00","2024-07-31T00:00:00","2024-08-01T00:00:00","2024-08-02T00:00:00","2024-08-03T00:00:00","2024-08-04T00:00:00","2024-08-05T00:00:00"," ...

# %% [markdown]
# Save model

# %%
import joblib

# Assuming `scaler` is your StandardScaler object
joblib.dump(scaler, 'scaler_maize.pkl')

#save model
model_RNN.save('best_maize_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
grouped_df0.to_excel("maize_avg_price.xlsx")
