# %% [markdown]
# Import modul and library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_excel("https://docs.google.com/spreadsheets/d/1-XSW9O8gU4gkDQ3OOGP57qeFMbFJyNny/export?format=xlsx")

# %%
df.head(5)
# Out:
#    Unnamed: 0  Sl no. District Name Market Name Commodity Variety   Grade  \
# 0           0   19389         Solan       Solan    Papaya   Other  Medium
# 1           1   23427        Amethi   Sultanpur    Papaya  Papaya  Medium
# 2           2    9794     North Goa      Mapusa    Papaya  Papaya  Medium
# 3           3   11250     Ghaziabad       Noida    Papaya  Papaya   Large
# 4           4   17581        Nashik       Nasik    Papaya   Other     FAQ
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                   2500.0                   3500.0
# 1                   2000.0                   2200.0
# 2                   1000.0                   1000.0
# 3                   1400.0                   1525.0
# 4                    800.0                   1700.0
#
#    Modal Price (Rs./Quintal) Price Date
# 0                     3000.0 2021-03-15
# 1                     2150.0 2021-03-15
# 2                     1000.0 2021-03-15
# 3                     1500.0 2021-03-15
# 4                     1300.0 2021-03-15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168003 entries, 0 to 168002
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Unnamed: 0                 168003 non-null  int64
#  1   Sl no.                     168003 non-null  int64
#  2   District Name              168003 non-null  object
#  3   Market Name                168003 non-null  object
#  4   Commodity                  168003 non-null  object
#  5   Variety                    168003 non-null  object
#  6   Grade                      168003 non-null  object
#  7   Min Price (Rs./Quintal)    168003 non-null  int64
#  8   Max Price (Rs./Quintal)    168003 non-null  int64
#  9   Modal Price (Rs./Quintal)  168003 non-null  int64
#  10  Price Date                 168003 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(5)
# memory usage: 14.1+ MB

# %% [markdown]
# dari semua varietas, grade, kelompokkan menjadi satu dan hitung rata-ratanya

# %%
grouped_df0 = df.groupby('Price Date')['Modal Price (Rs./Quintal)'].mean()

# %%
grouped_df0
# Out:
# Price Date
# 2021-03-15    1944.301587
# 2021-03-16    1967.880000
# 2021-03-17    1980.116279
# 2021-03-18    1983.073770
# 2021-03-19    2075.524194
#                  ...
# 2024-10-27    3003.505376
# 2024-10-28    3127.563707
# 2024-10-29    3165.663043
# 2024-10-30    3131.575630
# 2024-10-31    3058.771242
# Name: Modal Price (Rs./Quintal), Length: 1327, dtype: float64

# %%
type(grouped_df0)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Download grouped_df untuk digunakan pada saat deployment

# %%
#grouped_df.to_excel('grouped_prices_banana.xlsx', sheet_name='Prices')

# %% [markdown]
# Tinjau grafik harga dari harga komoditas tersebut untuk melihat trend secara kasat mata

# %%
# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(grouped_df0.index, grouped_df0, label='Modal Price', color='blue')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Define the split time
split1 = 2*180
split2 = 4*180

# Get the train set
time_train = grouped_df0.index[:split1]
x_train = grouped_df0[:split1]

# Get the validation set
time_valid = grouped_df0.index[split1:split2]
x_valid = grouped_df0[split1:split2]

# Get the test set
time_test = grouped_df0.index[split2:]
x_test = grouped_df0[split2:]

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the data and transform it
x_train_scaled = scaler.fit_transform(x_train.values.reshape(-1,1))
x_val_scaled = scaler.transform(x_valid.values.reshape(-1,1))
x_test_scaled = scaler.transform(x_test.values.reshape(-1,1))

# Convert the scaled data back into a DataFrame for easier reading
x_train_scaled_df = pd.DataFrame(x_train_scaled, columns=[x_train.name],index=x_train.index)
x_val_scaled_df = pd.DataFrame(x_val_scaled,  columns=[x_valid.name],index=x_valid.index)
x_test_scaled_df = pd.DataFrame(x_test_scaled,  columns=[x_test.name],index=x_test.index)

# %%
# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(time_valid, x_valid, label='Modal Price', color='blue')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# #Naive Forecast

# %%
series = np.array(grouped_df0)

# %%
series = scaler.transform(series.reshape(-1,1))

# %%
# Generate the naive forecast
split_time = split2
naive_forecast = series[split_time-1 :-1]

# Define time step
time_step = 100

# Print values
print(f'ground truth at time step {time_step}: {x_test_scaled[time_step]}')
print(f'prediction at time step {time_step + 1}: {naive_forecast[time_step +1]}')
# Out:
# ground truth at time step 100: [0.93253319]
# prediction at time step 101: [0.93253319]

# %%
len(x_test_scaled)
# Out:
# 607

# %%
len(naive_forecast)
# Out:
# 607

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
#results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index, naive_forecast, label='Predicted Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index, x_test_scaled, label='True Value', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
print("MSE:", mse(x_test_scaled, naive_forecast).numpy())
print("MAE:", mae(x_test_scaled, naive_forecast).numpy())

naive_mse = mse(x_test_scaled, naive_forecast).numpy()
naive_mae = mae(x_test_scaled, naive_forecast).numpy()
# Out:
# MSE: 0.41623145
# MAE: 0.4170772

# %%
# Parameters
window_size = 30
batch_size = 32

# %%
def windowed_dataset(series, window_size, batch_size):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    #dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size)

    # Optimize the dataset for training
    dataset = dataset.cache().prefetch(1)

    return dataset

# %%
# Generate the dataset windows
x_train_windowed = windowed_dataset(x_train_scaled, window_size, batch_size)
x_val_windowed = windowed_dataset(x_val_scaled, window_size, batch_size)

# %%
# Print properties of a single batch
for windows in x_train_windowed.take(1):
  print(f'data type: {type(windows)}')
  print(f'number of elements in the tuple: {len(windows)}')
  print(f'shape of first element: {windows[0].shape}')
  print(f'shape of second element: {windows[1].shape}')
# Out:
# data type: <class 'tuple'>
# number of elements in the tuple: 2
# shape of first element: (32, 30, 1)
# shape of second element: (32, 1)

# %% [markdown]
# #RNN

# %%
# Build the Model
model_tune = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.SimpleRNN(40, return_sequences=True),
    tf.keras.layers.SimpleRNN(40),
    tf.keras.layers.Dense(1),
])

# Print the model summary
model_tune.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 30, 40)              │           1,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_1 (SimpleRNN)             │ (None, 40)                  │           3,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              41 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,961 (19.38 KB)
#  Trainable params: 4,961 (19.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model_tune.fit(x_train_windowed, validation_data=x_val_windowed, epochs=200, callbacks=[lr_schedule])
# Out:
# Epoch 1/200
#      11/Unknown 3s 18ms/step - loss: 0.5148
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.5125 - val_loss: 0.3119 - learning_rate: 1.0000e-08
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5125 - val_loss: 0.3119 - learning_rate: 1.1220e-08
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5125 - val_loss: 0.3119 - learning_rate: 1.2589e-08
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5124 - val_loss: 0.3118 - learning_rate: 1.4125e-08
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5124 - val_loss: 0.3118 - learning_rate: 1.5849e-08
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5124 - val_loss: 0.3118 - learning_rate: 1.7783e-08
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5123 - val_loss: 0.3117 - learning_rate: 1.9953e-08
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.5123 - val_loss: 0.3117 - learning_rate: 2.2387e-08
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5122 - val_loss: 0.3117 - learning_rate: 2.5119e-08
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.5121 - val_loss: 0.3116 - learning_rate: 2.8184e-08
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.5121 - val_loss: 0.3116 - learning_rate: 3.1623e-08
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.5120 - val_loss: 0.3115 - learning_rate: 3.5481e-08
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.5119 - val_loss: 0.3114 - learning_rate: 3.9811e-08
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5118 - val_loss: 0.3114 - learning_rate: 4.4668e-08
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5117 - val_loss: 0.3113 - learning_rate: 5.0119e-08
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5115 - val_loss: 0.3112 - learning_rate: 5.6234e-08
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5114 - val_loss: 0.3111 - learning_rate: 6.3096e-08
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5112 - val_loss: 0.3110 - learning_rate: 7.0795e-08
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.5110 - val_loss: 0.3108 - learning_rate: 7.9433e-08
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.5108 - val_loss: 0.3107 - learning_rate: 8.9125e-08
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.5106 - val_loss: 0.3105 - learning_rate: 1.0000e-07
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5103 - val_loss: 0.3103 - learning_rate: 1.1220e-07
# Epoch 23/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.5100 - val_loss: 0.3101 - learning_rate: 1.2589e-07
# Epoch 24/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5097 - val_loss: 0.3099 - learning_rate: 1.4125e-07
# Epoch 25/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5093 - val_loss: 0.3096 - learning_rate: 1.5849e-07
# Epoch 26/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5089 - val_loss: 0.3093 - learning_rate: 1.7783e-07
# Epoch 27/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5084 - val_loss: 0.3090 - learning_rate: 1.9953e-07
# Epoch 28/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5079 - val_loss: 0.3086 - learning_rate: 2.2387e-07
# Epoch 29/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5073 - val_loss: 0.3082 - learning_rate: 2.5119e-07
# Epoch 30/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5066 - val_loss: 0.3077 - learning_rate: 2.8184e-07
# Epoch 31/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5059 - val_loss: 0.3072 - learning_rate: 3.1623e-07
# Epoch 32/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5050 - val_loss: 0.3066 - learning_rate: 3.5481e-07
# Epoch 33/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5041 - val_loss: 0.3060 - learning_rate: 3.9811e-07
# Epoch 34/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5030 - val_loss: 0.3052 - learning_rate: 4.4668e-07
# Epoch 35/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5019 - val_loss: 0.3044 - learning_rate: 5.0119e-07
# Epoch 36/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5005 - val_loss: 0.3035 - learning_rate: 5.6234e-07
# Epoch 37/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.4990 - val_loss: 0.3024 - learning_rate: 6.3096e-07
# Epoch 38/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.4974 - val_loss: 0.3013 - learning_rate: 7.0795e-07
# Epoch 39/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.4955 - val_loss: 0.2999 - learning_rate: 7.9433e-07
# Epoch 40/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.4934 - val_loss: 0.2985 - learning_rate: 8.9125e-07
# Epoch 41/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.4910 - val_loss: 0.2969 - learning_rate: 1.0000e-06
# Epoch 42/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4884 - val_loss: 0.2950 - learning_rate: 1.1220e-06
# Epoch 43/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4854 - val_loss: 0.2930 - learning_rate: 1.2589e-06
# Epoch 44/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4821 - val_loss: 0.2907 - learning_rate: 1.4125e-06
# Epoch 45/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4784 - val_loss: 0.2881 - learning_rate: 1.5849e-06
# Epoch 46/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4742 - val_loss: 0.2853 - learning_rate: 1.7783e-06
# Epoch 47/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4695 - val_loss: 0.2821 - learning_rate: 1.9953e-06
# Epoch 48/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4642 - val_loss: 0.2785 - learning_rate: 2.2387e-06
# Epoch 49/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4583 - val_loss: 0.2746 - learning_rate: 2.5119e-06
# Epoch 50/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4516 - val_loss: 0.2702 - learning_rate: 2.8184e-06
# Epoch 51/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4442 - val_loss: 0.2653 - learning_rate: 3.1623e-06
# Epoch 52/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4359 - val_loss: 0.2598 - learning_rate: 3.5481e-06
# Epoch 53/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4265 - val_loss: 0.2538 - learning_rate: 3.9811e-06
# Epoch 54/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4161 - val_loss: 0.2471 - learning_rate: 4.4668e-06
# Epoch 55/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4044 - val_loss: 0.2398 - learning_rate: 5.0119e-06
# Epoch 56/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3913 - val_loss: 0.2317 - learning_rate: 5.6234e-06
# Epoch 57/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3768 - val_loss: 0.2228 - learning_rate: 6.3096e-06
# Epoch 58/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3607 - val_loss: 0.2132 - learning_rate: 7.0795e-06
# Epoch 59/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3430 - val_loss: 0.2028 - learning_rate: 7.9433e-06
# Epoch 60/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3237 - val_loss: 0.1917 - learning_rate: 8.9125e-06
# Epoch 61/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3032 - val_loss: 0.1802 - learning_rate: 1.0000e-05
# Epoch 62/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2817 - val_loss: 0.1685 - learning_rate: 1.1220e-05
# Epoch 63/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2601 - val_loss: 0.1570 - learning_rate: 1.2589e-05
# Epoch 64/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2393 - val_loss: 0.1463 - learning_rate: 1.4125e-05
# Epoch 65/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2203 - val_loss: 0.1369 - learning_rate: 1.5849e-05
# Epoch 66/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2038 - val_loss: 0.1291 - learning_rate: 1.7783e-05
# Epoch 67/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1903 - val_loss: 0.1228 - learning_rate: 1.9953e-05
# Epoch 68/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1796 - val_loss: 0.1181 - learning_rate: 2.2387e-05
# Epoch 69/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1715 - val_loss: 0.1147 - learning_rate: 2.5119e-05
# Epoch 70/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1653 - val_loss: 0.1122 - learning_rate: 2.8184e-05
# Epoch 71/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.1608 - val_loss: 0.1105 - learning_rate: 3.1623e-05
# Epoch 72/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1574 - val_loss: 0.1093 - learning_rate: 3.5481e-05
# Epoch 73/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1548 - val_loss: 0.1084 - learning_rate: 3.9811e-05
# Epoch 74/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1528 - val_loss: 0.1077 - learning_rate: 4.4668e-05
# Epoch 75/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1511 - val_loss: 0.1070 - learning_rate: 5.0119e-05
# Epoch 76/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1496 - val_loss: 0.1064 - learning_rate: 5.6234e-05
# Epoch 77/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1482 - val_loss: 0.1057 - learning_rate: 6.3096e-05
# Epoch 78/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.1469 - val_loss: 0.1049 - learning_rate: 7.0795e-05
# Epoch 79/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.1455 - val_loss: 0.1041 - learning_rate: 7.9433e-05
# Epoch 80/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1440 - val_loss: 0.1031 - learning_rate: 8.9125e-05
# Epoch 81/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1424 - val_loss: 0.1021 - learning_rate: 1.0000e-04
# Epoch 82/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1407 - val_loss: 0.1010 - learning_rate: 1.1220e-04
# Epoch 83/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.1389 - val_loss: 0.0999 - learning_rate: 1.2589e-04
# Epoch 84/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.1370 - val_loss: 0.0987 - learning_rate: 1.4125e-04
# Epoch 85/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1350 - val_loss: 0.0974 - learning_rate: 1.5849e-04
# Epoch 86/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1328 - val_loss: 0.0960 - learning_rate: 1.7783e-04
# Epoch 87/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1306 - val_loss: 0.0946 - learning_rate: 1.9953e-04
# Epoch 88/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1282 - val_loss: 0.0932 - learning_rate: 2.2387e-04
# Epoch 89/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1257 - val_loss: 0.0916 - learning_rate: 2.5119e-04
# Epoch 90/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1231 - val_loss: 0.0901 - learning_rate: 2.8184e-04
# Epoch 91/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1204 - val_loss: 0.0884 - learning_rate: 3.1623e-04
# Epoch 92/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.1177 - val_loss: 0.0867 - learning_rate: 3.5481e-04
# Epoch 93/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.1149 - val_loss: 0.0849 - learning_rate: 3.9811e-04
# Epoch 94/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1121 - val_loss: 0.0830 - learning_rate: 4.4668e-04
# Epoch 95/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.1093 - val_loss: 0.0811 - learning_rate: 5.0119e-04
# Epoch 96/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.1066 - val_loss: 0.0792 - learning_rate: 5.6234e-04
# Epoch 97/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.1038 - val_loss: 0.0772 - learning_rate: 6.3096e-04
# Epoch 98/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1011 - val_loss: 0.0752 - learning_rate: 7.0795e-04
# Epoch 99/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0985 - val_loss: 0.0733 - learning_rate: 7.9433e-04
# Epoch 100/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0959 - val_loss: 0.0713 - learning_rate: 8.9125e-04
# Epoch 101/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0934 - val_loss: 0.0694 - learning_rate: 0.0010
# Epoch 102/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0910 - val_loss: 0.0675 - learning_rate: 0.0011
# Epoch 103/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0887 - val_loss: 0.0656 - learning_rate: 0.0013
# Epoch 104/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0865 - val_loss: 0.0638 - learning_rate: 0.0014
# Epoch 105/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0844 - val_loss: 0.0620 - learning_rate: 0.0016
# Epoch 106/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0823 - val_loss: 0.0602 - learning_rate: 0.0018
# Epoch 107/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0804 - val_loss: 0.0585 - learning_rate: 0.0020
# Epoch 108/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0786 - val_loss: 0.0569 - learning_rate: 0.0022
# Epoch 109/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0768 - val_loss: 0.0555 - learning_rate: 0.0025
# Epoch 110/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0751 - val_loss: 0.0542 - learning_rate: 0.0028
# Epoch 111/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0734 - val_loss: 0.0532 - learning_rate: 0.0032
# Epoch 112/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0719 - val_loss: 0.0523 - learning_rate: 0.0035
# Epoch 113/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0703 - val_loss: 0.0516 - learning_rate: 0.0040
# Epoch 114/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0688 - val_loss: 0.0511 - learning_rate: 0.0045
# Epoch 115/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0672 - val_loss: 0.0509 - learning_rate: 0.0050
# Epoch 116/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0657 - val_loss: 0.0507 - learning_rate: 0.0056
# Epoch 117/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0641 - val_loss: 0.0504 - learning_rate: 0.0063
# Epoch 118/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0621 - val_loss: 0.0504 - learning_rate: 0.0071
# Epoch 119/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0599 - val_loss: 0.0518 - learning_rate: 0.0079
# Epoch 120/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0579 - val_loss: 0.0539 - learning_rate: 0.0089
# Epoch 121/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0559 - val_loss: 0.0541 - learning_rate: 0.0100
# Epoch 122/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0530 - val_loss: 0.0514 - learning_rate: 0.0112
# Epoch 123/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0501 - val_loss: 0.0560 - learning_rate: 0.0126
# Epoch 124/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0510 - val_loss: 0.0827 - learning_rate: 0.0141
# Epoch 125/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0619 - val_loss: 0.1301 - learning_rate: 0.0158
# Epoch 126/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1160 - val_loss: 0.0687 - learning_rate: 0.0178
# Epoch 127/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0816 - val_loss: 0.1039 - learning_rate: 0.0200
# Epoch 128/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0828 - val_loss: 0.0824 - learning_rate: 0.0224
# Epoch 129/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0758 - val_loss: 0.1184 - learning_rate: 0.0251
# Epoch 130/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0979 - val_loss: 0.0792 - learning_rate: 0.0282
# Epoch 131/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0831 - val_loss: 0.1522 - learning_rate: 0.0316
# Epoch 132/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1405 - val_loss: 0.2183 - learning_rate: 0.0355
# Epoch 133/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1729 - val_loss: 0.3666 - learning_rate: 0.0398
# Epoch 134/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3214 - val_loss: 0.3775 - learning_rate: 0.0447
# Epoch 135/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3856 - val_loss: 0.3903 - learning_rate: 0.0501
# Epoch 136/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0935 - val_loss: 2.2366 - learning_rate: 0.0562
# Epoch 137/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.6295 - val_loss: 1.3605 - learning_rate: 0.0631
# Epoch 138/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3165 - val_loss: 0.3129 - learning_rate: 0.0708
# Epoch 139/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9796 - val_loss: 0.2381 - learning_rate: 0.0794
# Epoch 140/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.0458 - val_loss: 0.3028 - learning_rate: 0.0891
# Epoch 141/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.3762 - val_loss: 3.5139 - learning_rate: 0.1000
# Epoch 142/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.3574 - val_loss: 6.4611 - learning_rate: 0.1122
# Epoch 143/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 5.6316 - val_loss: 2.8932 - learning_rate: 0.1259
# Epoch 144/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.9612 - val_loss: 1.6935 - learning_rate: 0.1413
# Epoch 145/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.4528 - val_loss: 3.2113 - learning_rate: 0.1585
# Epoch 146/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 7.8317 - val_loss: 6.1845 - learning_rate: 0.1778
# Epoch 147/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6.2443 - val_loss: 8.5736 - learning_rate: 0.1995
# Epoch 148/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.9743 - val_loss: 7.2362 - learning_rate: 0.2239
# Epoch 149/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.9137 - val_loss: 3.3635 - learning_rate: 0.2512
# Epoch 150/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 8.5727 - val_loss: 34.8799 - learning_rate: 0.2818
# Epoch 151/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 29.2015 - val_loss: 36.1081 - learning_rate: 0.3162
# Epoch 152/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 19.4398 - val_loss: 20.8900 - learning_rate: 0.3548
# Epoch 153/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 21.7964 - val_loss: 25.9290 - learning_rate: 0.3981
# Epoch 154/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 26.4550 - val_loss: 22.2045 - learning_rate: 0.4467
# Epoch 155/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 19.5998 - val_loss: 28.9574 - learning_rate: 0.5012
# Epoch 156/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 57.0769 - val_loss: 113.5012 - learning_rate: 0.5623
# Epoch 157/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 98.5884 - val_loss: 26.6555 - learning_rate: 0.6310
# Epoch 158/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 35.3265 - val_loss: 5.5585 - learning_rate: 0.7079
# Epoch 159/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 14.4459 - val_loss: 7.4424 - learning_rate: 0.7943
# Epoch 160/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 12.5102 - val_loss: 11.4524 - learning_rate: 0.8913
# Epoch 161/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39.7806 - val_loss: 35.6015 - learning_rate: 1.0000
# Epoch 162/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 28.9317 - val_loss: 43.2011 - learning_rate: 1.1220
# Epoch 163/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 38.8693 - val_loss: 50.6823 - learning_rate: 1.2589
# Epoch 164/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 54.5979 - val_loss: 38.1864 - learning_rate: 1.4125
# Epoch 165/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 31.2318 - val_loss: 97.0329 - learning_rate: 1.5849
# Epoch 166/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 86.8989 - val_loss: 94.1129 - learning_rate: 1.7783
# Epoch 167/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 56.1093 - val_loss: 78.6801 - learning_rate: 1.9953
# Epoch 168/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 160.7776 - val_loss: 263.7137 - learning_rate: 2.2387
# Epoch 169/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 193.1051 - val_loss: 204.8697 - learning_rate: 2.5119
# Epoch 170/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 319.7548 - val_loss: 886.0997 - learning_rate: 2.8184
# Epoch 171/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 716.1490 - val_loss: 131.7255 - learning_rate: 3.1623
# Epoch 172/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 180.2971 - val_loss: 338.2585 - learning_rate: 3.5481
# Epoch 173/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 349.8349 - val_loss: 431.1902 - learning_rate: 3.9811
# Epoch 174/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 498.0403 - val_loss: 799.4308 - learning_rate: 4.4668
# Epoch 175/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 634.8903 - val_loss: 287.1377 - learning_rate: 5.0119
# Epoch 176/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 139.2204 - val_loss: 179.1644 - learning_rate: 5.6234
# Epoch 177/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 122.8265 - val_loss: 440.8523 - learning_rate: 6.3096
# Epoch 178/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 304.7682 - val_loss: 729.0507 - learning_rate: 7.0795
# Epoch 179/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 417.9508 - val_loss: 249.6611 - learning_rate: 7.9433
# Epoch 180/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 299.5921 - val_loss: 151.9141 - learning_rate: 8.9125
# Epoch 181/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 146.5094 - val_loss: 733.6988 - learning_rate: 10.0000
# Epoch 182/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 748.3796 - val_loss: 283.8068 - learning_rate: 11.2202
# Epoch 183/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 739.2877 - val_loss: 539.5137 - learning_rate: 12.5893
# Epoch 184/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 755.7956 - val_loss: 1779.6624 - learning_rate: 14.1254
# Epoch 185/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 926.1602 - val_loss: 155.7714 - learning_rate: 15.8489
# Epoch 186/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 646.3064 - val_loss: 661.8636 - learning_rate: 17.7828
# Epoch 187/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 946.5177 - val_loss: 368.2595 - learning_rate: 19.9526
# Epoch 188/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 600.4127 - val_loss: 381.0042 - learning_rate: 22.3872
# Epoch 189/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 387.9864 - val_loss: 1106.9680 - learning_rate: 25.1189
# Epoch 190/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 735.4711 - val_loss: 122.7627 - learning_rate: 28.1838
# Epoch 191/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 660.9328 - val_loss: 155.9134 - learning_rate: 31.6228
# Epoch 192/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 627.3439 - val_loss: 660.1595 - learning_rate: 35.4813
# Epoch 193/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2147.9604 - val_loss: 822.2922 - learning_rate: 39.8107
# Epoch 194/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 912.3090 - val_loss: 2822.5974 - learning_rate: 44.6684
# Epoch 195/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2407.7439 - val_loss: 2365.7876 - learning_rate: 50.1187
# Epoch 196/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2927.9001 - val_loss: 1873.7462 - learning_rate: 56.2341
# Epoch 197/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2692.2712 - val_loss: 4224.6973 - learning_rate: 63.0957
# Epoch 198/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6265.1016 - val_loss: 7166.8667 - learning_rate: 70.7946
# Epoch 199/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7454.3589 - val_loss: 17247.5020 - learning_rate: 79.4328
# Epoch 200/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 13143.6816 - val_loss: 16998.0996 - learning_rate: 89.1251

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(200) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the training loss in log scale
plt.semilogx(lrs, history.history["loss"], label="Training Loss")

# Plot the validation loss in log scale
plt.semilogx(lrs, history.history["val_loss"], label="Validation Loss")

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-1, 0, 1])

# Add a legend
plt.legend()

# Add labels and title
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Training and Validation Loss vs. Learning Rate")

# Show the plot
plt.show()

# %%
model_RNN=1

# %%
# Build the model
from tensorflow.keras.layers import Bidirectional, SimpleRNN, Dense
model_RNN = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size,1)),
    tf.keras.layers.SimpleRNN(50, return_sequences=True),
    tf.keras.layers.SimpleRNN(50),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1),
])

# Set the learning rate
learning_rate = 1e-3

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model_RNN.compile(loss=tf.keras.losses.Huber(),
                  optimizer=optimizer,
                  metrics=["mae"])

# EarlyStopping callback with patience
early_stopping = EarlyStopping(
    monitor="val_loss",     # Monitor validation loss
    patience=5,             # Wait 5 epochs for improvement
    mode="min",             # Stop when val_loss is minimized
    verbose=1               # Print when training stops early
)

# Train the model with EarlyStopping
history = model_RNN.fit(
    x_train_windowed,
    validation_data=x_val_windowed,
    epochs=100,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.6616 - mae: 1.0469 - val_loss: 0.2386 - val_mae: 0.5815
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1904 - mae: 0.5124 - val_loss: 0.1111 - val_mae: 0.3743
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1437 - mae: 0.4360 - val_loss: 0.1154 - val_mae: 0.3735
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1205 - mae: 0.3864 - val_loss: 0.0875 - val_mae: 0.3243
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.1105 - mae: 0.3706 - val_loss: 0.0885 - val_mae: 0.3245
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1009 - mae: 0.3475 - val_loss: 0.0745 - val_mae: 0.3034
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0987 - mae: 0.3506 - val_loss: 0.0787 - val_mae: 0.3050
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0930 - mae: 0.3323 - val_loss: 0.0685 - val_mae: 0.2922
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0912 - mae: 0.3351 - val_loss: 0.0700 - val_mae: 0.2880
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0870 - mae: 0.3199 - val_loss: 0.0639 - val_mae: 0.2821
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0852 - mae: 0.3226 - val_loss: 0.0636 - val_mae: 0.2762
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0819 - mae: 0.3107 - val_loss: 0.0599 - val_mae: 0.2733
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0803 - mae: 0.3118 - val_loss: 0.0592 - val_mae: 0.2675
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0775 - mae: 0.3031 - val_loss: 0.0568 - val_mae: 0.2658
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0758 - mae: 0.3024 - val_loss: 0.0563 - val_mae: 0.2612
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0734 - mae: 0.2959 - val_loss: 0.0546 - val_mae: 0.2599
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0719 - mae: 0.2939 - val_loss: 0.0543 - val_mae: 0.2562
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0700 - mae: 0.2895 - val_loss: 0.0531 - val_mae: 0.2552
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0687 - mae: 0.2871 - val_loss: 0.0529 - val_mae: 0.2526
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0673 - mae: 0.2842 - val_loss: 0.0520 - val_mae: 0.2520
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0663 - mae: 0.2818 - val_loss: 0.0519 - val_mae: 0.2501
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0652 - mae: 0.2797 - val_loss: 0.0512 - val_mae: 0.2493
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0644 - mae: 0.2774 - val_loss: 0.0511 - val_mae: 0.2482
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0636 - mae: 0.2762 - val_loss: 0.0505 - val_mae: 0.2474
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0629 - mae: 0.2737 - val_loss: 0.0505 - val_mae: 0.2467
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0623 - mae: 0.2730 - val_loss: 0.0499 - val_mae: 0.2457
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0617 - mae: 0.2707 - val_loss: 0.0500 - val_mae: 0.2455
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0612 - mae: 0.2702 - val_loss: 0.0495 - val_mae: 0.2444
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0606 - mae: 0.2681 - val_loss: 0.0495 - val_mae: 0.2447
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0602 - mae: 0.2676 - val_loss: 0.0491 - val_mae: 0.2437
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0597 - mae: 0.2657 - val_loss: 0.0492 - val_mae: 0.2441
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0593 - mae: 0.2652 - val_loss: 0.0489 - val_mae: 0.2433
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0588 - mae: 0.2636 - val_loss: 0.0489 - val_mae: 0.2437
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0585 - mae: 0.2630 - val_loss: 0.0486 - val_mae: 0.2430
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0580 - mae: 0.2615 - val_loss: 0.0487 - val_mae: 0.2434
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0577 - mae: 0.2610 - val_loss: 0.0485 - val_mae: 0.2429
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0573 - mae: 0.2596 - val_loss: 0.0485 - val_mae: 0.2431
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0569 - mae: 0.2591 - val_loss: 0.0484 - val_mae: 0.2428
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0566 - mae: 0.2578 - val_loss: 0.0483 - val_mae: 0.2430
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0562 - mae: 0.2573 - val_loss: 0.0483 - val_mae: 0.2428
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0559 - mae: 0.2562 - val_loss: 0.0482 - val_mae: 0.2430
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0556 - mae: 0.2556 - val_loss: 0.0482 - val_mae: 0.2430
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0552 - mae: 0.2546 - val_loss: 0.0482 - val_mae: 0.2431
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0549 - mae: 0.2539 - val_loss: 0.0482 - val_mae: 0.2432
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0546 - mae: 0.2531 - val_loss: 0.0482 - val_mae: 0.2433
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0543 - mae: 0.2522 - val_loss: 0.0482 - val_mae: 0.2434
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0540 - mae: 0.2515 - val_loss: 0.0482 - val_mae: 0.2435
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0537 - mae: 0.2507 - val_loss: 0.0482 - val_mae: 0.2436
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0534 - mae: 0.2500 - val_loss: 0.0482 - val_mae: 0.2437
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0531 - mae: 0.2491 - val_loss: 0.0483 - val_mae: 0.2439
# Epoch 50: early stopping

# %%
# Initialize a list
forecast = []

# Use the model to predict data points per window size
for time in range(len(grouped_df0)-split2-window_size):
  forecast.append(model_RNN.predict(x_test_scaled[time:time + window_size][np.newaxis], verbose=0))

# Slice the points that are aligned with the validation set
#forecast = forecast[split_time - window_size:]

# Compare number of elements in the predictions and the validation set
print(f'length of the forecast list: {len(forecast)}')
print(f'shape of the validation set: {x_test.shape}')
# Out:
# length of the forecast list: 577
# shape of the validation set: (607,)

# %%
# Preview shapes after using the conversion and squeeze methods
print(f'shape after converting to numpy array: {np.array(forecast).shape}')
print(f'shape after squeezing: {np.array(forecast).squeeze().shape}')

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()
# Out:
# shape after converting to numpy array: (577, 1, 1)
# shape after squeezing: (577,)

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)), label='True Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(results_reshaped), label='Predicted', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
true_values = x_test_scaled_df.values[30:].reshape(-1, 1)
predicted_values = results_reshaped

print("MSE:", mse(true_values, predicted_values).numpy())
print("MAE:", mae(true_values, predicted_values).numpy())

rnn_mse = mse(true_values, predicted_values).numpy()
rnn_mae = mae(true_values, predicted_values).numpy()
# Out:
# MSE: 0.40740207
# MAE: 0.4497181

# %% [markdown]
# #LSTM

# %%
# Build the Model
model_tune1 = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
])

# Print the model summary
model_tune1.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)        │ (None, 30, 64)              │           8,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 30, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 64)                  │          24,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 33,601 (131.25 KB)
#  Trainable params: 33,601 (131.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune1.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model_tune1.fit(x_train_windowed, validation_data=x_val_windowed, epochs=200, callbacks=[lr_schedule])
# Out:
# Epoch 1/200
#      11/Unknown 8s 51ms/step - loss: 0.5417
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 137ms/step - loss: 0.5376 - val_loss: 0.2667 - learning_rate: 1.0000e-08
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.5387 - val_loss: 0.2667 - learning_rate: 1.1220e-08
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.5373 - val_loss: 0.2667 - learning_rate: 1.2589e-08
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.5358 - val_loss: 0.2667 - learning_rate: 1.4125e-08
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.5368 - val_loss: 0.2667 - learning_rate: 1.5849e-08
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.5363 - val_loss: 0.2667 - learning_rate: 1.7783e-08
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.5370 - val_loss: 0.2667 - learning_rate: 1.9953e-08
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.5306 - val_loss: 0.2667 - learning_rate: 2.2387e-08
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.5378 - val_loss: 0.2667 - learning_rate: 2.5119e-08
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.5347 - val_loss: 0.2667 - learning_rate: 2.8184e-08
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.5369 - val_loss: 0.2667 - learning_rate: 3.1623e-08
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.5347 - val_loss: 0.2667 - learning_rate: 3.5481e-08
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.5376 - val_loss: 0.2667 - learning_rate: 3.9811e-08
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.5374 - val_loss: 0.2667 - learning_rate: 4.4668e-08
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.5351 - val_loss: 0.2667 - learning_rate: 5.0119e-08
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.5374 - val_loss: 0.2667 - learning_rate: 5.6234e-08
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.5368 - val_loss: 0.2667 - learning_rate: 6.3096e-08
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.5358 - val_loss: 0.2667 - learning_rate: 7.0795e-08
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.5366 - val_loss: 0.2667 - learning_rate: 7.9433e-08
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.5364 - val_loss: 0.2666 - learning_rate: 8.9125e-08
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.5343 - val_loss: 0.2666 - learning_rate: 1.0000e-07
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.5360 - val_loss: 0.2666 - learning_rate: 1.1220e-07
# Epoch 23/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.5355 - val_loss: 0.2666 - learning_rate: 1.2589e-07
# Epoch 24/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.5343 - val_loss: 0.2666 - learning_rate: 1.4125e-07
# Epoch 25/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.5374 - val_loss: 0.2666 - learning_rate: 1.5849e-07
# Epoch 26/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.5311 - val_loss: 0.2666 - learning_rate: 1.7783e-07
# Epoch 27/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.5354 - val_loss: 0.2665 - learning_rate: 1.9953e-07
# Epoch 28/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.5343 - val_loss: 0.2665 - learning_rate: 2.2387e-07
# Epoch 29/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.5362 - val_loss: 0.2665 - learning_rate: 2.5119e-07
# Epoch 30/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.5370 - val_loss: 0.2665 - learning_rate: 2.8184e-07
# Epoch 31/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.5344 - val_loss: 0.2664 - learning_rate: 3.1623e-07
# Epoch 32/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.5353 - val_loss: 0.2664 - learning_rate: 3.5481e-07
# Epoch 33/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.5353 - val_loss: 0.2663 - learning_rate: 3.9811e-07
# Epoch 34/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.5336 - val_loss: 0.2663 - learning_rate: 4.4668e-07
# Epoch 35/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.5351 - val_loss: 0.2662 - learning_rate: 5.0119e-07
# Epoch 36/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.5356 - val_loss: 0.2662 - learning_rate: 5.6234e-07
# Epoch 37/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.5354 - val_loss: 0.2661 - learning_rate: 6.3096e-07
# Epoch 38/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 0.5354 - val_loss: 0.2660 - learning_rate: 7.0795e-07
# Epoch 39/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.5372 - val_loss: 0.2660 - learning_rate: 7.9433e-07
# Epoch 40/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.5341 - val_loss: 0.2659 - learning_rate: 8.9125e-07
# Epoch 41/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.5323 - val_loss: 0.2658 - learning_rate: 1.0000e-06
# Epoch 42/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.5329 - val_loss: 0.2656 - learning_rate: 1.1220e-06
# Epoch 43/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.5333 - val_loss: 0.2655 - learning_rate: 1.2589e-06
# Epoch 44/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.5316 - val_loss: 0.2654 - learning_rate: 1.4125e-06
# Epoch 45/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.5339 - val_loss: 0.2652 - learning_rate: 1.5849e-06
# Epoch 46/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.5324 - val_loss: 0.2650 - learning_rate: 1.7783e-06
# Epoch 47/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.5338 - val_loss: 0.2648 - learning_rate: 1.9953e-06
# Epoch 48/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.5344 - val_loss: 0.2646 - learning_rate: 2.2387e-06
# Epoch 49/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.5322 - val_loss: 0.2643 - learning_rate: 2.5119e-06
# Epoch 50/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.5313 - val_loss: 0.2640 - learning_rate: 2.8184e-06
# Epoch 51/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.5306 - val_loss: 0.2637 - learning_rate: 3.1623e-06
# Epoch 52/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5292 - val_loss: 0.2633 - learning_rate: 3.5481e-06
# Epoch 53/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.5314 - val_loss: 0.2629 - learning_rate: 3.9811e-06
# Epoch 54/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.5268 - val_loss: 0.2624 - learning_rate: 4.4668e-06
# Epoch 55/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.5301 - val_loss: 0.2619 - learning_rate: 5.0119e-06
# Epoch 56/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.5285 - val_loss: 0.2613 - learning_rate: 5.6234e-06
# Epoch 57/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.5278 - val_loss: 0.2606 - learning_rate: 6.3096e-06
# Epoch 58/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.5263 - val_loss: 0.2599 - learning_rate: 7.0795e-06
# Epoch 59/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.5268 - val_loss: 0.2591 - learning_rate: 7.9433e-06
# Epoch 60/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.5208 - val_loss: 0.2581 - learning_rate: 8.9125e-06
# Epoch 61/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.5194 - val_loss: 0.2571 - learning_rate: 1.0000e-05
# Epoch 62/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.5190 - val_loss: 0.2560 - learning_rate: 1.1220e-05
# Epoch 63/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.5180 - val_loss: 0.2547 - learning_rate: 1.2589e-05
# Epoch 64/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.5165 - val_loss: 0.2532 - learning_rate: 1.4125e-05
# Epoch 65/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.5108 - val_loss: 0.2516 - learning_rate: 1.5849e-05
# Epoch 66/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.5100 - val_loss: 0.2498 - learning_rate: 1.7783e-05
# Epoch 67/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.5097 - val_loss: 0.2479 - learning_rate: 1.9953e-05
# Epoch 68/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.5053 - val_loss: 0.2456 - learning_rate: 2.2387e-05
# Epoch 69/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.5007 - val_loss: 0.2432 - learning_rate: 2.5119e-05
# Epoch 70/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.4951 - val_loss: 0.2404 - learning_rate: 2.8184e-05
# Epoch 71/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.4878 - val_loss: 0.2374 - learning_rate: 3.1623e-05
# Epoch 72/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.4859 - val_loss: 0.2340 - learning_rate: 3.5481e-05
# Epoch 73/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.4777 - val_loss: 0.2303 - learning_rate: 3.9811e-05
# Epoch 74/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.4731 - val_loss: 0.2261 - learning_rate: 4.4668e-05
# Epoch 75/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.4642 - val_loss: 0.2216 - learning_rate: 5.0119e-05
# Epoch 76/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.4598 - val_loss: 0.2166 - learning_rate: 5.6234e-05
# Epoch 77/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.4464 - val_loss: 0.2112 - learning_rate: 6.3096e-05
# Epoch 78/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.4378 - val_loss: 0.2053 - learning_rate: 7.0795e-05
# Epoch 79/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.4260 - val_loss: 0.1988 - learning_rate: 7.9433e-05
# Epoch 80/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.4132 - val_loss: 0.1919 - learning_rate: 8.9125e-05
# Epoch 81/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.4030 - val_loss: 0.1845 - learning_rate: 1.0000e-04
# Epoch 82/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.3880 - val_loss: 0.1766 - learning_rate: 1.1220e-04
# Epoch 83/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.3744 - val_loss: 0.1684 - learning_rate: 1.2589e-04
# Epoch 84/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.3558 - val_loss: 0.1598 - learning_rate: 1.4125e-04
# Epoch 85/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.3420 - val_loss: 0.1510 - learning_rate: 1.5849e-04
# Epoch 86/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.3232 - val_loss: 0.1423 - learning_rate: 1.7783e-04
# Epoch 87/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.3055 - val_loss: 0.1337 - learning_rate: 1.9953e-04
# Epoch 88/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.2879 - val_loss: 0.1254 - learning_rate: 2.2387e-04
# Epoch 89/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.2699 - val_loss: 0.1177 - learning_rate: 2.5119e-04
# Epoch 90/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.2536 - val_loss: 0.1108 - learning_rate: 2.8184e-04
# Epoch 91/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.2375 - val_loss: 0.1049 - learning_rate: 3.1623e-04
# Epoch 92/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.2258 - val_loss: 0.1001 - learning_rate: 3.5481e-04
# Epoch 93/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.2127 - val_loss: 0.0967 - learning_rate: 3.9811e-04
# Epoch 94/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.2023 - val_loss: 0.0947 - learning_rate: 4.4668e-04
# Epoch 95/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1930 - val_loss: 0.0940 - learning_rate: 5.0119e-04
# Epoch 96/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.1912 - val_loss: 0.0943 - learning_rate: 5.6234e-04
# Epoch 97/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.1857 - val_loss: 0.0953 - learning_rate: 6.3096e-04
# Epoch 98/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1847 - val_loss: 0.0966 - learning_rate: 7.0795e-04
# Epoch 99/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.1832 - val_loss: 0.0980 - learning_rate: 7.9433e-04
# Epoch 100/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1811 - val_loss: 0.0990 - learning_rate: 8.9125e-04
# Epoch 101/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1791 - val_loss: 0.0997 - learning_rate: 0.0010
# Epoch 102/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.1778 - val_loss: 0.0999 - learning_rate: 0.0011
# Epoch 103/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.1775 - val_loss: 0.0995 - learning_rate: 0.0013
# Epoch 104/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.1743 - val_loss: 0.0989 - learning_rate: 0.0014
# Epoch 105/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1696 - val_loss: 0.0981 - learning_rate: 0.0016
# Epoch 106/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.1661 - val_loss: 0.0972 - learning_rate: 0.0018
# Epoch 107/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.1619 - val_loss: 0.0964 - learning_rate: 0.0020
# Epoch 108/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1587 - val_loss: 0.0958 - learning_rate: 0.0022
# Epoch 109/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.1524 - val_loss: 0.0952 - learning_rate: 0.0025
# Epoch 110/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.1473 - val_loss: 0.0943 - learning_rate: 0.0028
# Epoch 111/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.1441 - val_loss: 0.0935 - learning_rate: 0.0032
# Epoch 112/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.1401 - val_loss: 0.0925 - learning_rate: 0.0035
# Epoch 113/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.1351 - val_loss: 0.0919 - learning_rate: 0.0040
# Epoch 114/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.1301 - val_loss: 0.0915 - learning_rate: 0.0045
# Epoch 115/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.1237 - val_loss: 0.0908 - learning_rate: 0.0050
# Epoch 116/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.1195 - val_loss: 0.0902 - learning_rate: 0.0056
# Epoch 117/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.1148 - val_loss: 0.0902 - learning_rate: 0.0063
# Epoch 118/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.1110 - val_loss: 0.0894 - learning_rate: 0.0071
# Epoch 119/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1060 - val_loss: 0.0889 - learning_rate: 0.0079
# Epoch 120/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1039 - val_loss: 0.0893 - learning_rate: 0.0089
# Epoch 121/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0994 - val_loss: 0.0888 - learning_rate: 0.0100
# Epoch 122/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0984 - val_loss: 0.0892 - learning_rate: 0.0112
# Epoch 123/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0952 - val_loss: 0.0894 - learning_rate: 0.0126
# Epoch 124/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0952 - val_loss: 0.0906 - learning_rate: 0.0141
# Epoch 125/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0928 - val_loss: 0.1015 - learning_rate: 0.0158
# Epoch 126/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.1097 - val_loss: 0.1583 - learning_rate: 0.0178
# Epoch 127/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.1369 - val_loss: 0.3864 - learning_rate: 0.0200
# Epoch 128/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 0.4112 - val_loss: 0.9886 - learning_rate: 0.0224
# Epoch 129/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.4590 - val_loss: 1.1784 - learning_rate: 0.0251
# Epoch 130/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.3854 - val_loss: 0.1447 - learning_rate: 0.0282
# Epoch 131/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.1770 - val_loss: 0.1463 - learning_rate: 0.0316
# Epoch 132/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.3849 - val_loss: 0.7192 - learning_rate: 0.0355
# Epoch 133/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.8729 - val_loss: 0.2777 - learning_rate: 0.0398
# Epoch 134/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.1727 - val_loss: 0.3507 - learning_rate: 0.0447
# Epoch 135/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.5219 - val_loss: 0.1958 - learning_rate: 0.0501
# Epoch 136/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.2468 - val_loss: 0.2821 - learning_rate: 0.0562
# Epoch 137/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.2002 - val_loss: 0.5547 - learning_rate: 0.0631
# Epoch 138/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.6660 - val_loss: 0.3867 - learning_rate: 0.0708
# Epoch 139/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.2472 - val_loss: 0.5102 - learning_rate: 0.0794
# Epoch 140/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.6012 - val_loss: 0.1112 - learning_rate: 0.0891
# Epoch 141/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 0.2967 - val_loss: 1.4260 - learning_rate: 0.1000
# Epoch 142/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.9699 - val_loss: 0.2415 - learning_rate: 0.1122
# Epoch 143/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.2745 - val_loss: 0.9956 - learning_rate: 0.1259
# Epoch 144/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.6125 - val_loss: 0.3975 - learning_rate: 0.1413
# Epoch 145/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.2470 - val_loss: 0.4753 - learning_rate: 0.1585
# Epoch 146/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.3357 - val_loss: 0.2411 - learning_rate: 0.1778
# Epoch 147/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.1871 - val_loss: 0.7596 - learning_rate: 0.1995
# Epoch 148/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.0097 - val_loss: 2.3851 - learning_rate: 0.2239
# Epoch 149/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 1.5559 - val_loss: 2.3456 - learning_rate: 0.2512
# Epoch 150/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 1.7480 - val_loss: 3.6781 - learning_rate: 0.2818
# Epoch 151/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 2.4563 - val_loss: 0.2742 - learning_rate: 0.3162
# Epoch 152/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.5979 - val_loss: 2.5432 - learning_rate: 0.3548
# Epoch 153/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 2.1658 - val_loss: 1.1308 - learning_rate: 0.3981
# Epoch 154/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.8610 - val_loss: 0.3651 - learning_rate: 0.4467
# Epoch 155/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.9703 - val_loss: 2.0187 - learning_rate: 0.5012
# Epoch 156/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 1.9532 - val_loss: 2.6528 - learning_rate: 0.5623
# Epoch 157/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2.8910 - val_loss: 0.8830 - learning_rate: 0.6310
# Epoch 158/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6431 - val_loss: 2.9993 - learning_rate: 0.7079
# Epoch 159/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 2.6035 - val_loss: 3.6850 - learning_rate: 0.7943
# Epoch 160/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 3.0696 - val_loss: 3.9130 - learning_rate: 0.8913
# Epoch 161/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 3.2362 - val_loss: 4.0050 - learning_rate: 1.0000
# Epoch 162/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 3.4950 - val_loss: 5.5332 - learning_rate: 1.1220
# Epoch 163/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 4.9812 - val_loss: 6.4547 - learning_rate: 1.2589
# Epoch 164/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 4.6238 - val_loss: 2.8360 - learning_rate: 1.4125
# Epoch 165/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 3.2421 - val_loss: 1.1173 - learning_rate: 1.5849
# Epoch 166/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.5015 - val_loss: 0.6128 - learning_rate: 1.7783
# Epoch 167/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.7041 - val_loss: 1.4113 - learning_rate: 1.9953
# Epoch 168/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2.1675 - val_loss: 0.6459 - learning_rate: 2.2387
# Epoch 169/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 1.6261 - val_loss: 0.2392 - learning_rate: 2.5119
# Epoch 170/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 1.4175 - val_loss: 3.8251 - learning_rate: 2.8184
# Epoch 171/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 3.9521 - val_loss: 2.1160 - learning_rate: 3.1623
# Epoch 172/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 1.9271 - val_loss: 0.2305 - learning_rate: 3.5481
# Epoch 173/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.7213 - val_loss: 1.3990 - learning_rate: 3.9811
# Epoch 174/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.0678 - val_loss: 0.7454 - learning_rate: 4.4668
# Epoch 175/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2.9237 - val_loss: 10.8767 - learning_rate: 5.0119
# Epoch 176/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 9.2824 - val_loss: 2.3590 - learning_rate: 5.6234
# Epoch 177/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 8.0383 - val_loss: 12.9625 - learning_rate: 6.3096
# Epoch 178/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 10.7989 - val_loss: 6.6394 - learning_rate: 7.0795
# Epoch 179/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 9.6442 - val_loss: 2.7118 - learning_rate: 7.9433
# Epoch 180/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 3.5438 - val_loss: 0.5046 - learning_rate: 8.9125
# Epoch 181/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 4.3127 - val_loss: 17.6060 - learning_rate: 10.0000
# Epoch 182/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 23.0776 - val_loss: 27.7065 - learning_rate: 11.2202
# Epoch 183/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 16.3679 - val_loss: 32.5108 - learning_rate: 12.5893
# Epoch 184/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 32.7022 - val_loss: 2.7428 - learning_rate: 14.1254
# Epoch 185/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 12.8962 - val_loss: 55.6465 - learning_rate: 15.8489
# Epoch 186/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 54.0108 - val_loss: 33.3093 - learning_rate: 17.7828
# Epoch 187/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 40.8728 - val_loss: 28.5523 - learning_rate: 19.9526
# Epoch 188/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 18.9447 - val_loss: 3.4296 - learning_rate: 22.3872
# Epoch 189/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 24.5205 - val_loss: 1.9856 - learning_rate: 25.1189
# Epoch 190/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 12.5549 - val_loss: 34.7268 - learning_rate: 28.1838
# Epoch 191/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 44.0893 - val_loss: 66.3428 - learning_rate: 31.6228
# Epoch 192/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 32.1180 - val_loss: 37.9184 - learning_rate: 35.4813
# Epoch 193/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 57.1036 - val_loss: 52.6260 - learning_rate: 39.8107
# Epoch 194/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 57.2787 - val_loss: 12.2436 - learning_rate: 44.6684
# Epoch 195/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 39.0109 - val_loss: 10.2567 - learning_rate: 50.1187
# Epoch 196/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 84.8699 - val_loss: 100.2348 - learning_rate: 56.2341
# Epoch 197/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 89.1217 - val_loss: 156.6255 - learning_rate: 63.0957
# Epoch 198/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 119.6295 - val_loss: 143.6135 - learning_rate: 70.7946
# Epoch 199/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 134.4429 - val_loss: 72.0966 - learning_rate: 79.4328
# Epoch 200/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 122.5218 - val_loss: 226.7695 - learning_rate: 89.1251

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(200) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the training loss in log scale
plt.semilogx(lrs, history.history["loss"], label="Training Loss")

# Plot the validation loss in log scale
plt.semilogx(lrs, history.history["val_loss"], label="Validation Loss")

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-1, 0, 1])

# Add a legend
plt.legend()

# Add labels and title
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Training and Validation Loss vs. Learning Rate")

# Show the plot
plt.show()

# %% [raw]
# model_LSTM=1

# %%
# Reset states generated by Keras
#tf.keras.backend.clear_session()

# Build the model
model_LSTM = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
])

# Set the learning rate
learning_rate = 1e-3

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model_LSTM.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# EarlyStopping callback with patience
early_stopping = EarlyStopping(
    monitor="val_loss",     # Monitor validation loss
    patience=5,             # Wait 5 epochs for improvement
    mode="min",             # Stop when val_loss is minimized
    verbose=1               # Print when training stops early
)

# Train the model with EarlyStopping
history = model_LSTM.fit(
    x_train_windowed,
    validation_data=x_val_windowed,
    epochs=100,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - loss: 0.4524 - mae: 0.8259 - val_loss: 0.1997 - val_mae: 0.5274
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.4040 - mae: 0.7684 - val_loss: 0.1717 - val_mae: 0.4842
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.3521 - mae: 0.7047 - val_loss: 0.1472 - val_mae: 0.4423
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.3078 - mae: 0.6471 - val_loss: 0.1283 - val_mae: 0.4078
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.2728 - mae: 0.6009 - val_loss: 0.1147 - val_mae: 0.3831
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.2461 - mae: 0.5647 - val_loss: 0.1058 - val_mae: 0.3703
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.2269 - mae: 0.5388 - val_loss: 0.1008 - val_mae: 0.3655
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.2140 - mae: 0.5216 - val_loss: 0.0988 - val_mae: 0.3637
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.2058 - mae: 0.5094 - val_loss: 0.0985 - val_mae: 0.3631
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.2006 - mae: 0.5019 - val_loss: 0.0989 - val_mae: 0.3629
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.1972 - mae: 0.4986 - val_loss: 0.0995 - val_mae: 0.3627
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.1945 - mae: 0.4970 - val_loss: 0.1000 - val_mae: 0.3622
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.1921 - mae: 0.4951 - val_loss: 0.1002 - val_mae: 0.3615
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1898 - mae: 0.4930 - val_loss: 0.1001 - val_mae: 0.3608
# Epoch 14: early stopping

# %%
type(x_test_scaled)
# Out:
# numpy.ndarray

# %%
# Initialize a list
forecast = []

# Use the model to predict data points per window size
for time in range(len(grouped_df0)-split2-window_size):
  forecast.append(model_LSTM.predict(x_test_scaled[time:time + window_size][np.newaxis], verbose=0))

# Slice the points that are aligned with the validation set
#forecast = forecast[split_time - window_size:]

# Compare number of elements in the predictions and the validation set
print(f'length of the forecast list: {len(forecast)}')
print(f'shape of the validation set: {x_test.shape}')
# Out:
# length of the forecast list: 577
# shape of the validation set: (607,)

# %%
# Preview shapes after using the conversion and squeeze methods
print(f'shape after converting to numpy array: {np.array(forecast).shape}')
print(f'shape after squeezing: {np.array(forecast).squeeze().shape}')

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()
# Out:
# shape after converting to numpy array: (577, 1, 1)
# shape after squeezing: (577,)

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)), label='True Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(results_reshaped), label='Predicted', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
import plotly.express as px
import pandas as pd

# Prepare a DataFrame for Plotly
plot_df = pd.DataFrame({
    'Price Date': x_test_scaled_df.index[30:],
    'True Value': scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)).flatten(),
    'Predicted': scaler.inverse_transform(results.reshape(-1, 1)).flatten()
})

# Create an interactive plot
fig = px.line(
    plot_df,
    x='Price Date',
    y=['True Value', 'Predicted'],
    labels={'value': 'Modal Price (Rs./Quintal)', 'variable': 'Legend'},
    title='Modal Price Over Time'
)

# Update layout for better aesthetics
fig.update_layout(
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9f72a721-9af6-4d0b-b804-a1230dbf249c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f72a721-9af6-4d0b-b804-a1230dbf249c")) {                    Plotly.newPlot(                        "9f72a721-9af6-4d0b-b804-a1230dbf249c",                        [{"hovertemplate":"Legend=True Value\u003cbr\u003ePrice Date=%{x}\u003cbr\u003eModal Price (Rs.\u002fQuintal)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True Value","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"True Value","showlegend":true,"x":["2023-04-04T00:00:00","2023-04-05T00:00:00","2023-04-06T00:00:00","2023-04-07T00:00:00","2023-04-08T00:00:00","2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-04-29T00:00:00","2023-04-30T00:00:00","2023-05-01T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-06T00:00:00","2023-05-07T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-13T00:00:00","2023-05-14T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-20T00:00:00","2023-05-21T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-27T00:00:00","2023-05-28T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-03T00:00:00","2023-06-04T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-10T00:00:00","2023-06-11T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-17T00:00:00","2023-06-18T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-24T00:00:00","2023-06-25T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-29T00:00:00","2023-06-30T00:00:00","2023-07-01T00:00:00","2023-07-02T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00","2023-08-18T00:00:00","2023-08-19T00:00:00","2023-08-20T00:00:00","2023-08-21T00:00:00","2023-08-22T00:00:00","2023-08-23T00:00:00"," ...

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
true_values = x_test_scaled_df.values[30:].reshape(-1, 1)
predicted_values = results_reshaped

print("MSE:", mse(true_values, predicted_values).numpy())
print("MAE:", mae(true_values, predicted_values).numpy())

lstm_mse = mse(true_values, predicted_values).numpy()
lstm_mae = mae(true_values, predicted_values).numpy()
# Out:
# MSE: 0.91132754
# MAE: 0.74357575

# %%
model_name = ['rnn', 'lstm']
lst_mse = [rnn_mse, lstm_mse]
lst_mae = [rnn_mae, lstm_mae]

for i in range(len(model_name)):
    print(f'MSE dari {model_name[i]} adalah {lst_mse[i]}')
    print(f'MAE dari {model_name[i]} adalah {lst_mae[i]}')

smallest_mse = np.argmin(lst_mse)
smallest_mae = np.argmin(lst_mae)

print(f'Model terbaik adalah {model_name[smallest_mse]} berdasarkan MSE terkecil')
print(f'Model terbaik adalah {model_name[smallest_mae]} berdasarkan MAE terkecil')
# Out:
# MSE dari rnn adalah 0.40740206837654114
# MAE dari rnn adalah 0.44971808791160583
# MSE dari lstm adalah 0.9113275408744812
# MAE dari lstm adalah 0.7435757517814636
# Model terbaik adalah rnn berdasarkan MSE terkecil
# Model terbaik adalah rnn berdasarkan MAE terkecil

# %% [markdown]
# Forecast

# %%
numpy_grouped_df=grouped_df0.to_numpy()

# %%
numpy_grouped_df_scaled = scaler.transform(numpy_grouped_df.reshape(-1,1))

# %%
days = 240

# %%
len(numpy_grouped_df)/240
# Out:
# 5.529166666666667

# %% [markdown]
# Plot ulang RNN

# %%
# Initialize lists for forecast
days = 240
forecast = []
result_forecast = numpy_grouped_df_scaled[-240:].tolist()  # Use the last 30 values as the starting point

# Flatten result_forecast if it contains nested lists
# Assuming numpy_grouped_df_scaled[-30:] is a 2D array or list of lists
result_forecast = [item[0] if isinstance(item, list) else float(item) for item in result_forecast]

# Forecast for 365 days
for _ in range(days):
    # Prepare input for the model
    input_data = np.array(result_forecast[-240:]).reshape(1, 240, 1)  # Reshape correctly

    # Predict and extract the scalar value
    prediksi = model_RNN.predict(input_data)[0][0]  # Extract scalar from prediction array

    # Append the prediction
    forecast.append(prediksi)  # For final forecast output
    result_forecast.append(prediksi)  # For generating subsequent predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %%
last_30_df = pd.DataFrame(numpy_grouped_df[-240:], columns=[grouped_df0.name],index=grouped_df0[-240:].index)

# %%
# Assume forecast contains the 30 predicted values
import pandas as pd

# Create a new datetime index for the next 30 days
new_dates = pd.date_range(start=last_30_df.index[-1] + pd.Timedelta(days=1), periods=days)

# Create a new DataFrame with the forecasted values
forecast_df = pd.DataFrame({'Modal Price (Rs./Quintal)': (scaler.inverse_transform(np.array(forecast).reshape(-1,1)).flatten())}, index=new_dates)

# Concatenate the existing DataFrame with the forecasted DataFrame
extended_df = pd.concat([last_30_df, forecast_df])

# Display the extended DataFrame
print(len(extended_df))
# Out:
# 480

# %%
import plotly.graph_objects as go
import pandas as pd

# Concatenate the actual and forecast DataFrames into a single DataFrame
combined_df = pd.concat([last_30_df, forecast_df])

# Create a figure
fig = go.Figure()


# Add a trace for the combined actual and forecast data (continuous line)
fig.add_trace(go.Scatter(
    x=extended_df.index,  # Use the combined index of both actual and forecast
    y=extended_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='Predicted Price',  # Label for combined data
    line=dict(color='red')  # Blue color for the forecasted data
))

# Add a trace for the last 30 actual values
fig.add_trace(go.Scatter(
    x=last_30_df.index,  # Only the index for the last 30 actual values
    y=last_30_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='True Price',  # Label for the last 30 actual data
    line=dict(color='blue')  # Green color for actual data
))


# Update layout for better aesthetics
fig.update_layout(
    title='Modal Price Over Time',
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8aecf7e8-71f0-4eca-a61e-b64f84ef5129" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8aecf7e8-71f0-4eca-a61e-b64f84ef5129")) {                    Plotly.newPlot(                        "8aecf7e8-71f0-4eca-a61e-b64f84ef5129",                        [{"line":{"color":"red"},"mode":"lines","name":"Predicted Price","x":["2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-24T00:00:00","2024-05-25T00:00:00","2024-05-26T00:00:00","2024-05-27T00:00:00","2024-05-28T00:00:00","2024-05-29T00:00:00","2024-05-30T00:00:00","2024-05-31T00:00:00","2024-06-01T00:00:00","2024-06-02T00:00:00","2024-06-03T00:00:00","2024-06-04T00:00:00","2024-06-05T00:00:00","2024-06-06T00:00:00","2024-06-07T00:00:00","2024-06-08T00:00:00","2024-06-09T00:00:00","2024-06-10T00:00:00","2024-06-11T00:00:00","2024-06-12T00:00:00","2024-06-13T00:00:00","2024-06-14T00:00:00","2024-06-15T00:00:00","2024-06-16T00:00:00","2024-06-17T00:00:00","2024-06-18T00:00:00","2024-06-19T00:00:00","2024-06-20T00:00:00","2024-06-21T00:00:00","2024-06-22T00:00:00","2024-06-23T00:00:00","2024-06-24T00:00:00","2024-06-25T00:00:00","2024-06-26T00:00:00","2024-06-27T00:00:00","2024-06-28T00:00:00","2024-06-29T00:00:00","2024-06-30T00:00:00","2024-07-01T00:00:00","2024-07-02T00:00:00","2024-07-03T00:00:00","2024-07-04T00:00:00","2024-07-05T00:00:00","2024-07-06T00:00:00","2024-07-07T00:00:00","2024-07-08T00:00:00","2024-07-09T00:00:00","2024-07-10T00:00:00","2024-07-11T00:00:00","2024-07-12T00:00:00","2024-07-13T00:00:00","2024-07-14T00:00:00","2024-07-15T00:00:00","2024-07-16T00:00:00","2024-07-17T00:00:00","2024-07-18T00:00:00","2024-07-19T00:00:00","2024-07-20T00:00:00","2024-07-21T00:00:00","2024-07-22T00:00:00","2024-07-23T00:00:00","2024-07-24T00:00:00","2024-07-25T00:00:00","2024-07-26T00:00:00","2024-07-27T00:00:00","2024-07-28T00:00:00","2024-07-29T00:00:00","2024-07-30T00:00:00","2024-07-31T00:00:00","2024-08-01T00:00:00","2024-08-02T00:00:00","2024-08-03T00:00:00","2024-08-04T00:00:00","2024-08-05T00:00:00"," ...

# %% [markdown]
# Plot ulang LSTM

# %%
# Initialize lists for forecast
days = 1*240
forecast = []
result_forecast = numpy_grouped_df_scaled[-1*240:].tolist()  # Use the last 30 values as the starting point

# Flatten result_forecast if it contains nested lists
# Assuming numpy_grouped_df_scaled[-30:] is a 2D array or list of lists
result_forecast = [item[0] if isinstance(item, list) else float(item) for item in result_forecast]

# Forecast for 365 days
for _ in range(days):
    # Prepare input for the model
    input_data = np.array(result_forecast[-1*240:]).reshape(1, 1*240, 1)  # Reshape correctly

    # Predict and extract the scalar value
    prediksi = model_LSTM.predict(input_data)[0][0]  # Extract scalar from prediction array

    # Append the prediction
    forecast.append(prediksi)  # For final forecast output
    result_forecast.append(prediksi)  # For generating subsequent predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
last_30_df = pd.DataFrame(numpy_grouped_df[-240:], columns=[grouped_df0.name],index=grouped_df0[-240:].index)

# %%
# Assume forecast contains the 30 predicted values
import pandas as pd

# Create a new datetime index for the next 30 days
new_dates = pd.date_range(start=last_30_df.index[-1] + pd.Timedelta(days=1), periods=days)

# Create a new DataFrame with the forecasted values
forecast_df = pd.DataFrame({'Modal Price (Rs./Quintal)': (scaler.inverse_transform(np.array(forecast).reshape(-1,1)).flatten())}, index=new_dates)

# Concatenate the existing DataFrame with the forecasted DataFrame
extended_df = pd.concat([last_30_df, forecast_df])

# Display the extended DataFrame
print(len(extended_df))
# Out:
# 480

# %%
import plotly.graph_objects as go
import pandas as pd

# Concatenate the actual and forecast DataFrames into a single DataFrame
combined_df = pd.concat([last_30_df, forecast_df])

# Create a figure
fig = go.Figure()


# Add a trace for the combined actual and forecast data (continuous line)
fig.add_trace(go.Scatter(
    x=extended_df.index,  # Use the combined index of both actual and forecast
    y=extended_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='Predicted Price',  # Label for combined data
    line=dict(color='red')  # Blue color for the forecasted data
))

# Add a trace for the last 30 actual values
fig.add_trace(go.Scatter(
    x=last_30_df.index,  # Only the index for the last 30 actual values
    y=last_30_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='True Price',  # Label for the last 30 actual data
    line=dict(color='blue')  # Green color for actual data
))


# Update layout for better aesthetics
fig.update_layout(
    title='Modal Price Over Time',
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4d37bc23-bcb8-414d-a0d3-351c8bba4bef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d37bc23-bcb8-414d-a0d3-351c8bba4bef")) {                    Plotly.newPlot(                        "4d37bc23-bcb8-414d-a0d3-351c8bba4bef",                        [{"line":{"color":"red"},"mode":"lines","name":"Predicted Price","x":["2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-24T00:00:00","2024-05-25T00:00:00","2024-05-26T00:00:00","2024-05-27T00:00:00","2024-05-28T00:00:00","2024-05-29T00:00:00","2024-05-30T00:00:00","2024-05-31T00:00:00","2024-06-01T00:00:00","2024-06-02T00:00:00","2024-06-03T00:00:00","2024-06-04T00:00:00","2024-06-05T00:00:00","2024-06-06T00:00:00","2024-06-07T00:00:00","2024-06-08T00:00:00","2024-06-09T00:00:00","2024-06-10T00:00:00","2024-06-11T00:00:00","2024-06-12T00:00:00","2024-06-13T00:00:00","2024-06-14T00:00:00","2024-06-15T00:00:00","2024-06-16T00:00:00","2024-06-17T00:00:00","2024-06-18T00:00:00","2024-06-19T00:00:00","2024-06-20T00:00:00","2024-06-21T00:00:00","2024-06-22T00:00:00","2024-06-23T00:00:00","2024-06-24T00:00:00","2024-06-25T00:00:00","2024-06-26T00:00:00","2024-06-27T00:00:00","2024-06-28T00:00:00","2024-06-29T00:00:00","2024-06-30T00:00:00","2024-07-01T00:00:00","2024-07-02T00:00:00","2024-07-03T00:00:00","2024-07-04T00:00:00","2024-07-05T00:00:00","2024-07-06T00:00:00","2024-07-07T00:00:00","2024-07-08T00:00:00","2024-07-09T00:00:00","2024-07-10T00:00:00","2024-07-11T00:00:00","2024-07-12T00:00:00","2024-07-13T00:00:00","2024-07-14T00:00:00","2024-07-15T00:00:00","2024-07-16T00:00:00","2024-07-17T00:00:00","2024-07-18T00:00:00","2024-07-19T00:00:00","2024-07-20T00:00:00","2024-07-21T00:00:00","2024-07-22T00:00:00","2024-07-23T00:00:00","2024-07-24T00:00:00","2024-07-25T00:00:00","2024-07-26T00:00:00","2024-07-27T00:00:00","2024-07-28T00:00:00","2024-07-29T00:00:00","2024-07-30T00:00:00","2024-07-31T00:00:00","2024-08-01T00:00:00","2024-08-02T00:00:00","2024-08-03T00:00:00","2024-08-04T00:00:00","2024-08-05T00:00:00"," ...

# %% [markdown]
# Save model

# %%
import joblib

# Assuming `scaler` is your StandardScaler object
joblib.dump(scaler, 'scaler_papaya.pkl')

#save model
model_RNN.save('best_papaya_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
grouped_df0.to_excel("papaya_avg_price.xlsx")
