# %% [markdown]
# Import modul and library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_excel("https://docs.google.com/spreadsheets/d/1-bkPYUbVfBoG1OlmosV_VQIrEtw9UQGY/export?format=xlsx")

# %%
df.head(5)
# Out:
#    Unnamed: 0  Sl no.    District Name          Market Name Commodity Variety  \
# 0           0    1753            Angul      Angul(Jarapada)      Rice   Other
# 1           1   22094       Darjeeling  Karsiyang(Matigara)      Rice   Other
# 2           2   47978          Mathura              Mathura      Rice     III
# 3           3   22221  Purba Bardhaman                Katwa      Rice    Fine
# 4           4   22259        Gorakhpur            Gorakhpur      Rice     III
#
#   Grade  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0   FAQ                     2500                   3000.0
# 1   FAQ                     4000                   5000.0
# 2   FAQ                     2480                   2650.0
# 3   FAQ                     2600                   2700.0
# 4   FAQ                     2350                   2410.0
#
#    Modal Price (Rs./Quintal) Price Date
# 0                     2800.0 2021-03-15
# 1                     4500.0 2021-03-15
# 2                     2590.0 2021-03-15
# 3                     2650.0 2021-03-15
# 4                     2375.0 2021-03-15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73479 entries, 0 to 73478
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 73479 non-null  int64
#  1   Sl no.                     73479 non-null  int64
#  2   District Name              73479 non-null  object
#  3   Market Name                73479 non-null  object
#  4   Commodity                  73479 non-null  object
#  5   Variety                    73479 non-null  object
#  6   Grade                      73479 non-null  object
#  7   Min Price (Rs./Quintal)    73479 non-null  int64
#  8   Max Price (Rs./Quintal)    73479 non-null  int64
#  9   Modal Price (Rs./Quintal)  73479 non-null  int64
#  10  Price Date                 73479 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(5)
# memory usage: 6.2+ MB

# %% [markdown]
# dari semua varietas, grade, kelompokkan menjadi satu dan hitung rata-ratanya

# %%
grouped_df0 = df.groupby('Price Date')['Modal Price (Rs./Quintal)'].mean()

# %%
grouped_df0
# Out:
# Price Date
# 2021-03-15    2757.200000
# 2021-03-16    2743.262222
# 2021-03-17    2646.611111
# 2021-03-18    2672.582938
# 2021-03-19    2635.665179
#                  ...
# 2024-10-27    3659.024590
# 2024-10-28    3627.813853
# 2024-10-29    3630.430622
# 2024-10-30    3618.846561
# 2024-10-31    3849.831461
# Name: Modal Price (Rs./Quintal), Length: 1174, dtype: float64

# %%
type(grouped_df0)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Download grouped_df untuk digunakan pada saat deployment

# %%
#grouped_df.to_excel('grouped_prices_banana.xlsx', sheet_name='Prices')

# %% [markdown]
# Tinjau grafik harga dari harga komoditas tersebut untuk melihat trend secara kasat mata

# %%
# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(grouped_df0.index, grouped_df0, label='Modal Price', color='blue')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Define the split time
split1 = round(0.6*len(grouped_df0))
split2 = round(0.8*len(grouped_df0))

# Get the train set
time_train = grouped_df0.index[:split1]
x_train = grouped_df0[:split1]

# Get the validation set
time_valid = grouped_df0.index[split1:split2]
x_valid = grouped_df0[split1:split2]

# Get the test set
time_test = grouped_df0.index[split2:]
x_test = grouped_df0[split2:]

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the data and transform it
x_train_scaled = scaler.fit_transform(x_train.values.reshape(-1,1))
x_val_scaled = scaler.transform(x_valid.values.reshape(-1,1))
x_test_scaled = scaler.transform(x_test.values.reshape(-1,1))

# Convert the scaled data back into a DataFrame for easier reading
x_train_scaled_df = pd.DataFrame(x_train_scaled, columns=[x_train.name],index=x_train.index)
x_val_scaled_df = pd.DataFrame(x_val_scaled,  columns=[x_valid.name],index=x_valid.index)
x_test_scaled_df = pd.DataFrame(x_test_scaled,  columns=[x_test.name],index=x_test.index)

# %%
# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(time_valid, x_valid, label='Modal Price', color='blue')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# #Naive Forecast

# %%
series = np.array(grouped_df0)

# %%
series = scaler.transform(series.reshape(-1,1))

# %%
# Generate the naive forecast
split_time = split2
naive_forecast = series[split_time-1 :-1]

# Define time step
time_step = 100

# Print values
print(f'ground truth at time step {time_step}: {x_test_scaled[time_step]}')
print(f'prediction at time step {time_step + 1}: {naive_forecast[time_step +1]}')
# Out:
# ground truth at time step 100: [4.85543109]
# prediction at time step 101: [4.85543109]

# %%
len(x_test_scaled)
# Out:
# 235

# %%
len(naive_forecast)
# Out:
# 235

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
#results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index, naive_forecast, label='Predicted Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index, x_test_scaled, label='True Value', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
print("MSE:", mse(x_test_scaled, naive_forecast).numpy())
print("MAE:", mae(x_test_scaled, naive_forecast).numpy())

naive_mse = mse(x_test_scaled, naive_forecast).numpy()
naive_mae = mae(x_test_scaled, naive_forecast).numpy()
# Out:
# MSE: 0.3183395
# MAE: 0.42958695

# %%
# Parameters
window_size = 30
batch_size = 32

# %%
def windowed_dataset(series, window_size, batch_size):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    #dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size)

    # Optimize the dataset for training
    dataset = dataset.cache().prefetch(1)

    return dataset

# %%
# Generate the dataset windows
x_train_windowed = windowed_dataset(x_train_scaled, window_size, batch_size)
x_val_windowed = windowed_dataset(x_val_scaled, window_size, batch_size)

# %%
# Print properties of a single batch
for windows in x_train_windowed.take(1):
  print(f'data type: {type(windows)}')
  print(f'number of elements in the tuple: {len(windows)}')
  print(f'shape of first element: {windows[0].shape}')
  print(f'shape of second element: {windows[1].shape}')
# Out:
# data type: <class 'tuple'>
# number of elements in the tuple: 2
# shape of first element: (32, 30, 1)
# shape of second element: (32, 1)

# %% [markdown]
# #RNN

# %%
# Build the Model
model_tune = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.SimpleRNN(40, return_sequences=True),
    tf.keras.layers.SimpleRNN(40),
    tf.keras.layers.Dense(1),
])

# Print the model summary
model_tune.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_17 (SimpleRNN)            │ (None, 30, 40)              │           1,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_18 (SimpleRNN)            │ (None, 40)                  │           3,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 1)                   │              41 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,961 (19.38 KB)
#  Trainable params: 4,961 (19.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model_tune.fit(x_train_windowed, validation_data=x_val_windowed, epochs=200, callbacks=[lr_schedule])
# Out:
# Epoch 1/200
#      19/Unknown 3s 17ms/step - loss: 0.1113
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.1166 - val_loss: 1.0898 - learning_rate: 1.0000e-08
# Epoch 2/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1166 - val_loss: 1.0898 - learning_rate: 1.1220e-08
# Epoch 3/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1166 - val_loss: 1.0898 - learning_rate: 1.2589e-08
# Epoch 4/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1166 - val_loss: 1.0897 - learning_rate: 1.4125e-08
# Epoch 5/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1166 - val_loss: 1.0897 - learning_rate: 1.5849e-08
# Epoch 6/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1166 - val_loss: 1.0897 - learning_rate: 1.7783e-08
# Epoch 7/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1166 - val_loss: 1.0896 - learning_rate: 1.9953e-08
# Epoch 8/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1166 - val_loss: 1.0896 - learning_rate: 2.2387e-08
# Epoch 9/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1166 - val_loss: 1.0895 - learning_rate: 2.5119e-08
# Epoch 10/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1166 - val_loss: 1.0895 - learning_rate: 2.8184e-08
# Epoch 11/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1166 - val_loss: 1.0894 - learning_rate: 3.1623e-08
# Epoch 12/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1166 - val_loss: 1.0893 - learning_rate: 3.5481e-08
# Epoch 13/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1166 - val_loss: 1.0892 - learning_rate: 3.9811e-08
# Epoch 14/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1165 - val_loss: 1.0891 - learning_rate: 4.4668e-08
# Epoch 15/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1165 - val_loss: 1.0890 - learning_rate: 5.0119e-08
# Epoch 16/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1165 - val_loss: 1.0889 - learning_rate: 5.6234e-08
# Epoch 17/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1165 - val_loss: 1.0887 - learning_rate: 6.3096e-08
# Epoch 18/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1165 - val_loss: 1.0886 - learning_rate: 7.0795e-08
# Epoch 19/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1165 - val_loss: 1.0884 - learning_rate: 7.9433e-08
# Epoch 20/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1164 - val_loss: 1.0882 - learning_rate: 8.9125e-08
# Epoch 21/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1164 - val_loss: 1.0879 - learning_rate: 1.0000e-07
# Epoch 22/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1164 - val_loss: 1.0877 - learning_rate: 1.1220e-07
# Epoch 23/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1164 - val_loss: 1.0874 - learning_rate: 1.2589e-07
# Epoch 24/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1163 - val_loss: 1.0871 - learning_rate: 1.4125e-07
# Epoch 25/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1163 - val_loss: 1.0867 - learning_rate: 1.5849e-07
# Epoch 26/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1162 - val_loss: 1.0863 - learning_rate: 1.7783e-07
# Epoch 27/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1162 - val_loss: 1.0858 - learning_rate: 1.9953e-07
# Epoch 28/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1161 - val_loss: 1.0853 - learning_rate: 2.2387e-07
# Epoch 29/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1161 - val_loss: 1.0848 - learning_rate: 2.5119e-07
# Epoch 30/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1160 - val_loss: 1.0842 - learning_rate: 2.8184e-07
# Epoch 31/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1159 - val_loss: 1.0835 - learning_rate: 3.1623e-07
# Epoch 32/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1158 - val_loss: 1.0827 - learning_rate: 3.5481e-07
# Epoch 33/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1157 - val_loss: 1.0818 - learning_rate: 3.9811e-07
# Epoch 34/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1156 - val_loss: 1.0809 - learning_rate: 4.4668e-07
# Epoch 35/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1155 - val_loss: 1.0798 - learning_rate: 5.0119e-07
# Epoch 36/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1154 - val_loss: 1.0787 - learning_rate: 5.6234e-07
# Epoch 37/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1153 - val_loss: 1.0774 - learning_rate: 6.3096e-07
# Epoch 38/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1152 - val_loss: 1.0760 - learning_rate: 7.0795e-07
# Epoch 39/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1150 - val_loss: 1.0745 - learning_rate: 7.9433e-07
# Epoch 40/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1149 - val_loss: 1.0728 - learning_rate: 8.9125e-07
# Epoch 41/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1147 - val_loss: 1.0710 - learning_rate: 1.0000e-06
# Epoch 42/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1145 - val_loss: 1.0690 - learning_rate: 1.1220e-06
# Epoch 43/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1143 - val_loss: 1.0668 - learning_rate: 1.2589e-06
# Epoch 44/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1142 - val_loss: 1.0645 - learning_rate: 1.4125e-06
# Epoch 45/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1140 - val_loss: 1.0620 - learning_rate: 1.5849e-06
# Epoch 46/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1138 - val_loss: 1.0593 - learning_rate: 1.7783e-06
# Epoch 47/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1136 - val_loss: 1.0565 - learning_rate: 1.9953e-06
# Epoch 48/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1134 - val_loss: 1.0534 - learning_rate: 2.2387e-06
# Epoch 49/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1132 - val_loss: 1.0503 - learning_rate: 2.5119e-06
# Epoch 50/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.1130 - val_loss: 1.0469 - learning_rate: 2.8184e-06
# Epoch 51/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1128 - val_loss: 1.0435 - learning_rate: 3.1623e-06
# Epoch 52/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1126 - val_loss: 1.0399 - learning_rate: 3.5481e-06
# Epoch 53/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1124 - val_loss: 1.0363 - learning_rate: 3.9811e-06
# Epoch 54/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1122 - val_loss: 1.0325 - learning_rate: 4.4668e-06
# Epoch 55/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1120 - val_loss: 1.0288 - learning_rate: 5.0119e-06
# Epoch 56/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1118 - val_loss: 1.0250 - learning_rate: 5.6234e-06
# Epoch 57/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1116 - val_loss: 1.0212 - learning_rate: 6.3096e-06
# Epoch 58/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1114 - val_loss: 1.0175 - learning_rate: 7.0795e-06
# Epoch 59/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1112 - val_loss: 1.0137 - learning_rate: 7.9433e-06
# Epoch 60/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1109 - val_loss: 1.0101 - learning_rate: 8.9125e-06
# Epoch 61/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1106 - val_loss: 1.0064 - learning_rate: 1.0000e-05
# Epoch 62/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1103 - val_loss: 1.0028 - learning_rate: 1.1220e-05
# Epoch 63/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1099 - val_loss: 0.9991 - learning_rate: 1.2589e-05
# Epoch 64/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1095 - val_loss: 0.9955 - learning_rate: 1.4125e-05
# Epoch 65/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1090 - val_loss: 0.9917 - learning_rate: 1.5849e-05
# Epoch 66/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1084 - val_loss: 0.9879 - learning_rate: 1.7783e-05
# Epoch 67/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1078 - val_loss: 0.9839 - learning_rate: 1.9953e-05
# Epoch 68/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1072 - val_loss: 0.9798 - learning_rate: 2.2387e-05
# Epoch 69/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1065 - val_loss: 0.9756 - learning_rate: 2.5119e-05
# Epoch 70/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1057 - val_loss: 0.9713 - learning_rate: 2.8184e-05
# Epoch 71/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1049 - val_loss: 0.9669 - learning_rate: 3.1623e-05
# Epoch 72/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1040 - val_loss: 0.9624 - learning_rate: 3.5481e-05
# Epoch 73/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1031 - val_loss: 0.9580 - learning_rate: 3.9811e-05
# Epoch 74/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1020 - val_loss: 0.9535 - learning_rate: 4.4668e-05
# Epoch 75/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.1010 - val_loss: 0.9491 - learning_rate: 5.0119e-05
# Epoch 76/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0998 - val_loss: 0.9449 - learning_rate: 5.6234e-05
# Epoch 77/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0986 - val_loss: 0.9408 - learning_rate: 6.3096e-05
# Epoch 78/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0974 - val_loss: 0.9369 - learning_rate: 7.0795e-05
# Epoch 79/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0960 - val_loss: 0.9331 - learning_rate: 7.9433e-05
# Epoch 80/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0947 - val_loss: 0.9295 - learning_rate: 8.9125e-05
# Epoch 81/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0933 - val_loss: 0.9262 - learning_rate: 1.0000e-04
# Epoch 82/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0919 - val_loss: 0.9229 - learning_rate: 1.1220e-04
# Epoch 83/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0905 - val_loss: 0.9199 - learning_rate: 1.2589e-04
# Epoch 84/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0891 - val_loss: 0.9171 - learning_rate: 1.4125e-04
# Epoch 85/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0877 - val_loss: 0.9144 - learning_rate: 1.5849e-04
# Epoch 86/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0864 - val_loss: 0.9118 - learning_rate: 1.7783e-04
# Epoch 87/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0851 - val_loss: 0.9093 - learning_rate: 1.9953e-04
# Epoch 88/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0839 - val_loss: 0.9069 - learning_rate: 2.2387e-04
# Epoch 89/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0828 - val_loss: 0.9046 - learning_rate: 2.5119e-04
# Epoch 90/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0818 - val_loss: 0.9022 - learning_rate: 2.8184e-04
# Epoch 91/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0808 - val_loss: 0.8997 - learning_rate: 3.1623e-04
# Epoch 92/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0800 - val_loss: 0.8972 - learning_rate: 3.5481e-04
# Epoch 93/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0791 - val_loss: 0.8946 - learning_rate: 3.9811e-04
# Epoch 94/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0784 - val_loss: 0.8919 - learning_rate: 4.4668e-04
# Epoch 95/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0777 - val_loss: 0.8892 - learning_rate: 5.0119e-04
# Epoch 96/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0772 - val_loss: 0.8863 - learning_rate: 5.6234e-04
# Epoch 97/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0766 - val_loss: 0.8833 - learning_rate: 6.3096e-04
# Epoch 98/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0762 - val_loss: 0.8800 - learning_rate: 7.0795e-04
# Epoch 99/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0759 - val_loss: 0.8763 - learning_rate: 7.9433e-04
# Epoch 100/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0758 - val_loss: 0.8718 - learning_rate: 8.9125e-04
# Epoch 101/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0759 - val_loss: 0.8666 - learning_rate: 0.0010
# Epoch 102/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0762 - val_loss: 0.8607 - learning_rate: 0.0011
# Epoch 103/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0769 - val_loss: 0.8538 - learning_rate: 0.0013
# Epoch 104/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0782 - val_loss: 0.8456 - learning_rate: 0.0014
# Epoch 105/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0803 - val_loss: 0.8357 - learning_rate: 0.0016
# Epoch 106/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0836 - val_loss: 0.8232 - learning_rate: 0.0018
# Epoch 107/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0884 - val_loss: 0.8082 - learning_rate: 0.0020
# Epoch 108/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0952 - val_loss: 0.7957 - learning_rate: 0.0022
# Epoch 109/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1070 - val_loss: 0.7958 - learning_rate: 0.0025
# Epoch 110/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1327 - val_loss: 0.8213 - learning_rate: 0.0028
# Epoch 111/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1728 - val_loss: 0.8770 - learning_rate: 0.0032
# Epoch 112/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1981 - val_loss: 0.7491 - learning_rate: 0.0035
# Epoch 113/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0890 - val_loss: 0.8630 - learning_rate: 0.0040
# Epoch 114/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1118 - val_loss: 0.8421 - learning_rate: 0.0045
# Epoch 115/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1274 - val_loss: 0.8455 - learning_rate: 0.0050
# Epoch 116/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2123 - val_loss: 0.8323 - learning_rate: 0.0056
# Epoch 117/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1646 - val_loss: 0.7418 - learning_rate: 0.0063
# Epoch 118/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1817 - val_loss: 1.1087 - learning_rate: 0.0071
# Epoch 119/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2471 - val_loss: 0.7153 - learning_rate: 0.0079
# Epoch 120/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1785 - val_loss: 0.8601 - learning_rate: 0.0089
# Epoch 121/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0907 - val_loss: 0.9361 - learning_rate: 0.0100
# Epoch 122/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1547 - val_loss: 0.8250 - learning_rate: 0.0112
# Epoch 123/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1534 - val_loss: 0.8097 - learning_rate: 0.0126
# Epoch 124/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0862 - val_loss: 0.9501 - learning_rate: 0.0141
# Epoch 125/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1342 - val_loss: 0.8141 - learning_rate: 0.0158
# Epoch 126/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2175 - val_loss: 0.8841 - learning_rate: 0.0178
# Epoch 127/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0785 - val_loss: 0.8899 - learning_rate: 0.0200
# Epoch 128/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0864 - val_loss: 0.8474 - learning_rate: 0.0224
# Epoch 129/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.1406 - val_loss: 0.8001 - learning_rate: 0.0251
# Epoch 130/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0864 - val_loss: 0.8500 - learning_rate: 0.0282
# Epoch 131/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.1290 - val_loss: 0.7561 - learning_rate: 0.0316
# Epoch 132/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1683 - val_loss: 0.6638 - learning_rate: 0.0355
# Epoch 133/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4412 - val_loss: 0.8732 - learning_rate: 0.0398
# Epoch 134/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3084 - val_loss: 2.0154 - learning_rate: 0.0447
# Epoch 135/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6001 - val_loss: 0.8945 - learning_rate: 0.0501
# Epoch 136/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5917 - val_loss: 0.7944 - learning_rate: 0.0562
# Epoch 137/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9118 - val_loss: 0.9784 - learning_rate: 0.0631
# Epoch 138/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5775 - val_loss: 0.9538 - learning_rate: 0.0708
# Epoch 139/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3445 - val_loss: 2.4731 - learning_rate: 0.0794
# Epoch 140/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2291 - val_loss: 1.2934 - learning_rate: 0.0891
# Epoch 141/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3828 - val_loss: 9.1915 - learning_rate: 0.1000
# Epoch 142/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.5826 - val_loss: 2.4220 - learning_rate: 0.1122
# Epoch 143/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.2828 - val_loss: 4.2516 - learning_rate: 0.1259
# Epoch 144/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.8525 - val_loss: 2.5852 - learning_rate: 0.1413
# Epoch 145/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.5447 - val_loss: 4.3591 - learning_rate: 0.1585
# Epoch 146/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9809 - val_loss: 2.5257 - learning_rate: 0.1778
# Epoch 147/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4456 - val_loss: 8.0833 - learning_rate: 0.1995
# Epoch 148/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.9561 - val_loss: 8.9208 - learning_rate: 0.2239
# Epoch 149/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.0451 - val_loss: 5.7584 - learning_rate: 0.2512
# Epoch 150/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.2010 - val_loss: 17.9522 - learning_rate: 0.2818
# Epoch 151/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 15.1721 - val_loss: 10.2228 - learning_rate: 0.3162
# Epoch 152/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 12.5180 - val_loss: 10.6551 - learning_rate: 0.3548
# Epoch 153/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 14.7912 - val_loss: 23.7909 - learning_rate: 0.3981
# Epoch 154/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 28.6607 - val_loss: 13.1588 - learning_rate: 0.4467
# Epoch 155/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 42.0950 - val_loss: 18.1125 - learning_rate: 0.5012
# Epoch 156/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 30.3273 - val_loss: 35.5094 - learning_rate: 0.5623
# Epoch 157/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 18.6395 - val_loss: 38.7632 - learning_rate: 0.6310
# Epoch 158/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 59.6860 - val_loss: 33.5124 - learning_rate: 0.7079
# Epoch 159/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 57.9049 - val_loss: 87.1905 - learning_rate: 0.7943
# Epoch 160/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 53.3180 - val_loss: 19.8358 - learning_rate: 0.8913
# Epoch 161/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 62.2814 - val_loss: 53.0160 - learning_rate: 1.0000
# Epoch 162/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 86.0899 - val_loss: 25.8944 - learning_rate: 1.1220
# Epoch 163/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 53.0373 - val_loss: 117.0336 - learning_rate: 1.2589
# Epoch 164/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 140.0060 - val_loss: 78.7734 - learning_rate: 1.4125
# Epoch 165/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 175.8690 - val_loss: 209.4711 - learning_rate: 1.5849
# Epoch 166/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 170.1649 - val_loss: 162.7538 - learning_rate: 1.7783
# Epoch 167/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 200.4315 - val_loss: 156.8032 - learning_rate: 1.9953
# Epoch 168/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 264.5538 - val_loss: 225.2092 - learning_rate: 2.2387
# Epoch 169/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 152.0952 - val_loss: 183.8628 - learning_rate: 2.5119
# Epoch 170/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 202.6412 - val_loss: 231.1661 - learning_rate: 2.8184
# Epoch 171/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 342.7841 - val_loss: 382.9684 - learning_rate: 3.1623
# Epoch 172/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 258.1332 - val_loss: 167.5944 - learning_rate: 3.5481
# Epoch 173/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 158.9851 - val_loss: 195.2170 - learning_rate: 3.9811
# Epoch 174/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 239.8388 - val_loss: 221.1263 - learning_rate: 4.4668
# Epoch 175/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 150.7065 - val_loss: 229.7939 - learning_rate: 5.0119
# Epoch 176/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 300.3430 - val_loss: 182.6057 - learning_rate: 5.6234
# Epoch 177/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 542.2963 - val_loss: 364.0348 - learning_rate: 6.3096
# Epoch 178/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 569.0865 - val_loss: 427.6386 - learning_rate: 7.0795
# Epoch 179/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 780.6578 - val_loss: 241.0911 - learning_rate: 7.9433
# Epoch 180/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1221.8627 - val_loss: 235.2876 - learning_rate: 8.9125
# Epoch 181/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 829.4495 - val_loss: 1086.2743 - learning_rate: 10.0000
# Epoch 182/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1893.0764 - val_loss: 738.9608 - learning_rate: 11.2202
# Epoch 183/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1030.6793 - val_loss: 158.8648 - learning_rate: 12.5893
# Epoch 184/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1035.1985 - val_loss: 1153.0698 - learning_rate: 14.1254
# Epoch 185/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2903.4675 - val_loss: 330.0225 - learning_rate: 15.8489
# Epoch 186/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1439.3326 - val_loss: 399.3642 - learning_rate: 17.7828
# Epoch 187/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 864.7727 - val_loss: 647.7993 - learning_rate: 19.9526
# Epoch 188/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1441.3250 - val_loss: 439.1071 - learning_rate: 22.3872
# Epoch 189/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 443.5375 - val_loss: 677.9255 - learning_rate: 25.1189
# Epoch 190/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1004.9512 - val_loss: 790.9263 - learning_rate: 28.1838
# Epoch 191/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2257.3774 - val_loss: 597.2210 - learning_rate: 31.6228
# Epoch 192/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4892.2407 - val_loss: 4693.8809 - learning_rate: 35.4813
# Epoch 193/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3174.7563 - val_loss: 1953.0939 - learning_rate: 39.8107
# Epoch 194/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3362.9504 - val_loss: 3196.5825 - learning_rate: 44.6684
# Epoch 195/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3878.6340 - val_loss: 2957.8840 - learning_rate: 50.1187
# Epoch 196/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2969.4434 - val_loss: 757.9982 - learning_rate: 56.2341
# Epoch 197/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3255.9482 - val_loss: 5755.7900 - learning_rate: 63.0957
# Epoch 198/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5847.6934 - val_loss: 1973.5598 - learning_rate: 70.7946
# Epoch 199/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 11196.8418 - val_loss: 12976.2363 - learning_rate: 79.4328
# Epoch 200/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9668.6182 - val_loss: 8037.7988 - learning_rate: 89.1251

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(200) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the training loss in log scale
plt.semilogx(lrs, history.history["loss"], label="Training Loss")

# Plot the validation loss in log scale
plt.semilogx(lrs, history.history["val_loss"], label="Validation Loss")

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-1, 0, 1])

# Add a legend
plt.legend()

# Add labels and title
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Training and Validation Loss vs. Learning Rate")

# Show the plot
plt.show()

# %%
model_RNN=1

# %%
# Build the model
from tensorflow.keras.layers import Bidirectional, SimpleRNN, Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential
model_RNN = Sequential([
    Bidirectional(SimpleRNN(128, return_sequences=True, input_shape=(window_size, 1))),  # First RNN layer
    Bidirectional(SimpleRNN(128, return_sequences=True)),  # Second RNN layer
    Bidirectional(SimpleRNN(128, return_sequences=False)),
    Dropout(0.2),
    Dense(64, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    Dense(1)  # Output layer for single prediction
])
# Compile the GRU model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001) # Added learning rate reduction
model_RNN.compile(optimizer='adam', loss=tf.keras.losses.Huber(), metrics=['mae'])

# Train the model with EarlyStopping
history = model_RNN.fit(
    x_train_windowed,
    validation_data=x_val_windowed,
    batch_size=32,
    epochs=100,
    callbacks=[early_stop, reduce_lr]  # Added early stopping and learning rate reduction
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 123ms/step - loss: 2.5098 - mae: 1.9309 - val_loss: 1.8339 - val_mae: 1.3006 - learning_rate: 0.0010
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - loss: 1.5214 - mae: 0.9343 - val_loss: 1.5695 - val_mae: 1.0546 - learning_rate: 0.0010
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 1.3669 - mae: 0.7862 - val_loss: 2.6237 - val_mae: 2.1628 - learning_rate: 0.0010
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 1.2126 - mae: 0.6273 - val_loss: 2.9351 - val_mae: 2.4916 - learning_rate: 0.0010
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 1.3111 - mae: 0.7868 - val_loss: 1.4460 - val_mae: 0.9194 - learning_rate: 0.0010
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 1.1387 - mae: 0.5959 - val_loss: 1.6311 - val_mae: 1.1320 - learning_rate: 0.0010
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 1.0763 - mae: 0.5267 - val_loss: 2.1053 - val_mae: 1.6992 - learning_rate: 0.0010
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 1.2603 - mae: 0.7983 - val_loss: 1.5904 - val_mae: 1.1838 - learning_rate: 0.0010
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 1.1210 - mae: 0.6649 - val_loss: 1.3225 - val_mae: 0.9065 - learning_rate: 0.0010
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 1.0156 - mae: 0.5297 - val_loss: 1.4217 - val_mae: 1.0272 - learning_rate: 0.0010
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 1.2135 - mae: 0.8377 - val_loss: 1.5737 - val_mae: 1.2182 - learning_rate: 0.0010
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.9317 - mae: 0.4816 - val_loss: 1.5670 - val_mae: 1.2135 - learning_rate: 0.0010
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - loss: 0.9268 - mae: 0.5292 - val_loss: 2.0098 - val_mae: 1.7495 - learning_rate: 0.0010
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.9753 - mae: 0.5943 - val_loss: 1.5547 - val_mae: 1.2511 - learning_rate: 0.0010
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.8047 - mae: 0.3754 - val_loss: 1.8241 - val_mae: 1.5862 - learning_rate: 0.0010
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.9045 - mae: 0.5354 - val_loss: 1.3426 - val_mae: 1.0366 - learning_rate: 0.0010
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.7770 - mae: 0.3941 - val_loss: 1.5304 - val_mae: 1.2494 - learning_rate: 0.0010
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.7956 - mae: 0.4458 - val_loss: 1.6770 - val_mae: 1.4600 - learning_rate: 0.0010
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.7792 - mae: 0.4549 - val_loss: 1.7147 - val_mae: 1.5277 - learning_rate: 0.0010

# %%
# Initialize a list
forecast = []

# Use the model to predict data points per window size
for time in range(len(grouped_df0)-split2-window_size):
  forecast.append(model_RNN.predict(x_test_scaled[time:time + window_size][np.newaxis], verbose=0))

# Slice the points that are aligned with the validation set
#forecast = forecast[split_time - window_size:]

# Compare number of elements in the predictions and the validation set
print(f'length of the forecast list: {len(forecast)}')
print(f'shape of the validation set: {x_test.shape}')
# Out:
# length of the forecast list: 205
# shape of the validation set: (235,)

# %%
# Preview shapes after using the conversion and squeeze methods
print(f'shape after converting to numpy array: {np.array(forecast).shape}')
print(f'shape after squeezing: {np.array(forecast).squeeze().shape}')

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()
# Out:
# shape after converting to numpy array: (205, 1, 1)
# shape after squeezing: (205,)

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)), label='True Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(results_reshaped), label='Predicted', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
true_values = x_test_scaled_df.values[30:].reshape(-1, 1)
predicted_values = results_reshaped

print("MSE:", mse(true_values, predicted_values).numpy())
print("MAE:", mae(true_values, predicted_values).numpy())

rnn_mse = mse(true_values, predicted_values).numpy()
rnn_mae = mae(true_values, predicted_values).numpy()
# Out:
# MSE: 5.528432
# MAE: 2.2690234

# %%
mape = np.mean(np.abs((true_values - predicted_values) / true_values)) * 100
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")

# 2. Calculate Baseline MAE
# Use the mean of the actual values as a naive prediction
baseline_predictions = np.mean(true_values)
baseline_mae = np.mean(np.abs(predicted_values - baseline_predictions))
print(f"Baseline MAE: {baseline_mae:.2f}")

# Compare your model's MAE with the baseline
model_mae = np.mean(np.abs(true_values - predicted_values))
improvement = ((baseline_mae - model_mae) / baseline_mae) * 100
print(f"Your model improves over the baseline by: {improvement:.2f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 41.05%
# Baseline MAE: 2.27
# Your model improves over the baseline by: 0.00%

# %%
# Plot the training and validation loss
plt.figure(figsize=(10, 6))

# Extract loss and validation loss from the history object
loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot loss
plt.plot(loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Validation Loss', color='orange')

# Add labels, title, and legend
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# #LSTM

# %%
# Build the Model
model_tune1 = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
])

# Print the model summary
model_tune1.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)        │ (None, 30, 64)              │           8,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 30, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 64)                  │          24,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 33,601 (131.25 KB)
#  Trainable params: 33,601 (131.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune1.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model_tune1.fit(x_train_windowed, validation_data=x_val_windowed, epochs=200, callbacks=[lr_schedule])
# Out:
# Epoch 1/200
#      11/Unknown 6s 41ms/step - loss: 0.5532
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - loss: 0.5430 - val_loss: 0.3562 - learning_rate: 1.0000e-08
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5422 - val_loss: 0.3562 - learning_rate: 1.1220e-08
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5417 - val_loss: 0.3562 - learning_rate: 1.2589e-08
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.5420 - val_loss: 0.3562 - learning_rate: 1.4125e-08
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.5427 - val_loss: 0.3562 - learning_rate: 1.5849e-08
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.5416 - val_loss: 0.3562 - learning_rate: 1.7783e-08
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.5423 - val_loss: 0.3562 - learning_rate: 1.9953e-08
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.5433 - val_loss: 0.3562 - learning_rate: 2.2387e-08
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.5427 - val_loss: 0.3562 - learning_rate: 2.5119e-08
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.5427 - val_loss: 0.3562 - learning_rate: 2.8184e-08
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.5429 - val_loss: 0.3562 - learning_rate: 3.1623e-08
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5435 - val_loss: 0.3562 - learning_rate: 3.5481e-08
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 168ms/step - loss: 0.5422 - val_loss: 0.3562 - learning_rate: 3.9811e-08
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - loss: 0.5417 - val_loss: 0.3562 - learning_rate: 4.4668e-08
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - loss: 0.5422 - val_loss: 0.3562 - learning_rate: 5.0119e-08
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - loss: 0.5431 - val_loss: 0.3562 - learning_rate: 5.6234e-08
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - loss: 0.5425 - val_loss: 0.3562 - learning_rate: 6.3096e-08
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.5420 - val_loss: 0.3562 - learning_rate: 7.0795e-08
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.5423 - val_loss: 0.3562 - learning_rate: 7.9433e-08
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.5435 - val_loss: 0.3562 - learning_rate: 8.9125e-08
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.5434 - val_loss: 0.3562 - learning_rate: 1.0000e-07
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5404 - val_loss: 0.3562 - learning_rate: 1.1220e-07
# Epoch 23/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.5430 - val_loss: 0.3562 - learning_rate: 1.2589e-07
# Epoch 24/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5433 - val_loss: 0.3561 - learning_rate: 1.4125e-07
# Epoch 25/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.5418 - val_loss: 0.3561 - learning_rate: 1.5849e-07
# Epoch 26/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.5414 - val_loss: 0.3561 - learning_rate: 1.7783e-07
# Epoch 27/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.5441 - val_loss: 0.3561 - learning_rate: 1.9953e-07
# Epoch 28/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.5421 - val_loss: 0.3561 - learning_rate: 2.2387e-07
# Epoch 29/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.5428 - val_loss: 0.3561 - learning_rate: 2.5119e-07
# Epoch 30/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5425 - val_loss: 0.3561 - learning_rate: 2.8184e-07
# Epoch 31/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.5420 - val_loss: 0.3561 - learning_rate: 3.1623e-07
# Epoch 32/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.5428 - val_loss: 0.3561 - learning_rate: 3.5481e-07
# Epoch 33/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5423 - val_loss: 0.3560 - learning_rate: 3.9811e-07
# Epoch 34/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.5430 - val_loss: 0.3560 - learning_rate: 4.4668e-07
# Epoch 35/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.5435 - val_loss: 0.3560 - learning_rate: 5.0119e-07
# Epoch 36/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.5430 - val_loss: 0.3560 - learning_rate: 5.6234e-07
# Epoch 37/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.5447 - val_loss: 0.3559 - learning_rate: 6.3096e-07
# Epoch 38/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.5414 - val_loss: 0.3559 - learning_rate: 7.0795e-07
# Epoch 39/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.5422 - val_loss: 0.3559 - learning_rate: 7.9433e-07
# Epoch 40/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.5409 - val_loss: 0.3558 - learning_rate: 8.9125e-07
# Epoch 41/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.5438 - val_loss: 0.3558 - learning_rate: 1.0000e-06
# Epoch 42/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.5439 - val_loss: 0.3557 - learning_rate: 1.1220e-06
# Epoch 43/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.5422 - val_loss: 0.3557 - learning_rate: 1.2589e-06
# Epoch 44/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.5423 - val_loss: 0.3556 - learning_rate: 1.4125e-06
# Epoch 45/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.5428 - val_loss: 0.3555 - learning_rate: 1.5849e-06
# Epoch 46/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.5420 - val_loss: 0.3554 - learning_rate: 1.7783e-06
# Epoch 47/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.5403 - val_loss: 0.3553 - learning_rate: 1.9953e-06
# Epoch 48/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.5433 - val_loss: 0.3552 - learning_rate: 2.2387e-06
# Epoch 49/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.5433 - val_loss: 0.3551 - learning_rate: 2.5119e-06
# Epoch 50/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.5425 - val_loss: 0.3550 - learning_rate: 2.8184e-06
# Epoch 51/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.5415 - val_loss: 0.3548 - learning_rate: 3.1623e-06
# Epoch 52/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.5411 - val_loss: 0.3547 - learning_rate: 3.5481e-06
# Epoch 53/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.5411 - val_loss: 0.3545 - learning_rate: 3.9811e-06
# Epoch 54/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.5408 - val_loss: 0.3543 - learning_rate: 4.4668e-06
# Epoch 55/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.5417 - val_loss: 0.3540 - learning_rate: 5.0119e-06
# Epoch 56/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.5385 - val_loss: 0.3538 - learning_rate: 5.6234e-06
# Epoch 57/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.5393 - val_loss: 0.3535 - learning_rate: 6.3096e-06
# Epoch 58/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.5400 - val_loss: 0.3532 - learning_rate: 7.0795e-06
# Epoch 59/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.5392 - val_loss: 0.3528 - learning_rate: 7.9433e-06
# Epoch 60/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.5398 - val_loss: 0.3524 - learning_rate: 8.9125e-06
# Epoch 61/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.5386 - val_loss: 0.3519 - learning_rate: 1.0000e-05
# Epoch 62/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.5364 - val_loss: 0.3514 - learning_rate: 1.1220e-05
# Epoch 63/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.5371 - val_loss: 0.3508 - learning_rate: 1.2589e-05
# Epoch 64/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.5363 - val_loss: 0.3501 - learning_rate: 1.4125e-05
# Epoch 65/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.5362 - val_loss: 0.3494 - learning_rate: 1.5849e-05
# Epoch 66/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.5343 - val_loss: 0.3486 - learning_rate: 1.7783e-05
# Epoch 67/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5340 - val_loss: 0.3477 - learning_rate: 1.9953e-05
# Epoch 68/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.5353 - val_loss: 0.3467 - learning_rate: 2.2387e-05
# Epoch 69/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.5331 - val_loss: 0.3455 - learning_rate: 2.5119e-05
# Epoch 70/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.5310 - val_loss: 0.3442 - learning_rate: 2.8184e-05
# Epoch 71/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.5302 - val_loss: 0.3428 - learning_rate: 3.1623e-05
# Epoch 72/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.5268 - val_loss: 0.3412 - learning_rate: 3.5481e-05
# Epoch 73/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5258 - val_loss: 0.3394 - learning_rate: 3.9811e-05
# Epoch 74/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.5256 - val_loss: 0.3374 - learning_rate: 4.4668e-05
# Epoch 75/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.5235 - val_loss: 0.3352 - learning_rate: 5.0119e-05
# Epoch 76/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5200 - val_loss: 0.3327 - learning_rate: 5.6234e-05
# Epoch 77/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.5165 - val_loss: 0.3300 - learning_rate: 6.3096e-05
# Epoch 78/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.5121 - val_loss: 0.3269 - learning_rate: 7.0795e-05
# Epoch 79/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5112 - val_loss: 0.3236 - learning_rate: 7.9433e-05
# Epoch 80/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.5062 - val_loss: 0.3198 - learning_rate: 8.9125e-05
# Epoch 81/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5018 - val_loss: 0.3156 - learning_rate: 1.0000e-04
# Epoch 82/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4970 - val_loss: 0.3110 - learning_rate: 1.1220e-04
# Epoch 83/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4916 - val_loss: 0.3059 - learning_rate: 1.2589e-04
# Epoch 84/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.4867 - val_loss: 0.3003 - learning_rate: 1.4125e-04
# Epoch 85/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.4778 - val_loss: 0.2942 - learning_rate: 1.5849e-04
# Epoch 86/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4717 - val_loss: 0.2874 - learning_rate: 1.7783e-04
# Epoch 87/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4639 - val_loss: 0.2800 - learning_rate: 1.9953e-04
# Epoch 88/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.4551 - val_loss: 0.2719 - learning_rate: 2.2387e-04
# Epoch 89/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4460 - val_loss: 0.2630 - learning_rate: 2.5119e-04
# Epoch 90/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4355 - val_loss: 0.2534 - learning_rate: 2.8184e-04
# Epoch 91/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.4234 - val_loss: 0.2430 - learning_rate: 3.1623e-04
# Epoch 92/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4111 - val_loss: 0.2318 - learning_rate: 3.5481e-04
# Epoch 93/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3967 - val_loss: 0.2198 - learning_rate: 3.9811e-04
# Epoch 94/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.3823 - val_loss: 0.2070 - learning_rate: 4.4668e-04
# Epoch 95/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3640 - val_loss: 0.1935 - learning_rate: 5.0119e-04
# Epoch 96/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.3441 - val_loss: 0.1794 - learning_rate: 5.6234e-04
# Epoch 97/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.3234 - val_loss: 0.1650 - learning_rate: 6.3096e-04
# Epoch 98/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3070 - val_loss: 0.1508 - learning_rate: 7.0795e-04
# Epoch 99/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2851 - val_loss: 0.1374 - learning_rate: 7.9433e-04
# Epoch 100/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2629 - val_loss: 0.1253 - learning_rate: 8.9125e-04
# Epoch 101/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.2417 - val_loss: 0.1151 - learning_rate: 0.0010
# Epoch 102/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2261 - val_loss: 0.1073 - learning_rate: 0.0011
# Epoch 103/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2089 - val_loss: 0.1018 - learning_rate: 0.0013
# Epoch 104/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1929 - val_loss: 0.0981 - learning_rate: 0.0014
# Epoch 105/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1861 - val_loss: 0.0954 - learning_rate: 0.0016
# Epoch 106/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.1803 - val_loss: 0.0933 - learning_rate: 0.0018
# Epoch 107/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.1730 - val_loss: 0.0911 - learning_rate: 0.0020
# Epoch 108/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.1664 - val_loss: 0.0887 - learning_rate: 0.0022
# Epoch 109/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.1618 - val_loss: 0.0861 - learning_rate: 0.0025
# Epoch 110/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1575 - val_loss: 0.0834 - learning_rate: 0.0028
# Epoch 111/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1513 - val_loss: 0.0807 - learning_rate: 0.0032
# Epoch 112/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1460 - val_loss: 0.0779 - learning_rate: 0.0035
# Epoch 113/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1413 - val_loss: 0.0753 - learning_rate: 0.0040
# Epoch 114/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1364 - val_loss: 0.0727 - learning_rate: 0.0045
# Epoch 115/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1301 - val_loss: 0.0702 - learning_rate: 0.0050
# Epoch 116/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1271 - val_loss: 0.0680 - learning_rate: 0.0056
# Epoch 117/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1210 - val_loss: 0.0659 - learning_rate: 0.0063
# Epoch 118/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1160 - val_loss: 0.0642 - learning_rate: 0.0071
# Epoch 119/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1132 - val_loss: 0.0627 - learning_rate: 0.0079
# Epoch 120/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1085 - val_loss: 0.0615 - learning_rate: 0.0089
# Epoch 121/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1062 - val_loss: 0.0605 - learning_rate: 0.0100
# Epoch 122/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1031 - val_loss: 0.0597 - learning_rate: 0.0112
# Epoch 123/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0987 - val_loss: 0.0596 - learning_rate: 0.0126
# Epoch 124/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0972 - val_loss: 0.0591 - learning_rate: 0.0141
# Epoch 125/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0958 - val_loss: 0.0604 - learning_rate: 0.0158
# Epoch 126/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0958 - val_loss: 0.0579 - learning_rate: 0.0178
# Epoch 127/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0931 - val_loss: 0.0705 - learning_rate: 0.0200
# Epoch 128/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.1070 - val_loss: 0.0837 - learning_rate: 0.0224
# Epoch 129/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.1145 - val_loss: 0.2935 - learning_rate: 0.0251
# Epoch 130/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.3704 - val_loss: 0.3024 - learning_rate: 0.0282
# Epoch 131/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2813 - val_loss: 0.4879 - learning_rate: 0.0316
# Epoch 132/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.6361 - val_loss: 0.0950 - learning_rate: 0.0355
# Epoch 133/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1413 - val_loss: 0.0728 - learning_rate: 0.0398
# Epoch 134/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1355 - val_loss: 0.0621 - learning_rate: 0.0447
# Epoch 135/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0976 - val_loss: 0.0716 - learning_rate: 0.0501
# Epoch 136/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1037 - val_loss: 0.0713 - learning_rate: 0.0562
# Epoch 137/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1000 - val_loss: 0.1718 - learning_rate: 0.0631
# Epoch 138/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2282 - val_loss: 0.2322 - learning_rate: 0.0708
# Epoch 139/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2128 - val_loss: 0.5218 - learning_rate: 0.0794
# Epoch 140/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.6199 - val_loss: 0.1790 - learning_rate: 0.0891
# Epoch 141/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2490 - val_loss: 0.3497 - learning_rate: 0.1000
# Epoch 142/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4955 - val_loss: 0.2083 - learning_rate: 0.1122
# Epoch 143/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.4821 - val_loss: 0.2674 - learning_rate: 0.1259
# Epoch 144/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.5134 - val_loss: 0.5454 - learning_rate: 0.1413
# Epoch 145/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.9404 - val_loss: 0.2604 - learning_rate: 0.1585
# Epoch 146/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.7525 - val_loss: 1.0405 - learning_rate: 0.1778
# Epoch 147/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.7757 - val_loss: 0.3583 - learning_rate: 0.1995
# Epoch 148/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.7998 - val_loss: 0.7411 - learning_rate: 0.2239
# Epoch 149/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.7538 - val_loss: 0.1049 - learning_rate: 0.2512
# Epoch 150/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2354 - val_loss: 0.3570 - learning_rate: 0.2818
# Epoch 151/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.9517 - val_loss: 1.8887 - learning_rate: 0.3162
# Epoch 152/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.4323 - val_loss: 0.6714 - learning_rate: 0.3548
# Epoch 153/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.3240 - val_loss: 0.5429 - learning_rate: 0.3981
# Epoch 154/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 1.0025 - val_loss: 1.4486 - learning_rate: 0.4467
# Epoch 155/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.5451 - val_loss: 2.1283 - learning_rate: 0.5012
# Epoch 156/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.2506 - val_loss: 1.0817 - learning_rate: 0.5623
# Epoch 157/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.6580 - val_loss: 0.6224 - learning_rate: 0.6310
# Epoch 158/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 1.3484 - val_loss: 2.5379 - learning_rate: 0.7079
# Epoch 159/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.4880 - val_loss: 3.4133 - learning_rate: 0.7943
# Epoch 160/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 2.5612 - val_loss: 1.2531 - learning_rate: 0.8913
# Epoch 161/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.4470 - val_loss: 4.2384 - learning_rate: 1.0000
# Epoch 162/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3.3857 - val_loss: 2.6048 - learning_rate: 1.1220
# Epoch 163/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 2.2798 - val_loss: 0.7210 - learning_rate: 1.2589
# Epoch 164/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.6676 - val_loss: 0.8258 - learning_rate: 1.4125
# Epoch 165/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 2.2943 - val_loss: 1.4133 - learning_rate: 1.5849
# Epoch 166/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 1.6191 - val_loss: 0.4356 - learning_rate: 1.7783
# Epoch 167/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.1665 - val_loss: 0.9198 - learning_rate: 1.9953
# Epoch 168/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.1574 - val_loss: 3.9579 - learning_rate: 2.2387
# Epoch 169/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 2.9228 - val_loss: 1.8269 - learning_rate: 2.5119
# Epoch 170/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 3.6329 - val_loss: 2.5093 - learning_rate: 2.8184
# Epoch 171/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 3.5169 - val_loss: 6.4829 - learning_rate: 3.1623
# Epoch 172/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.4114 - val_loss: 1.9924 - learning_rate: 3.5481
# Epoch 173/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 3.2227 - val_loss: 3.9486 - learning_rate: 3.9811
# Epoch 174/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.4508 - val_loss: 1.3035 - learning_rate: 4.4668
# Epoch 175/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3.8457 - val_loss: 7.0201 - learning_rate: 5.0119
# Epoch 176/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.8025 - val_loss: 1.6410 - learning_rate: 5.6234
# Epoch 177/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.1336 - val_loss: 0.4993 - learning_rate: 6.3096
# Epoch 178/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 1.3288 - val_loss: 4.2061 - learning_rate: 7.0795
# Epoch 179/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 4.2756 - val_loss: 5.3451 - learning_rate: 7.9433
# Epoch 180/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.6626 - val_loss: 6.4061 - learning_rate: 8.9125
# Epoch 181/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 4.6951 - val_loss: 8.4705 - learning_rate: 10.0000
# Epoch 182/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 5.1289 - val_loss: 6.3260 - learning_rate: 11.2202
# Epoch 183/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 6.6755 - val_loss: 19.0823 - learning_rate: 12.5893
# Epoch 184/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 15.4381 - val_loss: 1.2152 - learning_rate: 14.1254
# Epoch 185/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 13.5677 - val_loss: 17.9549 - learning_rate: 15.8489
# Epoch 186/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 17.0660 - val_loss: 7.8872 - learning_rate: 17.7828
# Epoch 187/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 9.1641 - val_loss: 4.9597 - learning_rate: 19.9526
# Epoch 188/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 11.1622 - val_loss: 9.5898 - learning_rate: 22.3872
# Epoch 189/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 11.2517 - val_loss: 0.4234 - learning_rate: 25.1189
# Epoch 190/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 13.4742 - val_loss: 15.0278 - learning_rate: 28.1838
# Epoch 191/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 16.4629 - val_loss: 8.4917 - learning_rate: 31.6228
# Epoch 192/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 21.0924 - val_loss: 62.2631 - learning_rate: 35.4813
# Epoch 193/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 68.4076 - val_loss: 21.0811 - learning_rate: 39.8107
# Epoch 194/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 60.5448 - val_loss: 69.9780 - learning_rate: 44.6684
# Epoch 195/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 71.0922 - val_loss: 138.6026 - learning_rate: 50.1187
# Epoch 196/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 102.7570 - val_loss: 88.8822 - learning_rate: 56.2341
# Epoch 197/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 102.4683 - val_loss: 22.4158 - learning_rate: 63.0957
# Epoch 198/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 32.6561 - val_loss: 19.2950 - learning_rate: 70.7946
# Epoch 199/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 40.1881 - val_loss: 16.7132 - learning_rate: 79.4328
# Epoch 200/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 67.1192 - val_loss: 190.5143 - learning_rate: 89.1251

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(200) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the training loss in log scale
plt.semilogx(lrs, history.history["loss"], label="Training Loss")

# Plot the validation loss in log scale
plt.semilogx(lrs, history.history["val_loss"], label="Validation Loss")

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-1, 0, 1])

# Add a legend
plt.legend()

# Add labels and title
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Training and Validation Loss vs. Learning Rate")

# Show the plot
plt.show()

# %% [raw]
# model_LSTM=1

# %%
# Reset states generated by Keras
#tf.keras.backend.clear_session()

# Build the model
model_LSTM = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
])

# Set the learning rate
learning_rate = 1e-3

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model_LSTM.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# EarlyStopping callback with patience
early_stopping = EarlyStopping(
    monitor="val_loss",     # Monitor validation loss
    patience=5,             # Wait 5 epochs for improvement
    mode="min",             # Stop when val_loss is minimized
    verbose=1               # Print when training stops early
)

# Train the model with EarlyStopping
history = model_LSTM.fit(
    x_train_windowed,
    validation_data=x_val_windowed,
    epochs=100,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5987 - mae: 0.9897 - val_loss: 0.3477 - val_mae: 0.6942
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5436 - mae: 0.9250 - val_loss: 0.2934 - val_mae: 0.6299
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4837 - mae: 0.8563 - val_loss: 0.2470 - val_mae: 0.5688
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4294 - mae: 0.7966 - val_loss: 0.2105 - val_mae: 0.5192
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.3808 - mae: 0.7403 - val_loss: 0.1821 - val_mae: 0.4833
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.3383 - mae: 0.6911 - val_loss: 0.1607 - val_mae: 0.4575
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.3030 - mae: 0.6503 - val_loss: 0.1460 - val_mae: 0.4400
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2753 - mae: 0.6158 - val_loss: 0.1366 - val_mae: 0.4287
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.2549 - mae: 0.5888 - val_loss: 0.1307 - val_mae: 0.4211
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.2404 - mae: 0.5694 - val_loss: 0.1267 - val_mae: 0.4153
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.2301 - mae: 0.5562 - val_loss: 0.1236 - val_mae: 0.4098
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2224 - mae: 0.5455 - val_loss: 0.1208 - val_mae: 0.4043
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2163 - mae: 0.5364 - val_loss: 0.1181 - val_mae: 0.3989
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2111 - mae: 0.5285 - val_loss: 0.1154 - val_mae: 0.3937
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2064 - mae: 0.5212 - val_loss: 0.1129 - val_mae: 0.3887
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2021 - mae: 0.5145 - val_loss: 0.1104 - val_mae: 0.3837
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1981 - mae: 0.5080 - val_loss: 0.1079 - val_mae: 0.3789
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1943 - mae: 0.5018 - val_loss: 0.1056 - val_mae: 0.3742
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1907 - mae: 0.4957 - val_loss: 0.1034 - val_mae: 0.3697
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1872 - mae: 0.4900 - val_loss: 0.1013 - val_mae: 0.3652
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1838 - mae: 0.4846 - val_loss: 0.0992 - val_mae: 0.3610
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1805 - mae: 0.4793 - val_loss: 0.0972 - val_mae: 0.3567
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1774 - mae: 0.4743 - val_loss: 0.0953 - val_mae: 0.3526
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1743 - mae: 0.4695 - val_loss: 0.0935 - val_mae: 0.3486
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1714 - mae: 0.4648 - val_loss: 0.0918 - val_mae: 0.3449
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1686 - mae: 0.4603 - val_loss: 0.0902 - val_mae: 0.3413
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1659 - mae: 0.4560 - val_loss: 0.0886 - val_mae: 0.3379
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.1633 - mae: 0.4520 - val_loss: 0.0871 - val_mae: 0.3347
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.1607 - mae: 0.4480 - val_loss: 0.0857 - val_mae: 0.3316
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.1583 - mae: 0.4441 - val_loss: 0.0843 - val_mae: 0.3286
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.1560 - mae: 0.4402 - val_loss: 0.0830 - val_mae: 0.3257
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1537 - mae: 0.4365 - val_loss: 0.0818 - val_mae: 0.3227
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1515 - mae: 0.4328 - val_loss: 0.0806 - val_mae: 0.3199
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1494 - mae: 0.4293 - val_loss: 0.0795 - val_mae: 0.3172
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1474 - mae: 0.4259 - val_loss: 0.0785 - val_mae: 0.3146
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1454 - mae: 0.4225 - val_loss: 0.0775 - val_mae: 0.3120
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1435 - mae: 0.4194 - val_loss: 0.0765 - val_mae: 0.3096
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1417 - mae: 0.4163 - val_loss: 0.0756 - val_mae: 0.3073
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1399 - mae: 0.4133 - val_loss: 0.0748 - val_mae: 0.3050
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1383 - mae: 0.4104 - val_loss: 0.0739 - val_mae: 0.3028
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1366 - mae: 0.4076 - val_loss: 0.0732 - val_mae: 0.3007
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1351 - mae: 0.4048 - val_loss: 0.0725 - val_mae: 0.2986
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1336 - mae: 0.4021 - val_loss: 0.0718 - val_mae: 0.2967
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1321 - mae: 0.3996 - val_loss: 0.0712 - val_mae: 0.2948
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1308 - mae: 0.3972 - val_loss: 0.0706 - val_mae: 0.2930
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1294 - mae: 0.3949 - val_loss: 0.0700 - val_mae: 0.2913
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.1282 - mae: 0.3926 - val_loss: 0.0695 - val_mae: 0.2896
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.1270 - mae: 0.3904 - val_loss: 0.0690 - val_mae: 0.2881
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.1258 - mae: 0.3883 - val_loss: 0.0686 - val_mae: 0.2867
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.1247 - mae: 0.3863 - val_loss: 0.0681 - val_mae: 0.2853
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1237 - mae: 0.3844 - val_loss: 0.0677 - val_mae: 0.2840
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1227 - mae: 0.3825 - val_loss: 0.0674 - val_mae: 0.2827
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1217 - mae: 0.3807 - val_loss: 0.0670 - val_mae: 0.2814
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1208 - mae: 0.3789 - val_loss: 0.0667 - val_mae: 0.2802
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1199 - mae: 0.3772 - val_loss: 0.0664 - val_mae: 0.2791
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1191 - mae: 0.3755 - val_loss: 0.0661 - val_mae: 0.2779
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1183 - mae: 0.3738 - val_loss: 0.0658 - val_mae: 0.2768
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1175 - mae: 0.3722 - val_loss: 0.0655 - val_mae: 0.2757
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1168 - mae: 0.3707 - val_loss: 0.0653 - val_mae: 0.2747
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1160 - mae: 0.3692 - val_loss: 0.0651 - val_mae: 0.2737
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1153 - mae: 0.3678 - val_loss: 0.0648 - val_mae: 0.2728
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1147 - mae: 0.3664 - val_loss: 0.0646 - val_mae: 0.2719
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1140 - mae: 0.3650 - val_loss: 0.0644 - val_mae: 0.2711
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1134 - mae: 0.3636 - val_loss: 0.0643 - val_mae: 0.2703
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1128 - mae: 0.3623 - val_loss: 0.0641 - val_mae: 0.2696
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.1122 - mae: 0.3610 - val_loss: 0.0639 - val_mae: 0.2689
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.1117 - mae: 0.3598 - val_loss: 0.0638 - val_mae: 0.2682
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1111 - mae: 0.3585 - val_loss: 0.0636 - val_mae: 0.2676
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1106 - mae: 0.3573 - val_loss: 0.0635 - val_mae: 0.2670
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1101 - mae: 0.3561 - val_loss: 0.0633 - val_mae: 0.2664
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.1096 - mae: 0.3550 - val_loss: 0.0632 - val_mae: 0.2658
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1091 - mae: 0.3538 - val_loss: 0.0630 - val_mae: 0.2652
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1087 - mae: 0.3527 - val_loss: 0.0629 - val_mae: 0.2647
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1082 - mae: 0.3516 - val_loss: 0.0628 - val_mae: 0.2642
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1077 - mae: 0.3506 - val_loss: 0.0627 - val_mae: 0.2637
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1073 - mae: 0.3495 - val_loss: 0.0626 - val_mae: 0.2632
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1069 - mae: 0.3485 - val_loss: 0.0625 - val_mae: 0.2628
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1065 - mae: 0.3474 - val_loss: 0.0624 - val_mae: 0.2623
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1061 - mae: 0.3464 - val_loss: 0.0623 - val_mae: 0.2619
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1057 - mae: 0.3455 - val_loss: 0.0622 - val_mae: 0.2615
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.1053 - mae: 0.3446 - val_loss: 0.0621 - val_mae: 0.2612
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1049 - mae: 0.3437 - val_loss: 0.0620 - val_mae: 0.2608
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.1045 - mae: 0.3428 - val_loss: 0.0619 - val_mae: 0.2605
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.1042 - mae: 0.3419 - val_loss: 0.0618 - val_mae: 0.2602
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.1038 - mae: 0.3411 - val_loss: 0.0617 - val_mae: 0.2599
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.1035 - mae: 0.3402 - val_loss: 0.0616 - val_mae: 0.2596
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1031 - mae: 0.3394 - val_loss: 0.0615 - val_mae: 0.2593
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1028 - mae: 0.3386 - val_loss: 0.0614 - val_mae: 0.2590
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1024 - mae: 0.3377 - val_loss: 0.0614 - val_mae: 0.2587
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1021 - mae: 0.3370 - val_loss: 0.0613 - val_mae: 0.2584
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1018 - mae: 0.3362 - val_loss: 0.0612 - val_mae: 0.2581
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1015 - mae: 0.3354 - val_loss: 0.0611 - val_mae: 0.2579
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.1012 - mae: 0.3346 - val_loss: 0.0611 - val_mae: 0.2576
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1008 - mae: 0.3339 - val_loss: 0.0610 - val_mae: 0.2573
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.1005 - mae: 0.3331 - val_loss: 0.0609 - val_mae: 0.2570
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1002 - mae: 0.3324 - val_loss: 0.0608 - val_mae: 0.2568
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0999 - mae: 0.3317 - val_loss: 0.0608 - val_mae: 0.2565
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0997 - mae: 0.3310 - val_loss: 0.0607 - val_mae: 0.2562
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0994 - mae: 0.3302 - val_loss: 0.0606 - val_mae: 0.2560
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0991 - mae: 0.3295 - val_loss: 0.0606 - val_mae: 0.2557

# %%
type(x_test_scaled)
# Out:
# numpy.ndarray

# %%
# Initialize a list
forecast = []

# Use the model to predict data points per window size
for time in range(len(grouped_df0)-split2-window_size):
  forecast.append(model_LSTM.predict(x_test_scaled[time:time + window_size][np.newaxis], verbose=0))

# Slice the points that are aligned with the validation set
#forecast = forecast[split_time - window_size:]

# Compare number of elements in the predictions and the validation set
print(f'length of the forecast list: {len(forecast)}')
print(f'shape of the validation set: {x_test.shape}')
# Out:
# length of the forecast list: 577
# shape of the validation set: (607,)

# %%
# Preview shapes after using the conversion and squeeze methods
print(f'shape after converting to numpy array: {np.array(forecast).shape}')
print(f'shape after squeezing: {np.array(forecast).squeeze().shape}')

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()
# Out:
# shape after converting to numpy array: (577, 1, 1)
# shape after squeezing: (577,)

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)), label='True Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(results_reshaped), label='Predicted', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
import plotly.express as px
import pandas as pd

# Prepare a DataFrame for Plotly
plot_df = pd.DataFrame({
    'Price Date': x_test_scaled_df.index[30:],
    'True Value': scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)).flatten(),
    'Predicted': scaler.inverse_transform(results.reshape(-1, 1)).flatten()
})

# Create an interactive plot
fig = px.line(
    plot_df,
    x='Price Date',
    y=['True Value', 'Predicted'],
    labels={'value': 'Modal Price (Rs./Quintal)', 'variable': 'Legend'},
    title='Modal Price Over Time'
)

# Update layout for better aesthetics
fig.update_layout(
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e43094a8-b691-4d73-8ea2-31a35e025288" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e43094a8-b691-4d73-8ea2-31a35e025288")) {                    Plotly.newPlot(                        "e43094a8-b691-4d73-8ea2-31a35e025288",                        [{"hovertemplate":"Legend=True Value\u003cbr\u003ePrice Date=%{x}\u003cbr\u003eModal Price (Rs.\u002fQuintal)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True Value","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"True Value","showlegend":true,"x":["2023-04-04T00:00:00","2023-04-05T00:00:00","2023-04-06T00:00:00","2023-04-07T00:00:00","2023-04-08T00:00:00","2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-04-29T00:00:00","2023-04-30T00:00:00","2023-05-01T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-06T00:00:00","2023-05-07T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-13T00:00:00","2023-05-14T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-20T00:00:00","2023-05-21T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-27T00:00:00","2023-05-28T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-03T00:00:00","2023-06-04T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-10T00:00:00","2023-06-11T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-17T00:00:00","2023-06-18T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-24T00:00:00","2023-06-25T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-29T00:00:00","2023-06-30T00:00:00","2023-07-01T00:00:00","2023-07-02T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00","2023-08-18T00:00:00","2023-08-19T00:00:00","2023-08-20T00:00:00","2023-08-21T00:00:00","2023-08-22T00:00:00","2023-08-23T00:00:00"," ...

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
true_values = x_test_scaled_df.values[30:].reshape(-1, 1)
predicted_values = results_reshaped

print("MSE:", mse(true_values, predicted_values).numpy())
print("MAE:", mae(true_values, predicted_values).numpy())

lstm_mse = mse(true_values, predicted_values).numpy()
lstm_mae = mae(true_values, predicted_values).numpy()
# Out:
# MSE: 0.22497799
# MAE: 0.32515892

# %%
model_name = ['rnn', 'lstm']
lst_mse = [rnn_mse, lstm_mse]
lst_mae = [rnn_mae, lstm_mae]

for i in range(len(model_name)):
    print(f'MSE dari {model_name[i]} adalah {lst_mse[i]}')
    print(f'MAE dari {model_name[i]} adalah {lst_mae[i]}')

smallest_mse = np.argmin(lst_mse)
smallest_mae = np.argmin(lst_mae)

print(f'Model terbaik adalah {model_name[smallest_mse]} berdasarkan MSE terkecil')
print(f'Model terbaik adalah {model_name[smallest_mae]} berdasarkan MAE terkecil')
# Out:
# MSE dari rnn adalah 0.14987105131149292
# MAE dari rnn adalah 0.25022685527801514
# MSE dari lstm adalah 0.2249779850244522
# MAE dari lstm adalah 0.3251589238643646
# Model terbaik adalah rnn berdasarkan MSE terkecil
# Model terbaik adalah rnn berdasarkan MAE terkecil

# %% [markdown]
# Forecast

# %%
numpy_grouped_df=grouped_df0.to_numpy()

# %%
numpy_grouped_df_scaled = scaler.transform(numpy_grouped_df.reshape(-1,1))

# %%
days = 240

# %%
len(numpy_grouped_df)/240
# Out:
# 4.891666666666667

# %% [markdown]
# Plot ulang RNN

# %%
# Initialize lists for forecast
days = 240
forecast = []
result_forecast = numpy_grouped_df_scaled[-240:].tolist()  # Use the last 30 values as the starting point

# Flatten result_forecast if it contains nested lists
# Assuming numpy_grouped_df_scaled[-30:] is a 2D array or list of lists
result_forecast = [item[0] if isinstance(item, list) else float(item) for item in result_forecast]

# Forecast for 365 days
for _ in range(days):
    # Prepare input for the model
    input_data = np.array(result_forecast[-240:]).reshape(1, 240, 1)  # Reshape correctly

    # Predict and extract the scalar value
    prediksi = model_RNN.predict(input_data)[0][0]  # Extract scalar from prediction array

    # Append the prediction
    forecast.append(prediksi)  # For final forecast output
    result_forecast.append(prediksi)  # For generating subsequent predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step

# %%
last_30_df = pd.DataFrame(numpy_grouped_df[-240:], columns=[grouped_df0.name],index=grouped_df0[-240:].index)

# %%
# Assume forecast contains the 30 predicted values
import pandas as pd

# Create a new datetime index for the next 30 days
new_dates = pd.date_range(start=last_30_df.index[-1] + pd.Timedelta(days=1), periods=days)

# Create a new DataFrame with the forecasted values
forecast_df = pd.DataFrame({'Modal Price (Rs./Quintal)': (scaler.inverse_transform(np.array(forecast).reshape(-1,1)).flatten())}, index=new_dates)

# Concatenate the existing DataFrame with the forecasted DataFrame
extended_df = pd.concat([last_30_df, forecast_df])

# Display the extended DataFrame
print(len(extended_df))
# Out:
# 480

# %%
import plotly.graph_objects as go
import pandas as pd

# Concatenate the actual and forecast DataFrames into a single DataFrame
combined_df = pd.concat([last_30_df, forecast_df])

# Create a figure
fig = go.Figure()


# Add a trace for the combined actual and forecast data (continuous line)
fig.add_trace(go.Scatter(
    x=extended_df.index,  # Use the combined index of both actual and forecast
    y=extended_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='Predicted Price',  # Label for combined data
    line=dict(color='red')  # Blue color for the forecasted data
))

# Add a trace for the last 30 actual values
fig.add_trace(go.Scatter(
    x=last_30_df.index,  # Only the index for the last 30 actual values
    y=last_30_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='True Price',  # Label for the last 30 actual data
    line=dict(color='blue')  # Green color for actual data
))


# Update layout for better aesthetics
fig.update_layout(
    title='Modal Price Over Time',
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f71a417f-38e7-43e5-ba90-e0118bfeec17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f71a417f-38e7-43e5-ba90-e0118bfeec17")) {                    Plotly.newPlot(                        "f71a417f-38e7-43e5-ba90-e0118bfeec17",                        [{"line":{"color":"red"},"mode":"lines","name":"Predicted Price","x":["2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-24T00:00:00","2024-05-25T00:00:00","2024-05-26T00:00:00","2024-05-27T00:00:00","2024-05-28T00:00:00","2024-05-29T00:00:00","2024-05-30T00:00:00","2024-05-31T00:00:00","2024-06-01T00:00:00","2024-06-02T00:00:00","2024-06-03T00:00:00","2024-06-04T00:00:00","2024-06-05T00:00:00","2024-06-06T00:00:00","2024-06-07T00:00:00","2024-06-08T00:00:00","2024-06-09T00:00:00","2024-06-10T00:00:00","2024-06-11T00:00:00","2024-06-12T00:00:00","2024-06-13T00:00:00","2024-06-14T00:00:00","2024-06-15T00:00:00","2024-06-16T00:00:00","2024-06-17T00:00:00","2024-06-18T00:00:00","2024-06-19T00:00:00","2024-06-20T00:00:00","2024-06-21T00:00:00","2024-06-22T00:00:00","2024-06-23T00:00:00","2024-06-24T00:00:00","2024-06-25T00:00:00","2024-06-26T00:00:00","2024-06-27T00:00:00","2024-06-28T00:00:00","2024-06-29T00:00:00","2024-06-30T00:00:00","2024-07-01T00:00:00","2024-07-02T00:00:00","2024-07-03T00:00:00","2024-07-04T00:00:00","2024-07-05T00:00:00","2024-07-06T00:00:00","2024-07-07T00:00:00","2024-07-08T00:00:00","2024-07-09T00:00:00","2024-07-10T00:00:00","2024-07-11T00:00:00","2024-07-12T00:00:00","2024-07-13T00:00:00","2024-07-14T00:00:00","2024-07-15T00:00:00","2024-07-16T00:00:00","2024-07-17T00:00:00","2024-07-18T00:00:00","2024-07-19T00:00:00","2024-07-20T00:00:00","2024-07-21T00:00:00","2024-07-22T00:00:00","2024-07-23T00:00:00","2024-07-24T00:00:00","2024-07-25T00:00:00","2024-07-26T00:00:00","2024-07-27T00:00:00","2024-07-28T00:00:00","2024-07-29T00:00:00","2024-07-30T00:00:00","2024-07-31T00:00:00","2024-08-01T00:00:00","2024-08-02T00:00:00","2024-08-03T00:00:00","2024-08-04T00:00:00","2024-08-05T00:00:00"," ...

# %% [markdown]
# Plot ulang LSTM

# %%
# Initialize lists for forecast
days = 1*240
forecast = []
result_forecast = numpy_grouped_df_scaled[-1*240:].tolist()  # Use the last 30 values as the starting point

# Flatten result_forecast if it contains nested lists
# Assuming numpy_grouped_df_scaled[-30:] is a 2D array or list of lists
result_forecast = [item[0] if isinstance(item, list) else float(item) for item in result_forecast]

# Forecast for 365 days
for _ in range(days):
    # Prepare input for the model
    input_data = np.array(result_forecast[-1*240:]).reshape(1, 1*240, 1)  # Reshape correctly

    # Predict and extract the scalar value
    prediksi = model_LSTM.predict(input_data)[0][0]  # Extract scalar from prediction array

    # Append the prediction
    forecast.append(prediksi)  # For final forecast output
    result_forecast.append(prediksi)  # For generating subsequent predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
last_30_df = pd.DataFrame(numpy_grouped_df[-240:], columns=[grouped_df.name],index=grouped_df[-240:].index)

# %%
# Assume forecast contains the 30 predicted values
import pandas as pd

# Create a new datetime index for the next 30 days
new_dates = pd.date_range(start=last_30_df.index[-1] + pd.Timedelta(days=1), periods=days)

# Create a new DataFrame with the forecasted values
forecast_df = pd.DataFrame({'Modal Price (Rs./Quintal)': (scaler.inverse_transform(np.array(forecast).reshape(-1,1)).flatten())}, index=new_dates)

# Concatenate the existing DataFrame with the forecasted DataFrame
extended_df = pd.concat([last_30_df, forecast_df])

# Display the extended DataFrame
print(len(extended_df))
# Out:
# 480

# %%
import plotly.graph_objects as go
import pandas as pd

# Concatenate the actual and forecast DataFrames into a single DataFrame
combined_df = pd.concat([last_30_df, forecast_df])

# Create a figure
fig = go.Figure()


# Add a trace for the combined actual and forecast data (continuous line)
fig.add_trace(go.Scatter(
    x=extended_df.index,  # Use the combined index of both actual and forecast
    y=extended_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='Predicted Price',  # Label for combined data
    line=dict(color='red')  # Blue color for the forecasted data
))

# Add a trace for the last 30 actual values
fig.add_trace(go.Scatter(
    x=last_30_df.index,  # Only the index for the last 30 actual values
    y=last_30_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='True Price',  # Label for the last 30 actual data
    line=dict(color='blue')  # Green color for actual data
))


# Update layout for better aesthetics
fig.update_layout(
    title='Modal Price Over Time',
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()

# %% [markdown]
# Save model

# %%
import joblib

# Assuming `scaler` is your StandardScaler object
joblib.dump(scaler, 'scaler_rice.pkl')

#save model
model_RNN.save('best_rice_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
grouped_df0.to_excel("rice_avg_price.xlsx")
