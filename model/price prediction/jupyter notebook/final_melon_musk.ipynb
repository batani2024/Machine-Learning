# %% [markdown]
# Import modul and library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_excel("https://docs.google.com/spreadsheets/d/1-SHmKNfL5PCr40mhsYG2Ha-mg9mNFB0H/export?format=xlsx")

# %%
df.head(5)
# Out:
#    Unnamed: 0  Sl no. District Name                  Market Name  \
# 0           0     672     Bangalore  Binny Mill (F&V), Bangalore
# 1           1    5020   Kurukshetra                     Shahabad
# 2           2    3329        Mumbai         Mumbai- Fruit Market
# 3           3    5153    Ahmednagar                   Shrirampur
# 4           4    2315     Jalandhar    Jalandhar City(Jalandhar)
#
#              Commodity   Variety   Grade  Min Price (Rs./Quintal)  \
# 0  Karbuja(Musk Melon)  Karbhuja     FAQ                    800.0
# 1  Karbuja(Musk Melon)  Karbhuja  Medium                   3500.0
# 2  Karbuja(Musk Melon)     Other     FAQ                   1500.0
# 3  Karbuja(Musk Melon)     Other     FAQ                   1000.0
# 4  Karbuja(Musk Melon)  Karbhuja  Medium                   1500.0
#
#    Max Price (Rs./Quintal)  Modal Price (Rs./Quintal) Price Date
# 0                   2000.0                     1600.0 2021-03-15
# 1                   3500.0                     3500.0 2021-03-15
# 2                   2000.0                     1750.0 2021-03-15
# 3                   1800.0                     1400.0 2021-03-15
# 4                   2500.0                     1900.0 2021-03-15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168003 entries, 0 to 168002
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Unnamed: 0                 168003 non-null  int64
#  1   Sl no.                     168003 non-null  int64
#  2   District Name              168003 non-null  object
#  3   Market Name                168003 non-null  object
#  4   Commodity                  168003 non-null  object
#  5   Variety                    168003 non-null  object
#  6   Grade                      168003 non-null  object
#  7   Min Price (Rs./Quintal)    168003 non-null  int64
#  8   Max Price (Rs./Quintal)    168003 non-null  int64
#  9   Modal Price (Rs./Quintal)  168003 non-null  int64
#  10  Price Date                 168003 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(5)
# memory usage: 14.1+ MB

# %% [markdown]
# dari semua varietas, grade, kelompokkan menjadi satu dan hitung rata-ratanya

# %%
grouped_df0 = df.groupby('Price Date')['Modal Price (Rs./Quintal)'].mean()

# %%
grouped_df0
# Out:
# Price Date
# 2021-03-15    2167.142857
# 2021-03-16    2460.187500
# 2021-03-17    2619.166667
# 2021-03-18    2713.636364
# 2021-03-19    2811.111111
#                  ...
# 2024-10-27    4662.500000
# 2024-10-28    4379.916667
# 2024-10-29    4077.900000
# 2024-10-30    4514.000000
# 2024-10-31    3966.666667
# Name: Modal Price (Rs./Quintal), Length: 1314, dtype: float64

# %%
type(grouped_df0)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Download grouped_df untuk digunakan pada saat deployment

# %%
#grouped_df.to_excel('grouped_prices_banana.xlsx', sheet_name='Prices')

# %% [markdown]
# Tinjau grafik harga dari harga komoditas tersebut untuk melihat trend secara kasat mata

# %%
# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(grouped_df0.index, grouped_df0, label='Modal Price', color='blue')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Define the split time
split1 = 2*180
split2 = 4*180

# Get the train set
time_train = grouped_df0.index[:split1]
x_train = grouped_df0[:split1]

# Get the validation set
time_valid = grouped_df0.index[split1:split2]
x_valid = grouped_df0[split1:split2]

# Get the test set
time_test = grouped_df0.index[split2:]
x_test = grouped_df0[split2:]

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the data and transform it
x_train_scaled = scaler.fit_transform(x_train.values.reshape(-1,1))
x_val_scaled = scaler.transform(x_valid.values.reshape(-1,1))
x_test_scaled = scaler.transform(x_test.values.reshape(-1,1))

# Convert the scaled data back into a DataFrame for easier reading
x_train_scaled_df = pd.DataFrame(x_train_scaled, columns=[x_train.name],index=x_train.index)
x_val_scaled_df = pd.DataFrame(x_val_scaled,  columns=[x_valid.name],index=x_valid.index)
x_test_scaled_df = pd.DataFrame(x_test_scaled,  columns=[x_test.name],index=x_test.index)

# %%
# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(time_valid, x_valid, label='Modal Price', color='blue')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# #Naive Forecast

# %%
series = np.array(grouped_df0)

# %%
series = scaler.transform(series.reshape(-1,1))

# %%
# Generate the naive forecast
split_time = split2
naive_forecast = series[split_time-1 :-1]

# Define time step
time_step = 100

# Print values
print(f'ground truth at time step {time_step}: {x_test_scaled[time_step]}')
print(f'prediction at time step {time_step + 1}: {naive_forecast[time_step +1]}')
# Out:
# ground truth at time step 100: [-1.27903921]
# prediction at time step 101: [-1.27903921]

# %%
len(x_test_scaled)
# Out:
# 594

# %%
len(naive_forecast)
# Out:
# 594

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
#results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index, naive_forecast, label='Predicted Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index, x_test_scaled, label='True Value', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
print("MSE:", mse(x_test_scaled, naive_forecast).numpy())
print("MAE:", mae(x_test_scaled, naive_forecast).numpy())

naive_mse = mse(x_test_scaled, naive_forecast).numpy()
naive_mae = mae(x_test_scaled, naive_forecast).numpy()
# Out:
# MSE: 0.6879291
# MAE: 0.52799934

# %%
# Parameters
window_size = 30
batch_size = 32

# %%
def windowed_dataset(series, window_size, batch_size):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    #dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size)

    # Optimize the dataset for training
    dataset = dataset.cache().prefetch(1)

    return dataset

# %%
# Generate the dataset windows
x_train_windowed = windowed_dataset(x_train_scaled, window_size, batch_size)
x_val_windowed = windowed_dataset(x_val_scaled, window_size, batch_size)

# %%
# Print properties of a single batch
for windows in x_train_windowed.take(1):
  print(f'data type: {type(windows)}')
  print(f'number of elements in the tuple: {len(windows)}')
  print(f'shape of first element: {windows[0].shape}')
  print(f'shape of second element: {windows[1].shape}')
# Out:
# data type: <class 'tuple'>
# number of elements in the tuple: 2
# shape of first element: (32, 30, 1)
# shape of second element: (32, 1)

# %% [markdown]
# #RNN

# %%
# Build the Model
model_tune = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.SimpleRNN(40, return_sequences=True),
    tf.keras.layers.SimpleRNN(40),
    tf.keras.layers.Dense(1),
])

# Print the model summary
model_tune.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 30, 40)              │           1,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_1 (SimpleRNN)             │ (None, 40)                  │           3,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              41 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,961 (19.38 KB)
#  Trainable params: 4,961 (19.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model_tune.fit(x_train_windowed, validation_data=x_val_windowed, epochs=200, callbacks=[lr_schedule])
# Out:
# Epoch 1/200
#      11/Unknown 3s 25ms/step - loss: 0.2902
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 0.2934 - val_loss: 0.2217 - learning_rate: 1.0000e-08
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2934 - val_loss: 0.2217 - learning_rate: 1.1220e-08
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2934 - val_loss: 0.2217 - learning_rate: 1.2589e-08
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2934 - val_loss: 0.2216 - learning_rate: 1.4125e-08
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2934 - val_loss: 0.2216 - learning_rate: 1.5849e-08
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2934 - val_loss: 0.2216 - learning_rate: 1.7783e-08
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2934 - val_loss: 0.2216 - learning_rate: 1.9953e-08
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2934 - val_loss: 0.2216 - learning_rate: 2.2387e-08
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2934 - val_loss: 0.2216 - learning_rate: 2.5119e-08
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2934 - val_loss: 0.2216 - learning_rate: 2.8184e-08
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2933 - val_loss: 0.2216 - learning_rate: 3.1623e-08
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2933 - val_loss: 0.2216 - learning_rate: 3.5481e-08
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2933 - val_loss: 0.2216 - learning_rate: 3.9811e-08
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2933 - val_loss: 0.2216 - learning_rate: 4.4668e-08
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2933 - val_loss: 0.2216 - learning_rate: 5.0119e-08
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2933 - val_loss: 0.2215 - learning_rate: 5.6234e-08
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2932 - val_loss: 0.2215 - learning_rate: 6.3096e-08
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2932 - val_loss: 0.2215 - learning_rate: 7.0795e-08
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2932 - val_loss: 0.2215 - learning_rate: 7.9433e-08
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2931 - val_loss: 0.2214 - learning_rate: 8.9125e-08
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2931 - val_loss: 0.2214 - learning_rate: 1.0000e-07
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2930 - val_loss: 0.2214 - learning_rate: 1.1220e-07
# Epoch 23/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2930 - val_loss: 0.2213 - learning_rate: 1.2589e-07
# Epoch 24/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2929 - val_loss: 0.2213 - learning_rate: 1.4125e-07
# Epoch 25/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2929 - val_loss: 0.2212 - learning_rate: 1.5849e-07
# Epoch 26/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2928 - val_loss: 0.2212 - learning_rate: 1.7783e-07
# Epoch 27/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2927 - val_loss: 0.2211 - learning_rate: 1.9953e-07
# Epoch 28/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2926 - val_loss: 0.2211 - learning_rate: 2.2387e-07
# Epoch 29/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2925 - val_loss: 0.2210 - learning_rate: 2.5119e-07
# Epoch 30/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2924 - val_loss: 0.2209 - learning_rate: 2.8184e-07
# Epoch 31/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2923 - val_loss: 0.2208 - learning_rate: 3.1623e-07
# Epoch 32/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2921 - val_loss: 0.2207 - learning_rate: 3.5481e-07
# Epoch 33/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2920 - val_loss: 0.2206 - learning_rate: 3.9811e-07
# Epoch 34/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2918 - val_loss: 0.2204 - learning_rate: 4.4668e-07
# Epoch 35/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2916 - val_loss: 0.2203 - learning_rate: 5.0119e-07
# Epoch 36/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2914 - val_loss: 0.2201 - learning_rate: 5.6234e-07
# Epoch 37/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2911 - val_loss: 0.2199 - learning_rate: 6.3096e-07
# Epoch 38/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2908 - val_loss: 0.2197 - learning_rate: 7.0795e-07
# Epoch 39/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2905 - val_loss: 0.2195 - learning_rate: 7.9433e-07
# Epoch 40/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2902 - val_loss: 0.2192 - learning_rate: 8.9125e-07
# Epoch 41/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2898 - val_loss: 0.2189 - learning_rate: 1.0000e-06
# Epoch 42/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2893 - val_loss: 0.2185 - learning_rate: 1.1220e-06
# Epoch 43/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2888 - val_loss: 0.2182 - learning_rate: 1.2589e-06
# Epoch 44/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2883 - val_loss: 0.2177 - learning_rate: 1.4125e-06
# Epoch 45/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2876 - val_loss: 0.2173 - learning_rate: 1.5849e-06
# Epoch 46/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2869 - val_loss: 0.2168 - learning_rate: 1.7783e-06
# Epoch 47/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.2862 - val_loss: 0.2162 - learning_rate: 1.9953e-06
# Epoch 48/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2853 - val_loss: 0.2155 - learning_rate: 2.2387e-06
# Epoch 49/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2844 - val_loss: 0.2148 - learning_rate: 2.5119e-06
# Epoch 50/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2833 - val_loss: 0.2140 - learning_rate: 2.8184e-06
# Epoch 51/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2821 - val_loss: 0.2131 - learning_rate: 3.1623e-06
# Epoch 52/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2808 - val_loss: 0.2122 - learning_rate: 3.5481e-06
# Epoch 53/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2794 - val_loss: 0.2111 - learning_rate: 3.9811e-06
# Epoch 54/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2778 - val_loss: 0.2099 - learning_rate: 4.4668e-06
# Epoch 55/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2760 - val_loss: 0.2086 - learning_rate: 5.0119e-06
# Epoch 56/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2741 - val_loss: 0.2071 - learning_rate: 5.6234e-06
# Epoch 57/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2719 - val_loss: 0.2056 - learning_rate: 6.3096e-06
# Epoch 58/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2696 - val_loss: 0.2038 - learning_rate: 7.0795e-06
# Epoch 59/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2670 - val_loss: 0.2020 - learning_rate: 7.9433e-06
# Epoch 60/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2642 - val_loss: 0.1999 - learning_rate: 8.9125e-06
# Epoch 61/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2612 - val_loss: 0.1977 - learning_rate: 1.0000e-05
# Epoch 62/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2580 - val_loss: 0.1954 - learning_rate: 1.1220e-05
# Epoch 63/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2545 - val_loss: 0.1929 - learning_rate: 1.2589e-05
# Epoch 64/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2507 - val_loss: 0.1902 - learning_rate: 1.4125e-05
# Epoch 65/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.2468 - val_loss: 0.1874 - learning_rate: 1.5849e-05
# Epoch 66/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2426 - val_loss: 0.1844 - learning_rate: 1.7783e-05
# Epoch 67/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2382 - val_loss: 0.1814 - learning_rate: 1.9953e-05
# Epoch 68/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2336 - val_loss: 0.1782 - learning_rate: 2.2387e-05
# Epoch 69/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.2289 - val_loss: 0.1750 - learning_rate: 2.5119e-05
# Epoch 70/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2241 - val_loss: 0.1717 - learning_rate: 2.8184e-05
# Epoch 71/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2193 - val_loss: 0.1684 - learning_rate: 3.1623e-05
# Epoch 72/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.2145 - val_loss: 0.1652 - learning_rate: 3.5481e-05
# Epoch 73/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2097 - val_loss: 0.1620 - learning_rate: 3.9811e-05
# Epoch 74/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2051 - val_loss: 0.1590 - learning_rate: 4.4668e-05
# Epoch 75/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2007 - val_loss: 0.1560 - learning_rate: 5.0119e-05
# Epoch 76/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1965 - val_loss: 0.1532 - learning_rate: 5.6234e-05
# Epoch 77/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1925 - val_loss: 0.1505 - learning_rate: 6.3096e-05
# Epoch 78/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1888 - val_loss: 0.1480 - learning_rate: 7.0795e-05
# Epoch 79/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1853 - val_loss: 0.1455 - learning_rate: 7.9433e-05
# Epoch 80/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1821 - val_loss: 0.1432 - learning_rate: 8.9125e-05
# Epoch 81/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1791 - val_loss: 0.1409 - learning_rate: 1.0000e-04
# Epoch 82/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1763 - val_loss: 0.1387 - learning_rate: 1.1220e-04
# Epoch 83/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1735 - val_loss: 0.1364 - learning_rate: 1.2589e-04
# Epoch 84/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1709 - val_loss: 0.1343 - learning_rate: 1.4125e-04
# Epoch 85/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1684 - val_loss: 0.1321 - learning_rate: 1.5849e-04
# Epoch 86/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1659 - val_loss: 0.1300 - learning_rate: 1.7783e-04
# Epoch 87/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1634 - val_loss: 0.1279 - learning_rate: 1.9953e-04
# Epoch 88/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1610 - val_loss: 0.1258 - learning_rate: 2.2387e-04
# Epoch 89/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1587 - val_loss: 0.1239 - learning_rate: 2.5119e-04
# Epoch 90/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1565 - val_loss: 0.1220 - learning_rate: 2.8184e-04
# Epoch 91/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1543 - val_loss: 0.1202 - learning_rate: 3.1623e-04
# Epoch 92/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1522 - val_loss: 0.1186 - learning_rate: 3.5481e-04
# Epoch 93/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1501 - val_loss: 0.1170 - learning_rate: 3.9811e-04
# Epoch 94/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1482 - val_loss: 0.1157 - learning_rate: 4.4668e-04
# Epoch 95/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1463 - val_loss: 0.1145 - learning_rate: 5.0119e-04
# Epoch 96/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1445 - val_loss: 0.1135 - learning_rate: 5.6234e-04
# Epoch 97/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1427 - val_loss: 0.1126 - learning_rate: 6.3096e-04
# Epoch 98/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1410 - val_loss: 0.1119 - learning_rate: 7.0795e-04
# Epoch 99/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1393 - val_loss: 0.1114 - learning_rate: 7.9433e-04
# Epoch 100/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1375 - val_loss: 0.1111 - learning_rate: 8.9125e-04
# Epoch 101/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1358 - val_loss: 0.1109 - learning_rate: 0.0010
# Epoch 102/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1341 - val_loss: 0.1108 - learning_rate: 0.0011
# Epoch 103/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1323 - val_loss: 0.1108 - learning_rate: 0.0013
# Epoch 104/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1305 - val_loss: 0.1108 - learning_rate: 0.0014
# Epoch 105/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1287 - val_loss: 0.1109 - learning_rate: 0.0016
# Epoch 106/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1267 - val_loss: 0.1110 - learning_rate: 0.0018
# Epoch 107/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1248 - val_loss: 0.1111 - learning_rate: 0.0020
# Epoch 108/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1227 - val_loss: 0.1112 - learning_rate: 0.0022
# Epoch 109/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1205 - val_loss: 0.1113 - learning_rate: 0.0025
# Epoch 110/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1182 - val_loss: 0.1115 - learning_rate: 0.0028
# Epoch 111/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1158 - val_loss: 0.1117 - learning_rate: 0.0032
# Epoch 112/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1132 - val_loss: 0.1122 - learning_rate: 0.0035
# Epoch 113/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1105 - val_loss: 0.1131 - learning_rate: 0.0040
# Epoch 114/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1076 - val_loss: 0.1144 - learning_rate: 0.0045
# Epoch 115/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.1046 - val_loss: 0.1162 - learning_rate: 0.0050
# Epoch 116/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1014 - val_loss: 0.1189 - learning_rate: 0.0056
# Epoch 117/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0979 - val_loss: 0.1226 - learning_rate: 0.0063
# Epoch 118/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0942 - val_loss: 0.1275 - learning_rate: 0.0071
# Epoch 119/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0903 - val_loss: 0.1342 - learning_rate: 0.0079
# Epoch 120/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0869 - val_loss: 0.1422 - learning_rate: 0.0089
# Epoch 121/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0844 - val_loss: 0.1491 - learning_rate: 0.0100
# Epoch 122/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0831 - val_loss: 0.1725 - learning_rate: 0.0112
# Epoch 123/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0965 - val_loss: 0.1941 - learning_rate: 0.0126
# Epoch 124/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1043 - val_loss: 0.2133 - learning_rate: 0.0141
# Epoch 125/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1384 - val_loss: 0.1786 - learning_rate: 0.0158
# Epoch 126/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1174 - val_loss: 0.2674 - learning_rate: 0.0178
# Epoch 127/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2058 - val_loss: 0.2479 - learning_rate: 0.0200
# Epoch 128/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3017 - val_loss: 0.1254 - learning_rate: 0.0224
# Epoch 129/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2355 - val_loss: 0.4072 - learning_rate: 0.0251
# Epoch 130/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7120 - val_loss: 0.3573 - learning_rate: 0.0282
# Epoch 131/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.6194 - val_loss: 0.6183 - learning_rate: 0.0316
# Epoch 132/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9933 - val_loss: 0.4373 - learning_rate: 0.0355
# Epoch 133/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6480 - val_loss: 0.5564 - learning_rate: 0.0398
# Epoch 134/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9887 - val_loss: 0.2022 - learning_rate: 0.0447
# Epoch 135/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5319 - val_loss: 0.4950 - learning_rate: 0.0501
# Epoch 136/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0884 - val_loss: 1.0315 - learning_rate: 0.0562
# Epoch 137/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1752 - val_loss: 0.8586 - learning_rate: 0.0631
# Epoch 138/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6533 - val_loss: 0.8237 - learning_rate: 0.0708
# Epoch 139/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.3322 - val_loss: 1.3001 - learning_rate: 0.0794
# Epoch 140/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.3383 - val_loss: 0.2614 - learning_rate: 0.0891
# Epoch 141/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2147 - val_loss: 0.3892 - learning_rate: 0.1000
# Epoch 142/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8551 - val_loss: 3.1108 - learning_rate: 0.1122
# Epoch 143/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3917 - val_loss: 0.6749 - learning_rate: 0.1259
# Epoch 144/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.4823 - val_loss: 3.8960 - learning_rate: 0.1413
# Epoch 145/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.1642 - val_loss: 0.4218 - learning_rate: 0.1585
# Epoch 146/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.4348 - val_loss: 7.7634 - learning_rate: 0.1778
# Epoch 147/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.7417 - val_loss: 14.0730 - learning_rate: 0.1995
# Epoch 148/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.1924 - val_loss: 8.0377 - learning_rate: 0.2239
# Epoch 149/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.8150 - val_loss: 0.4929 - learning_rate: 0.2512
# Epoch 150/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.4461 - val_loss: 0.9488 - learning_rate: 0.2818
# Epoch 151/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.0095 - val_loss: 7.6621 - learning_rate: 0.3162
# Epoch 152/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.9178 - val_loss: 4.1874 - learning_rate: 0.3548
# Epoch 153/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.4981 - val_loss: 9.3236 - learning_rate: 0.3981
# Epoch 154/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 13.7475 - val_loss: 10.7176 - learning_rate: 0.4467
# Epoch 155/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 15.6081 - val_loss: 24.3516 - learning_rate: 0.5012
# Epoch 156/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 23.4367 - val_loss: 22.8730 - learning_rate: 0.5623
# Epoch 157/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 21.6368 - val_loss: 35.9013 - learning_rate: 0.6310
# Epoch 158/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 29.0824 - val_loss: 25.4463 - learning_rate: 0.7079
# Epoch 159/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 27.7266 - val_loss: 31.9111 - learning_rate: 0.7943
# Epoch 160/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 43.2326 - val_loss: 15.3785 - learning_rate: 0.8913
# Epoch 161/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 31.5622 - val_loss: 1.0919 - learning_rate: 1.0000
# Epoch 162/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 39.9188 - val_loss: 62.3733 - learning_rate: 1.1220
# Epoch 163/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 50.2462 - val_loss: 36.9542 - learning_rate: 1.2589
# Epoch 164/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 62.8919 - val_loss: 3.6883 - learning_rate: 1.4125
# Epoch 165/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 136.3015 - val_loss: 43.3591 - learning_rate: 1.5849
# Epoch 166/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 60.4689 - val_loss: 62.0055 - learning_rate: 1.7783
# Epoch 167/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 71.3111 - val_loss: 4.3962 - learning_rate: 1.9953
# Epoch 168/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 74.8798 - val_loss: 48.6939 - learning_rate: 2.2387
# Epoch 169/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 79.6525 - val_loss: 137.9031 - learning_rate: 2.5119
# Epoch 170/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 124.8821 - val_loss: 123.7720 - learning_rate: 2.8184
# Epoch 171/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 108.6607 - val_loss: 51.7006 - learning_rate: 3.1623
# Epoch 172/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 43.6757 - val_loss: 73.4107 - learning_rate: 3.5481
# Epoch 173/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 133.9505 - val_loss: 417.4728 - learning_rate: 3.9811
# Epoch 174/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 230.9370 - val_loss: 16.3046 - learning_rate: 4.4668
# Epoch 175/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 107.3205 - val_loss: 413.5193 - learning_rate: 5.0119
# Epoch 176/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 420.8382 - val_loss: 214.1276 - learning_rate: 5.6234
# Epoch 177/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 346.6603 - val_loss: 307.5876 - learning_rate: 6.3096
# Epoch 178/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 168.3658 - val_loss: 20.0043 - learning_rate: 7.0795
# Epoch 179/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 171.1407 - val_loss: 540.9746 - learning_rate: 7.9433
# Epoch 180/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 611.2493 - val_loss: 187.0426 - learning_rate: 8.9125
# Epoch 181/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 561.1061 - val_loss: 652.3044 - learning_rate: 10.0000
# Epoch 182/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 661.1451 - val_loss: 1275.1061 - learning_rate: 11.2202
# Epoch 183/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 941.3588 - val_loss: 823.2828 - learning_rate: 12.5893
# Epoch 184/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 949.7899 - val_loss: 199.8401 - learning_rate: 14.1254
# Epoch 185/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 296.2751 - val_loss: 199.9450 - learning_rate: 15.8489
# Epoch 186/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 370.0621 - val_loss: 186.4806 - learning_rate: 17.7828
# Epoch 187/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 628.4156 - val_loss: 1953.0244 - learning_rate: 19.9526
# Epoch 188/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1428.7217 - val_loss: 1177.6404 - learning_rate: 22.3872
# Epoch 189/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 730.7045 - val_loss: 1756.2500 - learning_rate: 25.1189
# Epoch 190/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1211.2640 - val_loss: 633.0656 - learning_rate: 28.1838
# Epoch 191/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 386.0037 - val_loss: 68.4014 - learning_rate: 31.6228
# Epoch 192/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 894.5992 - val_loss: 700.8659 - learning_rate: 35.4813
# Epoch 193/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1463.9816 - val_loss: 1892.3074 - learning_rate: 39.8107
# Epoch 194/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1758.1088 - val_loss: 667.3530 - learning_rate: 44.6684
# Epoch 195/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 955.8558 - val_loss: 3080.1851 - learning_rate: 50.1187
# Epoch 196/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1683.3754 - val_loss: 430.5382 - learning_rate: 56.2341
# Epoch 197/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3556.8381 - val_loss: 1262.2255 - learning_rate: 63.0957
# Epoch 198/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1854.7571 - val_loss: 2672.9204 - learning_rate: 70.7946
# Epoch 199/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4444.2661 - val_loss: 5927.6426 - learning_rate: 79.4328
# Epoch 200/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5385.5024 - val_loss: 8784.7324 - learning_rate: 89.1251

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(200) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the training loss in log scale
plt.semilogx(lrs, history.history["loss"], label="Training Loss")

# Plot the validation loss in log scale
plt.semilogx(lrs, history.history["val_loss"], label="Validation Loss")

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-1, 0, 1])

# Add a legend
plt.legend()

# Add labels and title
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Training and Validation Loss vs. Learning Rate")

# Show the plot
plt.show()

# %%
model_RNN=1

# %%
# Build the model
from tensorflow.keras.layers import Bidirectional, SimpleRNN, Dense
model_RNN = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size,1)),
    tf.keras.layers.SimpleRNN(50, return_sequences=True),
    tf.keras.layers.SimpleRNN(50),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1),
])

# Set the learning rate
learning_rate = 1e-3

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model_RNN.compile(loss=tf.keras.losses.Huber(),
                  optimizer=optimizer,
                  metrics=["mae"])

# EarlyStopping callback with patience
early_stopping = EarlyStopping(
    monitor="val_loss",     # Monitor validation loss
    patience=5,             # Wait 5 epochs for improvement
    mode="min",             # Stop when val_loss is minimized
    verbose=1               # Print when training stops early
)

# Train the model with EarlyStopping
history = model_RNN.fit(
    x_train_windowed,
    validation_data=x_val_windowed,
    epochs=100,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.3279 - mae: 0.6372 - val_loss: 0.2097 - val_mae: 0.5306
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2048 - mae: 0.4973 - val_loss: 0.1670 - val_mae: 0.4772
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2304 - mae: 0.5714 - val_loss: 0.1498 - val_mae: 0.4391
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1761 - mae: 0.4438 - val_loss: 0.1294 - val_mae: 0.3971
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1648 - mae: 0.4420 - val_loss: 0.1328 - val_mae: 0.4000
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1561 - mae: 0.3970 - val_loss: 0.1245 - val_mae: 0.3849
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1495 - mae: 0.4117 - val_loss: 0.1294 - val_mae: 0.3941
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1470 - mae: 0.3869 - val_loss: 0.1208 - val_mae: 0.3777
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1420 - mae: 0.3963 - val_loss: 0.1230 - val_mae: 0.3783
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1385 - mae: 0.3655 - val_loss: 0.1167 - val_mae: 0.3669
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1342 - mae: 0.3756 - val_loss: 0.1185 - val_mae: 0.3666
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1321 - mae: 0.3523 - val_loss: 0.1153 - val_mae: 0.3626
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1296 - mae: 0.3646 - val_loss: 0.1161 - val_mae: 0.3602
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1278 - mae: 0.3462 - val_loss: 0.1147 - val_mae: 0.3606
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1261 - mae: 0.3561 - val_loss: 0.1150 - val_mae: 0.3580
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1245 - mae: 0.3429 - val_loss: 0.1144 - val_mae: 0.3596
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1232 - mae: 0.3493 - val_loss: 0.1144 - val_mae: 0.3573
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1217 - mae: 0.3399 - val_loss: 0.1142 - val_mae: 0.3592
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1206 - mae: 0.3436 - val_loss: 0.1141 - val_mae: 0.3572
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1191 - mae: 0.3364 - val_loss: 0.1142 - val_mae: 0.3591
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1181 - mae: 0.3385 - val_loss: 0.1141 - val_mae: 0.3578
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1167 - mae: 0.3328 - val_loss: 0.1142 - val_mae: 0.3594
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1157 - mae: 0.3339 - val_loss: 0.1142 - val_mae: 0.3585
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1144 - mae: 0.3291 - val_loss: 0.1144 - val_mae: 0.3600
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1134 - mae: 0.3294 - val_loss: 0.1144 - val_mae: 0.3595
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1122 - mae: 0.3254 - val_loss: 0.1148 - val_mae: 0.3610
# Epoch 26: early stopping

# %%
# Initialize a list
forecast = []

# Use the model to predict data points per window size
for time in range(len(grouped_df0)-split2-window_size):
  forecast.append(model_RNN.predict(x_test_scaled[time:time + window_size][np.newaxis], verbose=0))

# Slice the points that are aligned with the validation set
#forecast = forecast[split_time - window_size:]

# Compare number of elements in the predictions and the validation set
print(f'length of the forecast list: {len(forecast)}')
print(f'shape of the validation set: {x_test.shape}')
# Out:
# length of the forecast list: 564
# shape of the validation set: (594,)

# %%
# Preview shapes after using the conversion and squeeze methods
print(f'shape after converting to numpy array: {np.array(forecast).shape}')
print(f'shape after squeezing: {np.array(forecast).squeeze().shape}')

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()
# Out:
# shape after converting to numpy array: (564, 1, 1)
# shape after squeezing: (564,)

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)), label='True Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(results_reshaped), label='Predicted', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
true_values = x_test_scaled_df.values[30:].reshape(-1, 1)
predicted_values = results_reshaped

print("MSE:", mse(true_values, predicted_values).numpy())
print("MAE:", mae(true_values, predicted_values).numpy())

rnn_mse = mse(true_values, predicted_values).numpy()
rnn_mae = mae(true_values, predicted_values).numpy()
# Out:
# MSE: 0.5331561
# MAE: 0.50984085

# %% [markdown]
# #LSTM

# %%
# Build the Model
model_tune1 = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
])

# Print the model summary
model_tune1.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)        │ (None, 30, 64)              │           8,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 30, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 64)                  │          24,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 33,601 (131.25 KB)
#  Trainable params: 33,601 (131.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune1.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model_tune1.fit(x_train_windowed, validation_data=x_val_windowed, epochs=200, callbacks=[lr_schedule])
# Out:
# Epoch 1/200
#      10/Unknown 6s 75ms/step - loss: 0.5014
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 195ms/step - loss: 0.4904 - val_loss: 0.3236 - learning_rate: 1.0000e-08
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - loss: 0.4893 - val_loss: 0.3236 - learning_rate: 1.1220e-08
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.4887 - val_loss: 0.3236 - learning_rate: 1.2589e-08
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4885 - val_loss: 0.3236 - learning_rate: 1.4125e-08
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4881 - val_loss: 0.3236 - learning_rate: 1.5849e-08
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.4860 - val_loss: 0.3236 - learning_rate: 1.7783e-08
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - loss: 0.4884 - val_loss: 0.3236 - learning_rate: 1.9953e-08
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4883 - val_loss: 0.3236 - learning_rate: 2.2387e-08
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.4882 - val_loss: 0.3236 - learning_rate: 2.5119e-08
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - loss: 0.4884 - val_loss: 0.3236 - learning_rate: 2.8184e-08
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4874 - val_loss: 0.3236 - learning_rate: 3.1623e-08
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4876 - val_loss: 0.3236 - learning_rate: 3.5481e-08
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.4892 - val_loss: 0.3236 - learning_rate: 3.9811e-08
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.4889 - val_loss: 0.3236 - learning_rate: 4.4668e-08
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.4879 - val_loss: 0.3236 - learning_rate: 5.0119e-08
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - loss: 0.4876 - val_loss: 0.3236 - learning_rate: 5.6234e-08
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - loss: 0.4897 - val_loss: 0.3236 - learning_rate: 6.3096e-08
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.4886 - val_loss: 0.3236 - learning_rate: 7.0795e-08
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.4864 - val_loss: 0.3236 - learning_rate: 7.9433e-08
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4867 - val_loss: 0.3236 - learning_rate: 8.9125e-08
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.4885 - val_loss: 0.3236 - learning_rate: 1.0000e-07
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4878 - val_loss: 0.3236 - learning_rate: 1.1220e-07
# Epoch 23/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4881 - val_loss: 0.3236 - learning_rate: 1.2589e-07
# Epoch 24/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.4884 - val_loss: 0.3236 - learning_rate: 1.4125e-07
# Epoch 25/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.4887 - val_loss: 0.3236 - learning_rate: 1.5849e-07
# Epoch 26/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.4887 - val_loss: 0.3236 - learning_rate: 1.7783e-07
# Epoch 27/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4886 - val_loss: 0.3236 - learning_rate: 1.9953e-07
# Epoch 28/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4888 - val_loss: 0.3236 - learning_rate: 2.2387e-07
# Epoch 29/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4882 - val_loss: 0.3236 - learning_rate: 2.5119e-07
# Epoch 30/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4878 - val_loss: 0.3235 - learning_rate: 2.8184e-07
# Epoch 31/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4870 - val_loss: 0.3235 - learning_rate: 3.1623e-07
# Epoch 32/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4891 - val_loss: 0.3235 - learning_rate: 3.5481e-07
# Epoch 33/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4894 - val_loss: 0.3235 - learning_rate: 3.9811e-07
# Epoch 34/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4886 - val_loss: 0.3235 - learning_rate: 4.4668e-07
# Epoch 35/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4889 - val_loss: 0.3235 - learning_rate: 5.0119e-07
# Epoch 36/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4891 - val_loss: 0.3235 - learning_rate: 5.6234e-07
# Epoch 37/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4884 - val_loss: 0.3234 - learning_rate: 6.3096e-07
# Epoch 38/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4885 - val_loss: 0.3234 - learning_rate: 7.0795e-07
# Epoch 39/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4863 - val_loss: 0.3234 - learning_rate: 7.9433e-07
# Epoch 40/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4888 - val_loss: 0.3234 - learning_rate: 8.9125e-07
# Epoch 41/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4895 - val_loss: 0.3233 - learning_rate: 1.0000e-06
# Epoch 42/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4870 - val_loss: 0.3233 - learning_rate: 1.1220e-06
# Epoch 43/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.4872 - val_loss: 0.3232 - learning_rate: 1.2589e-06
# Epoch 44/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4875 - val_loss: 0.3232 - learning_rate: 1.4125e-06
# Epoch 45/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.4880 - val_loss: 0.3231 - learning_rate: 1.5849e-06
# Epoch 46/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4867 - val_loss: 0.3231 - learning_rate: 1.7783e-06
# Epoch 47/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4876 - val_loss: 0.3230 - learning_rate: 1.9953e-06
# Epoch 48/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.4869 - val_loss: 0.3229 - learning_rate: 2.2387e-06
# Epoch 49/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4880 - val_loss: 0.3228 - learning_rate: 2.5119e-06
# Epoch 50/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4881 - val_loss: 0.3227 - learning_rate: 2.8184e-06
# Epoch 51/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4870 - val_loss: 0.3226 - learning_rate: 3.1623e-06
# Epoch 52/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.4866 - val_loss: 0.3225 - learning_rate: 3.5481e-06
# Epoch 53/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.4879 - val_loss: 0.3224 - learning_rate: 3.9811e-06
# Epoch 54/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.4861 - val_loss: 0.3222 - learning_rate: 4.4668e-06
# Epoch 55/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4854 - val_loss: 0.3221 - learning_rate: 5.0119e-06
# Epoch 56/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4868 - val_loss: 0.3219 - learning_rate: 5.6234e-06
# Epoch 57/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4856 - val_loss: 0.3216 - learning_rate: 6.3096e-06
# Epoch 58/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.4855 - val_loss: 0.3214 - learning_rate: 7.0795e-06
# Epoch 59/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4855 - val_loss: 0.3211 - learning_rate: 7.9433e-06
# Epoch 60/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4849 - val_loss: 0.3208 - learning_rate: 8.9125e-06
# Epoch 61/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4859 - val_loss: 0.3205 - learning_rate: 1.0000e-05
# Epoch 62/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4850 - val_loss: 0.3201 - learning_rate: 1.1220e-05
# Epoch 63/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.4840 - val_loss: 0.3197 - learning_rate: 1.2589e-05
# Epoch 64/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.4842 - val_loss: 0.3192 - learning_rate: 1.4125e-05
# Epoch 65/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4835 - val_loss: 0.3186 - learning_rate: 1.5849e-05
# Epoch 66/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.4825 - val_loss: 0.3180 - learning_rate: 1.7783e-05
# Epoch 67/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4804 - val_loss: 0.3174 - learning_rate: 1.9953e-05
# Epoch 68/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4800 - val_loss: 0.3166 - learning_rate: 2.2387e-05
# Epoch 69/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4804 - val_loss: 0.3158 - learning_rate: 2.5119e-05
# Epoch 70/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4770 - val_loss: 0.3148 - learning_rate: 2.8184e-05
# Epoch 71/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4777 - val_loss: 0.3137 - learning_rate: 3.1623e-05
# Epoch 72/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4752 - val_loss: 0.3125 - learning_rate: 3.5481e-05
# Epoch 73/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4729 - val_loss: 0.3112 - learning_rate: 3.9811e-05
# Epoch 74/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.4719 - val_loss: 0.3097 - learning_rate: 4.4668e-05
# Epoch 75/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4708 - val_loss: 0.3081 - learning_rate: 5.0119e-05
# Epoch 76/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4685 - val_loss: 0.3062 - learning_rate: 5.6234e-05
# Epoch 77/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4675 - val_loss: 0.3042 - learning_rate: 6.3096e-05
# Epoch 78/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4617 - val_loss: 0.3019 - learning_rate: 7.0795e-05
# Epoch 79/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4593 - val_loss: 0.2993 - learning_rate: 7.9433e-05
# Epoch 80/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4564 - val_loss: 0.2965 - learning_rate: 8.9125e-05
# Epoch 81/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.4530 - val_loss: 0.2933 - learning_rate: 1.0000e-04
# Epoch 82/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.4475 - val_loss: 0.2898 - learning_rate: 1.1220e-04
# Epoch 83/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.4429 - val_loss: 0.2860 - learning_rate: 1.2589e-04
# Epoch 84/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.4379 - val_loss: 0.2817 - learning_rate: 1.4125e-04
# Epoch 85/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4330 - val_loss: 0.2770 - learning_rate: 1.5849e-04
# Epoch 86/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.4259 - val_loss: 0.2718 - learning_rate: 1.7783e-04
# Epoch 87/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4189 - val_loss: 0.2661 - learning_rate: 1.9953e-04
# Epoch 88/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4114 - val_loss: 0.2598 - learning_rate: 2.2387e-04
# Epoch 89/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4037 - val_loss: 0.2530 - learning_rate: 2.5119e-04
# Epoch 90/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.3932 - val_loss: 0.2457 - learning_rate: 2.8184e-04
# Epoch 91/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.3832 - val_loss: 0.2377 - learning_rate: 3.1623e-04
# Epoch 92/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.3712 - val_loss: 0.2292 - learning_rate: 3.5481e-04
# Epoch 93/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.3602 - val_loss: 0.2201 - learning_rate: 3.9811e-04
# Epoch 94/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.3460 - val_loss: 0.2106 - learning_rate: 4.4668e-04
# Epoch 95/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.3322 - val_loss: 0.2008 - learning_rate: 5.0119e-04
# Epoch 96/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.3191 - val_loss: 0.1908 - learning_rate: 5.6234e-04
# Epoch 97/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.3041 - val_loss: 0.1811 - learning_rate: 6.3096e-04
# Epoch 98/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2881 - val_loss: 0.1717 - learning_rate: 7.0795e-04
# Epoch 99/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2732 - val_loss: 0.1632 - learning_rate: 7.9433e-04
# Epoch 100/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2594 - val_loss: 0.1556 - learning_rate: 8.9125e-04
# Epoch 101/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2459 - val_loss: 0.1492 - learning_rate: 0.0010
# Epoch 102/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.2333 - val_loss: 0.1440 - learning_rate: 0.0011
# Epoch 103/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.2229 - val_loss: 0.1397 - learning_rate: 0.0013
# Epoch 104/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.2143 - val_loss: 0.1362 - learning_rate: 0.0014
# Epoch 105/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2073 - val_loss: 0.1332 - learning_rate: 0.0016
# Epoch 106/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2014 - val_loss: 0.1304 - learning_rate: 0.0018
# Epoch 107/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1958 - val_loss: 0.1275 - learning_rate: 0.0020
# Epoch 108/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1904 - val_loss: 0.1246 - learning_rate: 0.0022
# Epoch 109/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1861 - val_loss: 0.1215 - learning_rate: 0.0025
# Epoch 110/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1816 - val_loss: 0.1185 - learning_rate: 0.0028
# Epoch 111/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1784 - val_loss: 0.1154 - learning_rate: 0.0032
# Epoch 112/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1733 - val_loss: 0.1124 - learning_rate: 0.0035
# Epoch 113/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1705 - val_loss: 0.1097 - learning_rate: 0.0040
# Epoch 114/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1653 - val_loss: 0.1072 - learning_rate: 0.0045
# Epoch 115/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1642 - val_loss: 0.1049 - learning_rate: 0.0050
# Epoch 116/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1598 - val_loss: 0.1031 - learning_rate: 0.0056
# Epoch 117/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1579 - val_loss: 0.1017 - learning_rate: 0.0063
# Epoch 118/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1569 - val_loss: 0.1006 - learning_rate: 0.0071
# Epoch 119/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1544 - val_loss: 0.0999 - learning_rate: 0.0079
# Epoch 120/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1521 - val_loss: 0.0992 - learning_rate: 0.0089
# Epoch 121/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.1504 - val_loss: 0.0992 - learning_rate: 0.0100
# Epoch 122/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.1522 - val_loss: 0.0990 - learning_rate: 0.0112
# Epoch 123/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.1493 - val_loss: 0.0992 - learning_rate: 0.0126
# Epoch 124/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1510 - val_loss: 0.0990 - learning_rate: 0.0141
# Epoch 125/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1483 - val_loss: 0.0998 - learning_rate: 0.0158
# Epoch 126/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1507 - val_loss: 0.0990 - learning_rate: 0.0178
# Epoch 127/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1475 - val_loss: 0.1022 - learning_rate: 0.0200
# Epoch 128/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1530 - val_loss: 0.1005 - learning_rate: 0.0224
# Epoch 129/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1475 - val_loss: 0.1188 - learning_rate: 0.0251
# Epoch 130/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1729 - val_loss: 0.1451 - learning_rate: 0.0282
# Epoch 131/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1788 - val_loss: 0.3084 - learning_rate: 0.0316
# Epoch 132/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4066 - val_loss: 0.1461 - learning_rate: 0.0355
# Epoch 133/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2027 - val_loss: 0.1551 - learning_rate: 0.0398
# Epoch 134/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2691 - val_loss: 0.1146 - learning_rate: 0.0447
# Epoch 135/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1789 - val_loss: 0.1159 - learning_rate: 0.0501
# Epoch 136/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1504 - val_loss: 0.1974 - learning_rate: 0.0562
# Epoch 137/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2501 - val_loss: 0.2363 - learning_rate: 0.0631
# Epoch 138/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2318 - val_loss: 0.3445 - learning_rate: 0.0708
# Epoch 139/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4786 - val_loss: 0.1615 - learning_rate: 0.0794
# Epoch 140/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.2243 - val_loss: 0.1910 - learning_rate: 0.0891
# Epoch 141/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.2190 - val_loss: 0.1644 - learning_rate: 0.1000
# Epoch 142/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.1808 - val_loss: 0.4468 - learning_rate: 0.1122
# Epoch 143/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.5144 - val_loss: 0.1015 - learning_rate: 0.1259
# Epoch 144/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2404 - val_loss: 0.2948 - learning_rate: 0.1413
# Epoch 145/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.5047 - val_loss: 0.3552 - learning_rate: 0.1585
# Epoch 146/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.3457 - val_loss: 0.8248 - learning_rate: 0.1778
# Epoch 147/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.5857 - val_loss: 0.4785 - learning_rate: 0.1995
# Epoch 148/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.9499 - val_loss: 0.5082 - learning_rate: 0.2239
# Epoch 149/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.7673 - val_loss: 0.3893 - learning_rate: 0.2512
# Epoch 150/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.8106 - val_loss: 0.2620 - learning_rate: 0.2818
# Epoch 151/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.6048 - val_loss: 0.4424 - learning_rate: 0.3162
# Epoch 152/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.0421 - val_loss: 2.1743 - learning_rate: 0.3548
# Epoch 153/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 1.6397 - val_loss: 1.1744 - learning_rate: 0.3981
# Epoch 154/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.1864 - val_loss: 1.6278 - learning_rate: 0.4467
# Epoch 155/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.4019 - val_loss: 1.5011 - learning_rate: 0.5012
# Epoch 156/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 1.4599 - val_loss: 2.4862 - learning_rate: 0.5623
# Epoch 157/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.5805 - val_loss: 0.5193 - learning_rate: 0.6310
# Epoch 158/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.3327 - val_loss: 2.5130 - learning_rate: 0.7079
# Epoch 159/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.2659 - val_loss: 4.0085 - learning_rate: 0.7943
# Epoch 160/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 2.7268 - val_loss: 2.3129 - learning_rate: 0.8913
# Epoch 161/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 2.0171 - val_loss: 1.3231 - learning_rate: 1.0000
# Epoch 162/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 2.0293 - val_loss: 1.4903 - learning_rate: 1.1220
# Epoch 163/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.3233 - val_loss: 1.6147 - learning_rate: 1.2589
# Epoch 164/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.0794 - val_loss: 1.3204 - learning_rate: 1.4125
# Epoch 165/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.2323 - val_loss: 1.4126 - learning_rate: 1.5849
# Epoch 166/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.7570 - val_loss: 2.0383 - learning_rate: 1.7783
# Epoch 167/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.8184 - val_loss: 0.4417 - learning_rate: 1.9953
# Epoch 168/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.4284 - val_loss: 1.1172 - learning_rate: 2.2387
# Epoch 169/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1.8747 - val_loss: 1.2995 - learning_rate: 2.5119
# Epoch 170/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.1045 - val_loss: 2.1092 - learning_rate: 2.8184
# Epoch 171/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.2612 - val_loss: 3.9638 - learning_rate: 3.1623
# Epoch 172/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3.8081 - val_loss: 2.4198 - learning_rate: 3.5481
# Epoch 173/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.1139 - val_loss: 0.9993 - learning_rate: 3.9811
# Epoch 174/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.1628 - val_loss: 3.2321 - learning_rate: 4.4668
# Epoch 175/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 2.1211 - val_loss: 3.3125 - learning_rate: 5.0119
# Epoch 176/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.3685 - val_loss: 2.5483 - learning_rate: 5.6234
# Epoch 177/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.4142 - val_loss: 4.5645 - learning_rate: 6.3096
# Epoch 178/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 3.9162 - val_loss: 0.2848 - learning_rate: 7.0795
# Epoch 179/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.8536 - val_loss: 4.8388 - learning_rate: 7.9433
# Epoch 180/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 4.6363 - val_loss: 3.1651 - learning_rate: 8.9125
# Epoch 181/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 3.4951 - val_loss: 0.3473 - learning_rate: 10.0000
# Epoch 182/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.4925 - val_loss: 22.6782 - learning_rate: 11.2202
# Epoch 183/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 10.3324 - val_loss: 10.9771 - learning_rate: 12.5893
# Epoch 184/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 7.2246 - val_loss: 28.2115 - learning_rate: 14.1254
# Epoch 185/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 14.0745 - val_loss: 19.7727 - learning_rate: 15.8489
# Epoch 186/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 23.3097 - val_loss: 11.3349 - learning_rate: 17.7828
# Epoch 187/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 16.2235 - val_loss: 6.0315 - learning_rate: 19.9526
# Epoch 188/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 18.8675 - val_loss: 33.7094 - learning_rate: 22.3872
# Epoch 189/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 25.3642 - val_loss: 1.8189 - learning_rate: 25.1189
# Epoch 190/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 14.0253 - val_loss: 56.7581 - learning_rate: 28.1838
# Epoch 191/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 57.1699 - val_loss: 28.9131 - learning_rate: 31.6228
# Epoch 192/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 47.4167 - val_loss: 41.6849 - learning_rate: 35.4813
# Epoch 193/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 22.2275 - val_loss: 1.8122 - learning_rate: 39.8107
# Epoch 194/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 22.5669 - val_loss: 77.4829 - learning_rate: 44.6684
# Epoch 195/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 84.8728 - val_loss: 31.3525 - learning_rate: 50.1187
# Epoch 196/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 76.3861 - val_loss: 81.7500 - learning_rate: 56.2341
# Epoch 197/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 89.2036 - val_loss: 181.6590 - learning_rate: 63.0957
# Epoch 198/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 130.7778 - val_loss: 104.8097 - learning_rate: 70.7946
# Epoch 199/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 126.5141 - val_loss: 35.6203 - learning_rate: 79.4328
# Epoch 200/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 42.5390 - val_loss: 17.1321 - learning_rate: 89.1251

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(200) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the training loss in log scale
plt.semilogx(lrs, history.history["loss"], label="Training Loss")

# Plot the validation loss in log scale
plt.semilogx(lrs, history.history["val_loss"], label="Validation Loss")

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-1, 0, 1])

# Add a legend
plt.legend()

# Add labels and title
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Training and Validation Loss vs. Learning Rate")

# Show the plot
plt.show()

# %% [raw]
# model_LSTM=1

# %%
# Reset states generated by Keras
#tf.keras.backend.clear_session()

# Build the model
model_LSTM = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
])

# Set the learning rate
learning_rate = 1e-3

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model_LSTM.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# EarlyStopping callback with patience
early_stopping = EarlyStopping(
    monitor="val_loss",     # Monitor validation loss
    patience=5,             # Wait 5 epochs for improvement
    mode="min",             # Stop when val_loss is minimized
    verbose=1               # Print when training stops early
)

# Train the model with EarlyStopping
history = model_LSTM.fit(
    x_train_windowed,
    validation_data=x_val_windowed,
    epochs=100,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - loss: 0.4152 - mae: 0.7787 - val_loss: 0.2464 - val_mae: 0.5795
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.3796 - mae: 0.7401 - val_loss: 0.2207 - val_mae: 0.5494
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.3430 - mae: 0.6988 - val_loss: 0.1993 - val_mae: 0.5222
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.3117 - mae: 0.6636 - val_loss: 0.1829 - val_mae: 0.5020
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2866 - mae: 0.6338 - val_loss: 0.1711 - val_mae: 0.4873
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2673 - mae: 0.6094 - val_loss: 0.1627 - val_mae: 0.4754
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.2530 - mae: 0.5906 - val_loss: 0.1569 - val_mae: 0.4662
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.2424 - mae: 0.5763 - val_loss: 0.1526 - val_mae: 0.4590
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.2344 - mae: 0.5653 - val_loss: 0.1492 - val_mae: 0.4526
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.2282 - mae: 0.5564 - val_loss: 0.1464 - val_mae: 0.4473
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2231 - mae: 0.5486 - val_loss: 0.1439 - val_mae: 0.4427
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.2188 - mae: 0.5419 - val_loss: 0.1416 - val_mae: 0.4384
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2149 - mae: 0.5360 - val_loss: 0.1394 - val_mae: 0.4344
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2115 - mae: 0.5305 - val_loss: 0.1374 - val_mae: 0.4307
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2083 - mae: 0.5254 - val_loss: 0.1354 - val_mae: 0.4272
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2054 - mae: 0.5205 - val_loss: 0.1336 - val_mae: 0.4238
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2027 - mae: 0.5159 - val_loss: 0.1318 - val_mae: 0.4205
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2001 - mae: 0.5116 - val_loss: 0.1301 - val_mae: 0.4173
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1977 - mae: 0.5075 - val_loss: 0.1285 - val_mae: 0.4143
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1954 - mae: 0.5035 - val_loss: 0.1270 - val_mae: 0.4113
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1933 - mae: 0.4997 - val_loss: 0.1255 - val_mae: 0.4085
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1912 - mae: 0.4960 - val_loss: 0.1241 - val_mae: 0.4057
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1893 - mae: 0.4925 - val_loss: 0.1228 - val_mae: 0.4031
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1874 - mae: 0.4891 - val_loss: 0.1215 - val_mae: 0.4006
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1857 - mae: 0.4858 - val_loss: 0.1203 - val_mae: 0.3981
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1840 - mae: 0.4825 - val_loss: 0.1191 - val_mae: 0.3957
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.1824 - mae: 0.4794 - val_loss: 0.1181 - val_mae: 0.3934
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.1809 - mae: 0.4764 - val_loss: 0.1170 - val_mae: 0.3911
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.1794 - mae: 0.4735 - val_loss: 0.1160 - val_mae: 0.3889
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1780 - mae: 0.4707 - val_loss: 0.1151 - val_mae: 0.3867
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1767 - mae: 0.4680 - val_loss: 0.1142 - val_mae: 0.3845
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1754 - mae: 0.4654 - val_loss: 0.1133 - val_mae: 0.3824
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1742 - mae: 0.4629 - val_loss: 0.1125 - val_mae: 0.3804
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1731 - mae: 0.4605 - val_loss: 0.1118 - val_mae: 0.3784
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1720 - mae: 0.4580 - val_loss: 0.1111 - val_mae: 0.3766
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1710 - mae: 0.4557 - val_loss: 0.1104 - val_mae: 0.3748
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1700 - mae: 0.4534 - val_loss: 0.1097 - val_mae: 0.3731
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1690 - mae: 0.4512 - val_loss: 0.1091 - val_mae: 0.3714
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1681 - mae: 0.4491 - val_loss: 0.1085 - val_mae: 0.3697
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1672 - mae: 0.4471 - val_loss: 0.1080 - val_mae: 0.3682
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1664 - mae: 0.4451 - val_loss: 0.1074 - val_mae: 0.3666
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1656 - mae: 0.4432 - val_loss: 0.1069 - val_mae: 0.3652
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1649 - mae: 0.4414 - val_loss: 0.1065 - val_mae: 0.3638
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1642 - mae: 0.4396 - val_loss: 0.1060 - val_mae: 0.3624
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1635 - mae: 0.4378 - val_loss: 0.1056 - val_mae: 0.3611
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.1628 - mae: 0.4362 - val_loss: 0.1052 - val_mae: 0.3599
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.1622 - mae: 0.4345 - val_loss: 0.1048 - val_mae: 0.3588
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.1616 - mae: 0.4329 - val_loss: 0.1045 - val_mae: 0.3577
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.1610 - mae: 0.4314 - val_loss: 0.1041 - val_mae: 0.3567
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1605 - mae: 0.4299 - val_loss: 0.1038 - val_mae: 0.3556
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1600 - mae: 0.4285 - val_loss: 0.1035 - val_mae: 0.3547
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1595 - mae: 0.4272 - val_loss: 0.1032 - val_mae: 0.3537
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1590 - mae: 0.4259 - val_loss: 0.1030 - val_mae: 0.3529
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1585 - mae: 0.4246 - val_loss: 0.1027 - val_mae: 0.3520
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1581 - mae: 0.4233 - val_loss: 0.1025 - val_mae: 0.3512
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1577 - mae: 0.4221 - val_loss: 0.1023 - val_mae: 0.3504
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1573 - mae: 0.4210 - val_loss: 0.1021 - val_mae: 0.3496
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1569 - mae: 0.4198 - val_loss: 0.1019 - val_mae: 0.3489
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1565 - mae: 0.4188 - val_loss: 0.1017 - val_mae: 0.3481
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1562 - mae: 0.4177 - val_loss: 0.1015 - val_mae: 0.3474
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1558 - mae: 0.4167 - val_loss: 0.1013 - val_mae: 0.3468
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1555 - mae: 0.4156 - val_loss: 0.1012 - val_mae: 0.3461
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1552 - mae: 0.4147 - val_loss: 0.1010 - val_mae: 0.3454
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1549 - mae: 0.4137 - val_loss: 0.1009 - val_mae: 0.3448
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1546 - mae: 0.4128 - val_loss: 0.1007 - val_mae: 0.3442
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.1544 - mae: 0.4119 - val_loss: 0.1006 - val_mae: 0.3436
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.1541 - mae: 0.4110 - val_loss: 0.1005 - val_mae: 0.3430
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.1538 - mae: 0.4102 - val_loss: 0.1004 - val_mae: 0.3425
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.1536 - mae: 0.4094 - val_loss: 0.1003 - val_mae: 0.3419
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1534 - mae: 0.4087 - val_loss: 0.1002 - val_mae: 0.3414
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1531 - mae: 0.4080 - val_loss: 0.1001 - val_mae: 0.3409
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1529 - mae: 0.4073 - val_loss: 0.1000 - val_mae: 0.3404
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1527 - mae: 0.4066 - val_loss: 0.0999 - val_mae: 0.3399
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1525 - mae: 0.4059 - val_loss: 0.0999 - val_mae: 0.3394
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1523 - mae: 0.4052 - val_loss: 0.0998 - val_mae: 0.3389
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1521 - mae: 0.4046 - val_loss: 0.0997 - val_mae: 0.3385
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1520 - mae: 0.4040 - val_loss: 0.0996 - val_mae: 0.3381
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1518 - mae: 0.4034 - val_loss: 0.0996 - val_mae: 0.3377
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1516 - mae: 0.4028 - val_loss: 0.0995 - val_mae: 0.3373
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1515 - mae: 0.4022 - val_loss: 0.0995 - val_mae: 0.3369
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1513 - mae: 0.4017 - val_loss: 0.0994 - val_mae: 0.3365
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1511 - mae: 0.4011 - val_loss: 0.0994 - val_mae: 0.3362
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1510 - mae: 0.4006 - val_loss: 0.0993 - val_mae: 0.3358
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1509 - mae: 0.4001 - val_loss: 0.0993 - val_mae: 0.3355
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1507 - mae: 0.3996 - val_loss: 0.0992 - val_mae: 0.3352
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.1506 - mae: 0.3991 - val_loss: 0.0992 - val_mae: 0.3349
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.1504 - mae: 0.3987 - val_loss: 0.0991 - val_mae: 0.3346
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.1503 - mae: 0.3982 - val_loss: 0.0991 - val_mae: 0.3344
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1502 - mae: 0.3978 - val_loss: 0.0991 - val_mae: 0.3341
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1501 - mae: 0.3974 - val_loss: 0.0990 - val_mae: 0.3338
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1500 - mae: 0.3970 - val_loss: 0.0990 - val_mae: 0.3336
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1498 - mae: 0.3966 - val_loss: 0.0990 - val_mae: 0.3334
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1497 - mae: 0.3962 - val_loss: 0.0989 - val_mae: 0.3332
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1496 - mae: 0.3958 - val_loss: 0.0989 - val_mae: 0.3329
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1495 - mae: 0.3954 - val_loss: 0.0989 - val_mae: 0.3327
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1494 - mae: 0.3951 - val_loss: 0.0989 - val_mae: 0.3325
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.1493 - mae: 0.3947 - val_loss: 0.0988 - val_mae: 0.3323
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1492 - mae: 0.3944 - val_loss: 0.0988 - val_mae: 0.3321
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1491 - mae: 0.3941 - val_loss: 0.0988 - val_mae: 0.3319
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1490 - mae: 0.3938 - val_loss: 0.0988 - val_mae: 0.3317

# %%
type(x_test_scaled)
# Out:
# numpy.ndarray

# %%
# Initialize a list
forecast = []

# Use the model to predict data points per window size
for time in range(len(grouped_df0)-split2-window_size):
  forecast.append(model_LSTM.predict(x_test_scaled[time:time + window_size][np.newaxis], verbose=0))

# Slice the points that are aligned with the validation set
#forecast = forecast[split_time - window_size:]

# Compare number of elements in the predictions and the validation set
print(f'length of the forecast list: {len(forecast)}')
print(f'shape of the validation set: {x_test.shape}')
# Out:
# length of the forecast list: 564
# shape of the validation set: (594,)

# %%
# Preview shapes after using the conversion and squeeze methods
print(f'shape after converting to numpy array: {np.array(forecast).shape}')
print(f'shape after squeezing: {np.array(forecast).squeeze().shape}')

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()
# Out:
# shape after converting to numpy array: (564, 1, 1)
# shape after squeezing: (564,)

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)), label='True Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(results_reshaped), label='Predicted', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
import plotly.express as px
import pandas as pd

# Prepare a DataFrame for Plotly
plot_df = pd.DataFrame({
    'Price Date': x_test_scaled_df.index[30:],
    'True Value': scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)).flatten(),
    'Predicted': scaler.inverse_transform(results.reshape(-1, 1)).flatten()
})

# Create an interactive plot
fig = px.line(
    plot_df,
    x='Price Date',
    y=['True Value', 'Predicted'],
    labels={'value': 'Modal Price (Rs./Quintal)', 'variable': 'Legend'},
    title='Modal Price Over Time'
)

# Update layout for better aesthetics
fig.update_layout(
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="573ff984-2254-42b2-aa36-ad45e77e97b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("573ff984-2254-42b2-aa36-ad45e77e97b9")) {                    Plotly.newPlot(                        "573ff984-2254-42b2-aa36-ad45e77e97b9",                        [{"hovertemplate":"Legend=True Value\u003cbr\u003ePrice Date=%{x}\u003cbr\u003eModal Price (Rs.\u002fQuintal)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True Value","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"True Value","showlegend":true,"x":["2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-04-29T00:00:00","2023-04-30T00:00:00","2023-05-01T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-06T00:00:00","2023-05-07T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-13T00:00:00","2023-05-14T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-20T00:00:00","2023-05-21T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-27T00:00:00","2023-05-28T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-03T00:00:00","2023-06-04T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-10T00:00:00","2023-06-11T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-17T00:00:00","2023-06-18T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-24T00:00:00","2023-06-25T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-29T00:00:00","2023-06-30T00:00:00","2023-07-01T00:00:00","2023-07-02T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00","2023-08-18T00:00:00","2023-08-19T00:00:00","2023-08-21T00:00:00","2023-08-22T00:00:00","2023-08-23T00:00:00","2023-08-24T00:00:00","2023-08-25T00:00:00","2023-08-26T00:00:00","2023-08-27T00:00:00","2023-08-28T00:00:00","2023-08-29T00:00:00"," ...

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
true_values = x_test_scaled_df.values[30:].reshape(-1, 1)
predicted_values = results_reshaped

print("MSE:", mse(true_values, predicted_values).numpy())
print("MAE:", mae(true_values, predicted_values).numpy())

lstm_mse = mse(true_values, predicted_values).numpy()
lstm_mae = mae(true_values, predicted_values).numpy()
# Out:
# MSE: 0.7635378
# MAE: 0.6280214

# %%
model_name = ['rnn', 'lstm']
lst_mse = [rnn_mse, lstm_mse]
lst_mae = [rnn_mae, lstm_mae]

for i in range(len(model_name)):
    print(f'MSE dari {model_name[i]} adalah {lst_mse[i]}')
    print(f'MAE dari {model_name[i]} adalah {lst_mae[i]}')

smallest_mse = np.argmin(lst_mse)
smallest_mae = np.argmin(lst_mae)

print(f'Model terbaik adalah {model_name[smallest_mse]} berdasarkan MSE terkecil')
print(f'Model terbaik adalah {model_name[smallest_mae]} berdasarkan MAE terkecil')
# Out:
# MSE dari rnn adalah 0.5331560969352722
# MAE dari rnn adalah 0.5098408460617065
# MSE dari lstm adalah 0.7635378241539001
# MAE dari lstm adalah 0.6280214190483093
# Model terbaik adalah rnn berdasarkan MSE terkecil
# Model terbaik adalah rnn berdasarkan MAE terkecil

# %% [markdown]
# Forecast

# %%
numpy_grouped_df=grouped_df0.to_numpy()

# %%
numpy_grouped_df_scaled = scaler.transform(numpy_grouped_df.reshape(-1,1))

# %%
days = 240

# %%
len(numpy_grouped_df)/240
# Out:
# 5.475

# %% [markdown]
# Plot ulang RNN

# %%
# Initialize lists for forecast
days = 240
forecast = []
result_forecast = numpy_grouped_df_scaled[-240:].tolist()  # Use the last 30 values as the starting point

# Flatten result_forecast if it contains nested lists
# Assuming numpy_grouped_df_scaled[-30:] is a 2D array or list of lists
result_forecast = [item[0] if isinstance(item, list) else float(item) for item in result_forecast]

# Forecast for 365 days
for _ in range(days):
    # Prepare input for the model
    input_data = np.array(result_forecast[-240:]).reshape(1, 240, 1)  # Reshape correctly

    # Predict and extract the scalar value
    prediksi = model_RNN.predict(input_data)[0][0]  # Extract scalar from prediction array

    # Append the prediction
    forecast.append(prediksi)  # For final forecast output
    result_forecast.append(prediksi)  # For generating subsequent predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
last_30_df = pd.DataFrame(numpy_grouped_df[-240:], columns=[grouped_df0.name],index=grouped_df0[-240:].index)

# %%
# Assume forecast contains the 30 predicted values
import pandas as pd

# Create a new datetime index for the next 30 days
new_dates = pd.date_range(start=last_30_df.index[-1] + pd.Timedelta(days=1), periods=days)

# Create a new DataFrame with the forecasted values
forecast_df = pd.DataFrame({'Modal Price (Rs./Quintal)': (scaler.inverse_transform(np.array(forecast).reshape(-1,1)).flatten())}, index=new_dates)

# Concatenate the existing DataFrame with the forecasted DataFrame
extended_df = pd.concat([last_30_df, forecast_df])

# Display the extended DataFrame
print(len(extended_df))
# Out:
# 480

# %%
import plotly.graph_objects as go
import pandas as pd

# Concatenate the actual and forecast DataFrames into a single DataFrame
combined_df = pd.concat([last_30_df, forecast_df])

# Create a figure
fig = go.Figure()


# Add a trace for the combined actual and forecast data (continuous line)
fig.add_trace(go.Scatter(
    x=extended_df.index,  # Use the combined index of both actual and forecast
    y=extended_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='Predicted Price',  # Label for combined data
    line=dict(color='red')  # Blue color for the forecasted data
))

# Add a trace for the last 30 actual values
fig.add_trace(go.Scatter(
    x=last_30_df.index,  # Only the index for the last 30 actual values
    y=last_30_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='True Price',  # Label for the last 30 actual data
    line=dict(color='blue')  # Green color for actual data
))


# Update layout for better aesthetics
fig.update_layout(
    title='Modal Price Over Time',
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6cd9a577-6325-49de-93f2-9b9752bc0150" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cd9a577-6325-49de-93f2-9b9752bc0150")) {                    Plotly.newPlot(                        "6cd9a577-6325-49de-93f2-9b9752bc0150",                        [{"line":{"color":"red"},"mode":"lines","name":"Predicted Price","x":["2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-24T00:00:00","2024-05-25T00:00:00","2024-05-26T00:00:00","2024-05-27T00:00:00","2024-05-28T00:00:00","2024-05-29T00:00:00","2024-05-30T00:00:00","2024-05-31T00:00:00","2024-06-01T00:00:00","2024-06-02T00:00:00","2024-06-03T00:00:00","2024-06-04T00:00:00","2024-06-05T00:00:00","2024-06-06T00:00:00","2024-06-07T00:00:00","2024-06-08T00:00:00","2024-06-09T00:00:00","2024-06-10T00:00:00","2024-06-11T00:00:00","2024-06-12T00:00:00","2024-06-13T00:00:00","2024-06-14T00:00:00","2024-06-15T00:00:00","2024-06-16T00:00:00","2024-06-17T00:00:00","2024-06-18T00:00:00","2024-06-19T00:00:00","2024-06-20T00:00:00","2024-06-21T00:00:00","2024-06-22T00:00:00","2024-06-23T00:00:00","2024-06-24T00:00:00","2024-06-25T00:00:00","2024-06-26T00:00:00","2024-06-27T00:00:00","2024-06-28T00:00:00","2024-06-29T00:00:00","2024-06-30T00:00:00","2024-07-01T00:00:00","2024-07-02T00:00:00","2024-07-03T00:00:00","2024-07-04T00:00:00","2024-07-05T00:00:00","2024-07-06T00:00:00","2024-07-07T00:00:00","2024-07-08T00:00:00","2024-07-09T00:00:00","2024-07-10T00:00:00","2024-07-11T00:00:00","2024-07-12T00:00:00","2024-07-13T00:00:00","2024-07-14T00:00:00","2024-07-15T00:00:00","2024-07-16T00:00:00","2024-07-17T00:00:00","2024-07-18T00:00:00","2024-07-19T00:00:00","2024-07-20T00:00:00","2024-07-21T00:00:00","2024-07-22T00:00:00","2024-07-23T00:00:00","2024-07-24T00:00:00","2024-07-25T00:00:00","2024-07-26T00:00:00","2024-07-27T00:00:00","2024-07-28T00:00:00","2024-07-29T00:00:00","2024-07-30T00:00:00","2024-07-31T00:00:00","2024-08-01T00:00:00","2024-08-02T00:00:00","2024-08-03T00:00:00","2024-08-04T00:00:00","2024-08-05T00:00:00"," ...

# %% [markdown]
# Plot ulang LSTM

# %%
# Initialize lists for forecast
days = 1*240
forecast = []
result_forecast = numpy_grouped_df_scaled[-1*240:].tolist()  # Use the last 30 values as the starting point

# Flatten result_forecast if it contains nested lists
# Assuming numpy_grouped_df_scaled[-30:] is a 2D array or list of lists
result_forecast = [item[0] if isinstance(item, list) else float(item) for item in result_forecast]

# Forecast for 365 days
for _ in range(days):
    # Prepare input for the model
    input_data = np.array(result_forecast[-1*240:]).reshape(1, 1*240, 1)  # Reshape correctly

    # Predict and extract the scalar value
    prediksi = model_LSTM.predict(input_data)[0][0]  # Extract scalar from prediction array

    # Append the prediction
    forecast.append(prediksi)  # For final forecast output
    result_forecast.append(prediksi)  # For generating subsequent predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
last_30_df = pd.DataFrame(numpy_grouped_df[-240:], columns=[grouped_df0.name],index=grouped_df0[-240:].index)

# %%
# Assume forecast contains the 30 predicted values
import pandas as pd

# Create a new datetime index for the next 30 days
new_dates = pd.date_range(start=last_30_df.index[-1] + pd.Timedelta(days=1), periods=days)

# Create a new DataFrame with the forecasted values
forecast_df = pd.DataFrame({'Modal Price (Rs./Quintal)': (scaler.inverse_transform(np.array(forecast).reshape(-1,1)).flatten())}, index=new_dates)

# Concatenate the existing DataFrame with the forecasted DataFrame
extended_df = pd.concat([last_30_df, forecast_df])

# Display the extended DataFrame
print(len(extended_df))
# Out:
# 480

# %%
import plotly.graph_objects as go
import pandas as pd

# Concatenate the actual and forecast DataFrames into a single DataFrame
combined_df = pd.concat([last_30_df, forecast_df])

# Create a figure
fig = go.Figure()


# Add a trace for the combined actual and forecast data (continuous line)
fig.add_trace(go.Scatter(
    x=extended_df.index,  # Use the combined index of both actual and forecast
    y=extended_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='Predicted Price',  # Label for combined data
    line=dict(color='red')  # Blue color for the forecasted data
))

# Add a trace for the last 30 actual values
fig.add_trace(go.Scatter(
    x=last_30_df.index,  # Only the index for the last 30 actual values
    y=last_30_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='True Price',  # Label for the last 30 actual data
    line=dict(color='blue')  # Green color for actual data
))


# Update layout for better aesthetics
fig.update_layout(
    title='Modal Price Over Time',
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4d37bc23-bcb8-414d-a0d3-351c8bba4bef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d37bc23-bcb8-414d-a0d3-351c8bba4bef")) {                    Plotly.newPlot(                        "4d37bc23-bcb8-414d-a0d3-351c8bba4bef",                        [{"line":{"color":"red"},"mode":"lines","name":"Predicted Price","x":["2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-24T00:00:00","2024-05-25T00:00:00","2024-05-26T00:00:00","2024-05-27T00:00:00","2024-05-28T00:00:00","2024-05-29T00:00:00","2024-05-30T00:00:00","2024-05-31T00:00:00","2024-06-01T00:00:00","2024-06-02T00:00:00","2024-06-03T00:00:00","2024-06-04T00:00:00","2024-06-05T00:00:00","2024-06-06T00:00:00","2024-06-07T00:00:00","2024-06-08T00:00:00","2024-06-09T00:00:00","2024-06-10T00:00:00","2024-06-11T00:00:00","2024-06-12T00:00:00","2024-06-13T00:00:00","2024-06-14T00:00:00","2024-06-15T00:00:00","2024-06-16T00:00:00","2024-06-17T00:00:00","2024-06-18T00:00:00","2024-06-19T00:00:00","2024-06-20T00:00:00","2024-06-21T00:00:00","2024-06-22T00:00:00","2024-06-23T00:00:00","2024-06-24T00:00:00","2024-06-25T00:00:00","2024-06-26T00:00:00","2024-06-27T00:00:00","2024-06-28T00:00:00","2024-06-29T00:00:00","2024-06-30T00:00:00","2024-07-01T00:00:00","2024-07-02T00:00:00","2024-07-03T00:00:00","2024-07-04T00:00:00","2024-07-05T00:00:00","2024-07-06T00:00:00","2024-07-07T00:00:00","2024-07-08T00:00:00","2024-07-09T00:00:00","2024-07-10T00:00:00","2024-07-11T00:00:00","2024-07-12T00:00:00","2024-07-13T00:00:00","2024-07-14T00:00:00","2024-07-15T00:00:00","2024-07-16T00:00:00","2024-07-17T00:00:00","2024-07-18T00:00:00","2024-07-19T00:00:00","2024-07-20T00:00:00","2024-07-21T00:00:00","2024-07-22T00:00:00","2024-07-23T00:00:00","2024-07-24T00:00:00","2024-07-25T00:00:00","2024-07-26T00:00:00","2024-07-27T00:00:00","2024-07-28T00:00:00","2024-07-29T00:00:00","2024-07-30T00:00:00","2024-07-31T00:00:00","2024-08-01T00:00:00","2024-08-02T00:00:00","2024-08-03T00:00:00","2024-08-04T00:00:00","2024-08-05T00:00:00"," ...

# %% [markdown]
# Save model

# %%
import joblib

# Assuming `scaler` is your StandardScaler object
joblib.dump(scaler, 'scaler_melonmusk.pkl')

#save model
model_RNN.save('best_melonmusk_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
grouped_df0.to_excel("melonmusk_avg_price.xlsx")
