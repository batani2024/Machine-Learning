# %% [markdown]
# Import modul and library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_excel("https://docs.google.com/spreadsheets/d/1-PL4qsgDiQSPlGMNPn0n-gzXsWvH7qZU/export?format=xlsx")

# %%
df.head(5)
# Out:
#    Unnamed: 0  Sl no. District Name           Market Name Commodity  \
# 0           0   16558      Bhatinda                  Maur     Mango
# 1           1    1021         Ajmer            Ajmer(F&V)     Mango
# 2           2    6497       Mehsana  Mehsana(Mehsana Veg)     Mango
# 3           3    4000       Barnala               Barnala     Mango
# 4           4   16650        Mumbai  Mumbai- Fruit Market     Mango
#
#           Variety   Grade  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0           Other  Medium                    13500                    15000
# 1           Other   Large                     4000                     6000
# 2           Other   Large                     2500                     3000
# 3           Other   Large                     9000                    12000
# 4  Hapus(Alphaso)     FAQ                    15000                    30000
#
#    Modal Price (Rs./Quintal) Price Date
# 0                    14000.0 2021-03-15
# 1                     5000.0 2021-03-15
# 2                     2750.0 2021-03-15
# 3                    10500.0 2021-03-15
# 4                    22500.0 2021-03-15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94472 entries, 0 to 94471
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 94472 non-null  int64
#  1   Sl no.                     94472 non-null  int64
#  2   District Name              94472 non-null  object
#  3   Market Name                94472 non-null  object
#  4   Commodity                  94472 non-null  object
#  5   Variety                    94472 non-null  object
#  6   Grade                      94472 non-null  object
#  7   Min Price (Rs./Quintal)    94472 non-null  int64
#  8   Max Price (Rs./Quintal)    94472 non-null  int64
#  9   Modal Price (Rs./Quintal)  94472 non-null  float64
#  10  Price Date                 94472 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 7.9+ MB

# %% [markdown]
# dari semua varietas, grade, kelompokkan menjadi satu dan hitung rata-ratanya

# %%
grouped_df0 = df.groupby('Price Date')['Modal Price (Rs./Quintal)'].mean()

# %%
grouped_df0
# Out:
# Price Date
# 2021-03-15    7207.000000
# 2021-03-16    6931.000000
# 2021-03-17    5874.687500
# 2021-03-18    6162.500000
# 2021-03-19    6056.323529
#                  ...
# 2024-10-27    8350.000000
# 2024-10-28    8360.714286
# 2024-10-29    8420.833333
# 2024-10-30    8163.636364
# 2024-10-31    5730.000000
# Name: Modal Price (Rs./Quintal), Length: 1324, dtype: float64

# %%
type(grouped_df0)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Download grouped_df untuk digunakan pada saat deployment

# %%
#grouped_df.to_excel('grouped_prices_banana.xlsx', sheet_name='Prices')

# %% [markdown]
# Tinjau grafik harga dari harga komoditas tersebut untuk melihat trend secara kasat mata

# %%
# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(grouped_df0.index, grouped_df0, label='Modal Price', color='blue')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Define the split time
split1 = 4*90
split2 = 8*90

# Get the train set
time_train = grouped_df0.index[:split1]
x_train = grouped_df0[:split1]

# Get the validation set
time_valid = grouped_df0.index[split1:split2]
x_valid = grouped_df0[split1:split2]

# Get the test set
time_test = grouped_df0.index[split2:]
x_test = grouped_df0[split2:]

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the data and transform it
x_train_scaled = scaler.fit_transform(x_train.values.reshape(-1,1))
x_val_scaled = scaler.transform(x_valid.values.reshape(-1,1))
x_test_scaled = scaler.transform(x_test.values.reshape(-1,1))

# Convert the scaled data back into a DataFrame for easier reading
x_train_scaled_df = pd.DataFrame(x_train_scaled, columns=[x_train.name],index=x_train.index)
x_val_scaled_df = pd.DataFrame(x_val_scaled,  columns=[x_valid.name],index=x_valid.index)
x_test_scaled_df = pd.DataFrame(x_test_scaled,  columns=[x_test.name],index=x_test.index)

# %%
# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(time_valid, x_valid, label='Modal Price', color='blue')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# #Naive Forecast

# %%
series = np.array(grouped_df0)

# %%
series = scaler.transform(series.reshape(-1,1))

# %%
# Generate the naive forecast
split_time = split2
naive_forecast = series[split_time-1 :-1]

# Define time step
time_step = 100

# Print values
print(f'ground truth at time step {time_step}: {x_test_scaled[time_step]}')
print(f'prediction at time step {time_step + 1}: {naive_forecast[time_step +1]}')
# Out:
# ground truth at time step 100: [-0.70708642]
# prediction at time step 101: [-0.70708642]

# %%
len(x_test_scaled)
# Out:
# 604

# %%
len(naive_forecast)
# Out:
# 604

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
#results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index, naive_forecast, label='Predicted Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index, x_test_scaled, label='True Value', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
print("MSE:", mse(x_test_scaled, naive_forecast).numpy())
print("MAE:", mae(x_test_scaled, naive_forecast).numpy())

naive_mse = mse(x_test_scaled, naive_forecast).numpy()
naive_mae = mae(x_test_scaled, naive_forecast).numpy()
# Out:
# MSE: 0.1194324
# MAE: 0.19759303

# %%
# Parameters
window_size = 30
batch_size = 32

# %%
def windowed_dataset(series, window_size, batch_size):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    #dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size)

    # Optimize the dataset for training
    dataset = dataset.cache().prefetch(1)

    return dataset

# %%
# Generate the dataset windows
x_train_windowed = windowed_dataset(x_train_scaled, window_size, batch_size)
x_val_windowed = windowed_dataset(x_val_scaled, window_size, batch_size)

# %%
# Print properties of a single batch
for windows in x_train_windowed.take(1):
  print(f'data type: {type(windows)}')
  print(f'number of elements in the tuple: {len(windows)}')
  print(f'shape of first element: {windows[0].shape}')
  print(f'shape of second element: {windows[1].shape}')
# Out:
# data type: <class 'tuple'>
# number of elements in the tuple: 2
# shape of first element: (32, 30, 1)
# shape of second element: (32, 1)

# %% [markdown]
# #RNN

# %%
# Build the Model
model_tune = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.SimpleRNN(40, return_sequences=True),
    tf.keras.layers.SimpleRNN(40),
    tf.keras.layers.Dense(1),
])

# Print the model summary
model_tune.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 30, 40)              │           1,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_1 (SimpleRNN)             │ (None, 40)                  │           3,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              41 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,961 (19.38 KB)
#  Trainable params: 4,961 (19.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model_tune.fit(x_train_windowed, validation_data=x_val_windowed, epochs=200, callbacks=[lr_schedule])
# Out:
# Epoch 1/200
#       7/Unknown 5s 18ms/step - loss: 0.0337
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0830 - val_loss: 0.1419 - learning_rate: 1.0000e-08
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0830 - val_loss: 0.1419 - learning_rate: 1.1220e-08
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0830 - val_loss: 0.1419 - learning_rate: 1.2589e-08
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0830 - val_loss: 0.1419 - learning_rate: 1.4125e-08
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0830 - val_loss: 0.1419 - learning_rate: 1.5849e-08
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0830 - val_loss: 0.1419 - learning_rate: 1.7783e-08
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0830 - val_loss: 0.1419 - learning_rate: 1.9953e-08
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0830 - val_loss: 0.1419 - learning_rate: 2.2387e-08
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0830 - val_loss: 0.1418 - learning_rate: 2.5119e-08
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0830 - val_loss: 0.1418 - learning_rate: 2.8184e-08
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0830 - val_loss: 0.1418 - learning_rate: 3.1623e-08
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0830 - val_loss: 0.1418 - learning_rate: 3.5481e-08
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0830 - val_loss: 0.1418 - learning_rate: 3.9811e-08
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0830 - val_loss: 0.1418 - learning_rate: 4.4668e-08
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0830 - val_loss: 0.1418 - learning_rate: 5.0119e-08
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0830 - val_loss: 0.1418 - learning_rate: 5.6234e-08
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0830 - val_loss: 0.1418 - learning_rate: 6.3096e-08
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0829 - val_loss: 0.1418 - learning_rate: 7.0795e-08
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0829 - val_loss: 0.1418 - learning_rate: 7.9433e-08
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0829 - val_loss: 0.1418 - learning_rate: 8.9125e-08
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0829 - val_loss: 0.1418 - learning_rate: 1.0000e-07
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0829 - val_loss: 0.1418 - learning_rate: 1.1220e-07
# Epoch 23/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0829 - val_loss: 0.1417 - learning_rate: 1.2589e-07
# Epoch 24/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0828 - val_loss: 0.1417 - learning_rate: 1.4125e-07
# Epoch 25/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0828 - val_loss: 0.1417 - learning_rate: 1.5849e-07
# Epoch 26/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0828 - val_loss: 0.1417 - learning_rate: 1.7783e-07
# Epoch 27/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0828 - val_loss: 0.1417 - learning_rate: 1.9953e-07
# Epoch 28/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0827 - val_loss: 0.1416 - learning_rate: 2.2387e-07
# Epoch 29/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0827 - val_loss: 0.1416 - learning_rate: 2.5119e-07
# Epoch 30/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0826 - val_loss: 0.1416 - learning_rate: 2.8184e-07
# Epoch 31/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0826 - val_loss: 0.1415 - learning_rate: 3.1623e-07
# Epoch 32/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0825 - val_loss: 0.1415 - learning_rate: 3.5481e-07
# Epoch 33/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0825 - val_loss: 0.1414 - learning_rate: 3.9811e-07
# Epoch 34/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0824 - val_loss: 0.1414 - learning_rate: 4.4668e-07
# Epoch 35/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0823 - val_loss: 0.1413 - learning_rate: 5.0119e-07
# Epoch 36/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0822 - val_loss: 0.1412 - learning_rate: 5.6234e-07
# Epoch 37/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0821 - val_loss: 0.1412 - learning_rate: 6.3096e-07
# Epoch 38/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0820 - val_loss: 0.1411 - learning_rate: 7.0795e-07
# Epoch 39/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0819 - val_loss: 0.1410 - learning_rate: 7.9433e-07
# Epoch 40/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0818 - val_loss: 0.1409 - learning_rate: 8.9125e-07
# Epoch 41/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0816 - val_loss: 0.1408 - learning_rate: 1.0000e-06
# Epoch 42/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0815 - val_loss: 0.1406 - learning_rate: 1.1220e-06
# Epoch 43/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0813 - val_loss: 0.1405 - learning_rate: 1.2589e-06
# Epoch 44/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0811 - val_loss: 0.1403 - learning_rate: 1.4125e-06
# Epoch 45/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0808 - val_loss: 0.1402 - learning_rate: 1.5849e-06
# Epoch 46/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0806 - val_loss: 0.1400 - learning_rate: 1.7783e-06
# Epoch 47/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0803 - val_loss: 0.1397 - learning_rate: 1.9953e-06
# Epoch 48/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0800 - val_loss: 0.1395 - learning_rate: 2.2387e-06
# Epoch 49/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0797 - val_loss: 0.1392 - learning_rate: 2.5119e-06
# Epoch 50/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0793 - val_loss: 0.1389 - learning_rate: 2.8184e-06
# Epoch 51/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0789 - val_loss: 0.1386 - learning_rate: 3.1623e-06
# Epoch 52/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0784 - val_loss: 0.1383 - learning_rate: 3.5481e-06
# Epoch 53/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0780 - val_loss: 0.1379 - learning_rate: 3.9811e-06
# Epoch 54/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0774 - val_loss: 0.1375 - learning_rate: 4.4668e-06
# Epoch 55/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0769 - val_loss: 0.1370 - learning_rate: 5.0119e-06
# Epoch 56/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0763 - val_loss: 0.1365 - learning_rate: 5.6234e-06
# Epoch 57/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0756 - val_loss: 0.1360 - learning_rate: 6.3096e-06
# Epoch 58/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0749 - val_loss: 0.1354 - learning_rate: 7.0795e-06
# Epoch 59/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0742 - val_loss: 0.1348 - learning_rate: 7.9433e-06
# Epoch 60/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0734 - val_loss: 0.1342 - learning_rate: 8.9125e-06
# Epoch 61/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0726 - val_loss: 0.1335 - learning_rate: 1.0000e-05
# Epoch 62/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0718 - val_loss: 0.1328 - learning_rate: 1.1220e-05
# Epoch 63/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0710 - val_loss: 0.1320 - learning_rate: 1.2589e-05
# Epoch 64/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0701 - val_loss: 0.1313 - learning_rate: 1.4125e-05
# Epoch 65/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0693 - val_loss: 0.1305 - learning_rate: 1.5849e-05
# Epoch 66/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0684 - val_loss: 0.1297 - learning_rate: 1.7783e-05
# Epoch 67/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0676 - val_loss: 0.1290 - learning_rate: 1.9953e-05
# Epoch 68/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0668 - val_loss: 0.1282 - learning_rate: 2.2387e-05
# Epoch 69/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0660 - val_loss: 0.1274 - learning_rate: 2.5119e-05
# Epoch 70/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0653 - val_loss: 0.1267 - learning_rate: 2.8184e-05
# Epoch 71/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0646 - val_loss: 0.1260 - learning_rate: 3.1623e-05
# Epoch 72/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0639 - val_loss: 0.1253 - learning_rate: 3.5481e-05
# Epoch 73/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0633 - val_loss: 0.1246 - learning_rate: 3.9811e-05
# Epoch 74/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0627 - val_loss: 0.1240 - learning_rate: 4.4668e-05
# Epoch 75/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0621 - val_loss: 0.1234 - learning_rate: 5.0119e-05
# Epoch 76/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0616 - val_loss: 0.1228 - learning_rate: 5.6234e-05
# Epoch 77/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0610 - val_loss: 0.1222 - learning_rate: 6.3096e-05
# Epoch 78/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0603 - val_loss: 0.1216 - learning_rate: 7.0795e-05
# Epoch 79/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0597 - val_loss: 0.1211 - learning_rate: 7.9433e-05
# Epoch 80/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0589 - val_loss: 0.1205 - learning_rate: 8.9125e-05
# Epoch 81/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0581 - val_loss: 0.1199 - learning_rate: 1.0000e-04
# Epoch 82/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0572 - val_loss: 0.1193 - learning_rate: 1.1220e-04
# Epoch 83/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0561 - val_loss: 0.1186 - learning_rate: 1.2589e-04
# Epoch 84/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0550 - val_loss: 0.1180 - learning_rate: 1.4125e-04
# Epoch 85/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0537 - val_loss: 0.1174 - learning_rate: 1.5849e-04
# Epoch 86/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0524 - val_loss: 0.1168 - learning_rate: 1.7783e-04
# Epoch 87/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0511 - val_loss: 0.1163 - learning_rate: 1.9953e-04
# Epoch 88/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0498 - val_loss: 0.1160 - learning_rate: 2.2387e-04
# Epoch 89/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0486 - val_loss: 0.1158 - learning_rate: 2.5119e-04
# Epoch 90/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0476 - val_loss: 0.1157 - learning_rate: 2.8184e-04
# Epoch 91/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0466 - val_loss: 0.1156 - learning_rate: 3.1623e-04
# Epoch 92/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0457 - val_loss: 0.1156 - learning_rate: 3.5481e-04
# Epoch 93/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0450 - val_loss: 0.1156 - learning_rate: 3.9811e-04
# Epoch 94/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0443 - val_loss: 0.1156 - learning_rate: 4.4668e-04
# Epoch 95/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0437 - val_loss: 0.1156 - learning_rate: 5.0119e-04
# Epoch 96/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0431 - val_loss: 0.1156 - learning_rate: 5.6234e-04
# Epoch 97/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0426 - val_loss: 0.1155 - learning_rate: 6.3096e-04
# Epoch 98/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0421 - val_loss: 0.1154 - learning_rate: 7.0795e-04
# Epoch 99/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0416 - val_loss: 0.1154 - learning_rate: 7.9433e-04
# Epoch 100/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0411 - val_loss: 0.1153 - learning_rate: 8.9125e-04
# Epoch 101/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0406 - val_loss: 0.1154 - learning_rate: 0.0010
# Epoch 102/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0401 - val_loss: 0.1156 - learning_rate: 0.0011
# Epoch 103/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0397 - val_loss: 0.1158 - learning_rate: 0.0013
# Epoch 104/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0392 - val_loss: 0.1163 - learning_rate: 0.0014
# Epoch 105/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0388 - val_loss: 0.1168 - learning_rate: 0.0016
# Epoch 106/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0383 - val_loss: 0.1174 - learning_rate: 0.0018
# Epoch 107/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0379 - val_loss: 0.1181 - learning_rate: 0.0020
# Epoch 108/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0375 - val_loss: 0.1189 - learning_rate: 0.0022
# Epoch 109/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0371 - val_loss: 0.1198 - learning_rate: 0.0025
# Epoch 110/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0367 - val_loss: 0.1210 - learning_rate: 0.0028
# Epoch 111/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0364 - val_loss: 0.1226 - learning_rate: 0.0032
# Epoch 112/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0362 - val_loss: 0.1252 - learning_rate: 0.0035
# Epoch 113/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0362 - val_loss: 0.1296 - learning_rate: 0.0040
# Epoch 114/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0368 - val_loss: 0.1372 - learning_rate: 0.0045
# Epoch 115/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0385 - val_loss: 0.1511 - learning_rate: 0.0050
# Epoch 116/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0435 - val_loss: 0.1715 - learning_rate: 0.0056
# Epoch 117/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0541 - val_loss: 0.2004 - learning_rate: 0.0063
# Epoch 118/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0852 - val_loss: 0.1547 - learning_rate: 0.0071
# Epoch 119/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0434 - val_loss: 0.1286 - learning_rate: 0.0079
# Epoch 120/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0332 - val_loss: 0.1490 - learning_rate: 0.0089
# Epoch 121/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0405 - val_loss: 0.1423 - learning_rate: 0.0100
# Epoch 122/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.1146 - val_loss: 0.1460 - learning_rate: 0.0112
# Epoch 123/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0955 - val_loss: 0.3344 - learning_rate: 0.0126
# Epoch 124/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3739 - val_loss: 0.1706 - learning_rate: 0.0141
# Epoch 125/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0685 - val_loss: 0.1378 - learning_rate: 0.0158
# Epoch 126/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0768 - val_loss: 0.2449 - learning_rate: 0.0178
# Epoch 127/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2337 - val_loss: 0.2245 - learning_rate: 0.0200
# Epoch 128/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5470 - val_loss: 0.6707 - learning_rate: 0.0224
# Epoch 129/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8374 - val_loss: 0.2801 - learning_rate: 0.0251
# Epoch 130/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3442 - val_loss: 0.3181 - learning_rate: 0.0282
# Epoch 131/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4733 - val_loss: 0.3988 - learning_rate: 0.0316
# Epoch 132/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6045 - val_loss: 0.5560 - learning_rate: 0.0355
# Epoch 133/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.7534 - val_loss: 0.8285 - learning_rate: 0.0398
# Epoch 134/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1514 - val_loss: 0.6312 - learning_rate: 0.0447
# Epoch 135/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2757 - val_loss: 2.3740 - learning_rate: 0.0501
# Epoch 136/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.8739 - val_loss: 0.8461 - learning_rate: 0.0562
# Epoch 137/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3084 - val_loss: 0.9023 - learning_rate: 0.0631
# Epoch 138/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9822 - val_loss: 2.5812 - learning_rate: 0.0708
# Epoch 139/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.9224 - val_loss: 4.7013 - learning_rate: 0.0794
# Epoch 140/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.0182 - val_loss: 2.3896 - learning_rate: 0.0891
# Epoch 141/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.0524 - val_loss: 2.6603 - learning_rate: 0.1000
# Epoch 142/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3510 - val_loss: 8.6253 - learning_rate: 0.1122
# Epoch 143/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.4735 - val_loss: 1.1814 - learning_rate: 0.1259
# Epoch 144/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8063 - val_loss: 5.1146 - learning_rate: 0.1413
# Epoch 145/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.4854 - val_loss: 7.7718 - learning_rate: 0.1585
# Epoch 146/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.4231 - val_loss: 1.4131 - learning_rate: 0.1778
# Epoch 147/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.8678 - val_loss: 13.0502 - learning_rate: 0.1995
# Epoch 148/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 12.6262 - val_loss: 5.1686 - learning_rate: 0.2239
# Epoch 149/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.7365 - val_loss: 9.2598 - learning_rate: 0.2512
# Epoch 150/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.1469 - val_loss: 3.2924 - learning_rate: 0.2818
# Epoch 151/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.5436 - val_loss: 16.9541 - learning_rate: 0.3162
# Epoch 152/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 13.7433 - val_loss: 4.2943 - learning_rate: 0.3548
# Epoch 153/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.2820 - val_loss: 9.5317 - learning_rate: 0.3981
# Epoch 154/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.5808 - val_loss: 3.4884 - learning_rate: 0.4467
# Epoch 155/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.4727 - val_loss: 25.7250 - learning_rate: 0.5012
# Epoch 156/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 29.8375 - val_loss: 16.6167 - learning_rate: 0.5623
# Epoch 157/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 22.6583 - val_loss: 37.6019 - learning_rate: 0.6310
# Epoch 158/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 39.4691 - val_loss: 41.1803 - learning_rate: 0.7079
# Epoch 159/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 43.3358 - val_loss: 1.8241 - learning_rate: 0.7943
# Epoch 160/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 49.5098 - val_loss: 42.7609 - learning_rate: 0.8913
# Epoch 161/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 23.5357 - val_loss: 1.6049 - learning_rate: 1.0000
# Epoch 162/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 23.0337 - val_loss: 84.7407 - learning_rate: 1.1220
# Epoch 163/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 89.5758 - val_loss: 18.6878 - learning_rate: 1.2589
# Epoch 164/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 79.4979 - val_loss: 101.6218 - learning_rate: 1.4125
# Epoch 165/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 94.8192 - val_loss: 49.0890 - learning_rate: 1.5849
# Epoch 166/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 53.0100 - val_loss: 190.7036 - learning_rate: 1.7783
# Epoch 167/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 143.1133 - val_loss: 72.5659 - learning_rate: 1.9953
# Epoch 168/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 69.2945 - val_loss: 56.0418 - learning_rate: 2.2387
# Epoch 169/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 96.4955 - val_loss: 203.8283 - learning_rate: 2.5119
# Epoch 170/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 227.2183 - val_loss: 400.1874 - learning_rate: 2.8184
# Epoch 171/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 301.9639 - val_loss: 368.1062 - learning_rate: 3.1623
# Epoch 172/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 262.7027 - val_loss: 102.2390 - learning_rate: 3.5481
# Epoch 173/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 146.8135 - val_loss: 42.7173 - learning_rate: 3.9811
# Epoch 174/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 120.5068 - val_loss: 565.9723 - learning_rate: 4.4668
# Epoch 175/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 349.9246 - val_loss: 162.4144 - learning_rate: 5.0119
# Epoch 176/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 175.0434 - val_loss: 551.4197 - learning_rate: 5.6234
# Epoch 177/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 439.0903 - val_loss: 301.7326 - learning_rate: 6.3096
# Epoch 178/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 246.2114 - val_loss: 542.9053 - learning_rate: 7.0795
# Epoch 179/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 478.5993 - val_loss: 426.8378 - learning_rate: 7.9433
# Epoch 180/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 248.2621 - val_loss: 474.5378 - learning_rate: 8.9125
# Epoch 181/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 421.1489 - val_loss: 59.1497 - learning_rate: 10.0000
# Epoch 182/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 250.7891 - val_loss: 195.9252 - learning_rate: 11.2202
# Epoch 183/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 370.3344 - val_loss: 416.0947 - learning_rate: 12.5893
# Epoch 184/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 513.6738 - val_loss: 175.0528 - learning_rate: 14.1254
# Epoch 185/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 373.4633 - val_loss: 387.0778 - learning_rate: 15.8489
# Epoch 186/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 579.7523 - val_loss: 2144.4768 - learning_rate: 17.7828
# Epoch 187/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1167.5751 - val_loss: 164.4018 - learning_rate: 19.9526
# Epoch 188/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1267.7657 - val_loss: 2039.4390 - learning_rate: 22.3872
# Epoch 189/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1299.4459 - val_loss: 520.2614 - learning_rate: 25.1189
# Epoch 190/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 579.3549 - val_loss: 2184.4446 - learning_rate: 28.1838
# Epoch 191/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1973.5560 - val_loss: 261.7936 - learning_rate: 31.6228
# Epoch 192/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 702.5346 - val_loss: 3006.9280 - learning_rate: 35.4813
# Epoch 193/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2493.2683 - val_loss: 1216.6724 - learning_rate: 39.8107
# Epoch 194/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1607.1825 - val_loss: 5106.2119 - learning_rate: 44.6684
# Epoch 195/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2656.7808 - val_loss: 495.0883 - learning_rate: 50.1187
# Epoch 196/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3119.8691 - val_loss: 9229.0762 - learning_rate: 56.2341
# Epoch 197/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7160.1943 - val_loss: 9519.2402 - learning_rate: 63.0957
# Epoch 198/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7076.2363 - val_loss: 6680.0991 - learning_rate: 70.7946
# Epoch 199/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6731.7393 - val_loss: 2671.5325 - learning_rate: 79.4328
# Epoch 200/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5285.9448 - val_loss: 4843.2056 - learning_rate: 89.1251

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(200) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the training loss in log scale
plt.semilogx(lrs, history.history["loss"], label="Training Loss")

# Plot the validation loss in log scale
plt.semilogx(lrs, history.history["val_loss"], label="Validation Loss")

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-1, 0, 1])

# Add a legend
plt.legend()

# Add labels and title
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Training and Validation Loss vs. Learning Rate")

# Show the plot
plt.show()

# %%
model_RNN=1

# %%
# Build the model
from tensorflow.keras.layers import Bidirectional, SimpleRNN, Dense
model_RNN = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size,1)),
    tf.keras.layers.SimpleRNN(50, return_sequences=True),
    tf.keras.layers.SimpleRNN(50),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1),
])

# Set the learning rate
learning_rate = 1e-3

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model_RNN.compile(loss=tf.keras.losses.Huber(),
                  optimizer=optimizer,
                  metrics=["mae"])

# EarlyStopping callback with patience
early_stopping = EarlyStopping(
    monitor="val_loss",     # Monitor validation loss
    patience=5,             # Wait 5 epochs for improvement
    mode="min",             # Stop when val_loss is minimized
    verbose=1               # Print when training stops early
)

# Train the model with EarlyStopping
history = model_RNN.fit(
    x_train_windowed,
    validation_data=x_val_windowed,
    epochs=100,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.1258 - mae: 0.4033 - val_loss: 0.1849 - val_mae: 0.5069
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1035 - mae: 0.3481 - val_loss: 0.1332 - val_mae: 0.3701
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0636 - mae: 0.2376 - val_loss: 0.1480 - val_mae: 0.4214
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0542 - mae: 0.1897 - val_loss: 0.1197 - val_mae: 0.3513
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0523 - mae: 0.2079 - val_loss: 0.1312 - val_mae: 0.3734
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0456 - mae: 0.1575 - val_loss: 0.1164 - val_mae: 0.3387
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0465 - mae: 0.1797 - val_loss: 0.1223 - val_mae: 0.3478
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0428 - mae: 0.1484 - val_loss: 0.1156 - val_mae: 0.3324
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0433 - mae: 0.1621 - val_loss: 0.1191 - val_mae: 0.3375
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0413 - mae: 0.1449 - val_loss: 0.1161 - val_mae: 0.3304
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0414 - mae: 0.1506 - val_loss: 0.1179 - val_mae: 0.3325
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0403 - mae: 0.1419 - val_loss: 0.1168 - val_mae: 0.3288
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0401 - mae: 0.1434 - val_loss: 0.1179 - val_mae: 0.3298
# Epoch 13: early stopping

# %%
# Initialize a list
forecast = []

# Use the model to predict data points per window size
for time in range(len(grouped_df0)-split2-window_size):
  forecast.append(model_RNN.predict(x_test_scaled[time:time + window_size][np.newaxis], verbose=0))

# Slice the points that are aligned with the validation set
#forecast = forecast[split_time - window_size:]

# Compare number of elements in the predictions and the validation set
print(f'length of the forecast list: {len(forecast)}')
print(f'shape of the validation set: {x_test.shape}')
# Out:
# length of the forecast list: 574
# shape of the validation set: (604,)

# %%
# Preview shapes after using the conversion and squeeze methods
print(f'shape after converting to numpy array: {np.array(forecast).shape}')
print(f'shape after squeezing: {np.array(forecast).squeeze().shape}')

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()
# Out:
# shape after converting to numpy array: (574, 1, 1)
# shape after squeezing: (574,)

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)), label='True Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(results_reshaped), label='Predicted', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
true_values = x_test_scaled_df.values[30:].reshape(-1, 1)
predicted_values = results_reshaped

print("MSE:", mse(true_values, predicted_values).numpy())
print("MAE:", mae(true_values, predicted_values).numpy())

rnn_mse = mse(true_values, predicted_values).numpy()
rnn_mae = mae(true_values, predicted_values).numpy()
# Out:
# MSE: 0.08131499
# MAE: 0.1845779

# %% [markdown]
# #LSTM

# %%
# Build the Model
model_tune1 = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
])

# Print the model summary
model_tune1.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)        │ (None, 30, 64)              │           8,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 30, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 64)                  │          24,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 33,601 (131.25 KB)
#  Trainable params: 33,601 (131.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune1.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model_tune1.fit(x_train_windowed, validation_data=x_val_windowed, epochs=200, callbacks=[lr_schedule])
# Out:
# Epoch 1/200
#      11/Unknown 6s 39ms/step - loss: 0.2428
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.2527 - val_loss: 0.2517 - learning_rate: 1.0000e-08
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.2519 - val_loss: 0.2517 - learning_rate: 1.1220e-08
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.2527 - val_loss: 0.2517 - learning_rate: 1.2589e-08
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.2530 - val_loss: 0.2517 - learning_rate: 1.4125e-08
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.2531 - val_loss: 0.2517 - learning_rate: 1.5849e-08
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2536 - val_loss: 0.2517 - learning_rate: 1.7783e-08
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2532 - val_loss: 0.2517 - learning_rate: 1.9953e-08
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2525 - val_loss: 0.2517 - learning_rate: 2.2387e-08
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2524 - val_loss: 0.2517 - learning_rate: 2.5119e-08
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.2526 - val_loss: 0.2517 - learning_rate: 2.8184e-08
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2523 - val_loss: 0.2517 - learning_rate: 3.1623e-08
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2522 - val_loss: 0.2517 - learning_rate: 3.5481e-08
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2531 - val_loss: 0.2517 - learning_rate: 3.9811e-08
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2524 - val_loss: 0.2517 - learning_rate: 4.4668e-08
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.2521 - val_loss: 0.2517 - learning_rate: 5.0119e-08
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2524 - val_loss: 0.2517 - learning_rate: 5.6234e-08
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2519 - val_loss: 0.2517 - learning_rate: 6.3096e-08
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2519 - val_loss: 0.2517 - learning_rate: 7.0795e-08
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.2513 - val_loss: 0.2517 - learning_rate: 7.9433e-08
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2536 - val_loss: 0.2517 - learning_rate: 8.9125e-08
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.2515 - val_loss: 0.2516 - learning_rate: 1.0000e-07
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - loss: 0.2522 - val_loss: 0.2516 - learning_rate: 1.1220e-07
# Epoch 23/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.2526 - val_loss: 0.2516 - learning_rate: 1.2589e-07
# Epoch 24/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2525 - val_loss: 0.2516 - learning_rate: 1.4125e-07
# Epoch 25/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2515 - val_loss: 0.2516 - learning_rate: 1.5849e-07
# Epoch 26/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2519 - val_loss: 0.2516 - learning_rate: 1.7783e-07
# Epoch 27/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2540 - val_loss: 0.2516 - learning_rate: 1.9953e-07
# Epoch 28/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2522 - val_loss: 0.2516 - learning_rate: 2.2387e-07
# Epoch 29/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2537 - val_loss: 0.2516 - learning_rate: 2.5119e-07
# Epoch 30/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2524 - val_loss: 0.2516 - learning_rate: 2.8184e-07
# Epoch 31/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2533 - val_loss: 0.2516 - learning_rate: 3.1623e-07
# Epoch 32/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2519 - val_loss: 0.2516 - learning_rate: 3.5481e-07
# Epoch 33/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2538 - val_loss: 0.2516 - learning_rate: 3.9811e-07
# Epoch 34/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2526 - val_loss: 0.2516 - learning_rate: 4.4668e-07
# Epoch 35/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2523 - val_loss: 0.2516 - learning_rate: 5.0119e-07
# Epoch 36/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2517 - val_loss: 0.2515 - learning_rate: 5.6234e-07
# Epoch 37/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2515 - val_loss: 0.2515 - learning_rate: 6.3096e-07
# Epoch 38/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2522 - val_loss: 0.2515 - learning_rate: 7.0795e-07
# Epoch 39/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.2513 - val_loss: 0.2515 - learning_rate: 7.9433e-07
# Epoch 40/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.2513 - val_loss: 0.2515 - learning_rate: 8.9125e-07
# Epoch 41/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.2518 - val_loss: 0.2514 - learning_rate: 1.0000e-06
# Epoch 42/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.2528 - val_loss: 0.2514 - learning_rate: 1.1220e-06
# Epoch 43/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.2517 - val_loss: 0.2514 - learning_rate: 1.2589e-06
# Epoch 44/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2526 - val_loss: 0.2513 - learning_rate: 1.4125e-06
# Epoch 45/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2519 - val_loss: 0.2513 - learning_rate: 1.5849e-06
# Epoch 46/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2516 - val_loss: 0.2513 - learning_rate: 1.7783e-06
# Epoch 47/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2501 - val_loss: 0.2512 - learning_rate: 1.9953e-06
# Epoch 48/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2507 - val_loss: 0.2512 - learning_rate: 2.2387e-06
# Epoch 49/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.2509 - val_loss: 0.2511 - learning_rate: 2.5119e-06
# Epoch 50/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2508 - val_loss: 0.2510 - learning_rate: 2.8184e-06
# Epoch 51/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2504 - val_loss: 0.2509 - learning_rate: 3.1623e-06
# Epoch 52/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2512 - val_loss: 0.2508 - learning_rate: 3.5481e-06
# Epoch 53/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2512 - val_loss: 0.2507 - learning_rate: 3.9811e-06
# Epoch 54/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2497 - val_loss: 0.2506 - learning_rate: 4.4668e-06
# Epoch 55/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2501 - val_loss: 0.2505 - learning_rate: 5.0119e-06
# Epoch 56/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2493 - val_loss: 0.2504 - learning_rate: 5.6234e-06
# Epoch 57/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2482 - val_loss: 0.2502 - learning_rate: 6.3096e-06
# Epoch 58/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2480 - val_loss: 0.2500 - learning_rate: 7.0795e-06
# Epoch 59/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.2485 - val_loss: 0.2498 - learning_rate: 7.9433e-06
# Epoch 60/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.2471 - val_loss: 0.2496 - learning_rate: 8.9125e-06
# Epoch 61/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.2474 - val_loss: 0.2494 - learning_rate: 1.0000e-05
# Epoch 62/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.2465 - val_loss: 0.2491 - learning_rate: 1.1220e-05
# Epoch 63/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2456 - val_loss: 0.2488 - learning_rate: 1.2589e-05
# Epoch 64/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2438 - val_loss: 0.2484 - learning_rate: 1.4125e-05
# Epoch 65/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2445 - val_loss: 0.2481 - learning_rate: 1.5849e-05
# Epoch 66/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.2417 - val_loss: 0.2476 - learning_rate: 1.7783e-05
# Epoch 67/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.2422 - val_loss: 0.2472 - learning_rate: 1.9953e-05
# Epoch 68/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2392 - val_loss: 0.2466 - learning_rate: 2.2387e-05
# Epoch 69/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2381 - val_loss: 0.2460 - learning_rate: 2.5119e-05
# Epoch 70/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2373 - val_loss: 0.2454 - learning_rate: 2.8184e-05
# Epoch 71/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2353 - val_loss: 0.2446 - learning_rate: 3.1623e-05
# Epoch 72/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.2317 - val_loss: 0.2438 - learning_rate: 3.5481e-05
# Epoch 73/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2300 - val_loss: 0.2429 - learning_rate: 3.9811e-05
# Epoch 74/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2291 - val_loss: 0.2419 - learning_rate: 4.4668e-05
# Epoch 75/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2263 - val_loss: 0.2408 - learning_rate: 5.0119e-05
# Epoch 76/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2235 - val_loss: 0.2396 - learning_rate: 5.6234e-05
# Epoch 77/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.2201 - val_loss: 0.2382 - learning_rate: 6.3096e-05
# Epoch 78/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.2162 - val_loss: 0.2367 - learning_rate: 7.0795e-05
# Epoch 79/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.2117 - val_loss: 0.2351 - learning_rate: 7.9433e-05
# Epoch 80/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.2085 - val_loss: 0.2333 - learning_rate: 8.9125e-05
# Epoch 81/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2043 - val_loss: 0.2313 - learning_rate: 1.0000e-04
# Epoch 82/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1988 - val_loss: 0.2291 - learning_rate: 1.1220e-04
# Epoch 83/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1936 - val_loss: 0.2268 - learning_rate: 1.2589e-04
# Epoch 84/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1882 - val_loss: 0.2242 - learning_rate: 1.4125e-04
# Epoch 85/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1833 - val_loss: 0.2214 - learning_rate: 1.5849e-04
# Epoch 86/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1772 - val_loss: 0.2183 - learning_rate: 1.7783e-04
# Epoch 87/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.1707 - val_loss: 0.2149 - learning_rate: 1.9953e-04
# Epoch 88/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1630 - val_loss: 0.2113 - learning_rate: 2.2387e-04
# Epoch 89/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1569 - val_loss: 0.2074 - learning_rate: 2.5119e-04
# Epoch 90/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1489 - val_loss: 0.2032 - learning_rate: 2.8184e-04
# Epoch 91/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1421 - val_loss: 0.1987 - learning_rate: 3.1623e-04
# Epoch 92/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1352 - val_loss: 0.1938 - learning_rate: 3.5481e-04
# Epoch 93/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.1280 - val_loss: 0.1886 - learning_rate: 3.9811e-04
# Epoch 94/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1208 - val_loss: 0.1831 - learning_rate: 4.4668e-04
# Epoch 95/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1145 - val_loss: 0.1773 - learning_rate: 5.0119e-04
# Epoch 96/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.1071 - val_loss: 0.1713 - learning_rate: 5.6234e-04
# Epoch 97/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.0995 - val_loss: 0.1651 - learning_rate: 6.3096e-04
# Epoch 98/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0939 - val_loss: 0.1588 - learning_rate: 7.0795e-04
# Epoch 99/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0886 - val_loss: 0.1526 - learning_rate: 7.9433e-04
# Epoch 100/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0830 - val_loss: 0.1467 - learning_rate: 8.9125e-04
# Epoch 101/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0780 - val_loss: 0.1413 - learning_rate: 0.0010
# Epoch 102/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0740 - val_loss: 0.1365 - learning_rate: 0.0011
# Epoch 103/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0708 - val_loss: 0.1326 - learning_rate: 0.0013
# Epoch 104/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0680 - val_loss: 0.1295 - learning_rate: 0.0014
# Epoch 105/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0648 - val_loss: 0.1272 - learning_rate: 0.0016
# Epoch 106/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0631 - val_loss: 0.1257 - learning_rate: 0.0018
# Epoch 107/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0607 - val_loss: 0.1247 - learning_rate: 0.0020
# Epoch 108/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0601 - val_loss: 0.1241 - learning_rate: 0.0022
# Epoch 109/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0585 - val_loss: 0.1236 - learning_rate: 0.0025
# Epoch 110/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0582 - val_loss: 0.1231 - learning_rate: 0.0028
# Epoch 111/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0563 - val_loss: 0.1226 - learning_rate: 0.0032
# Epoch 112/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0557 - val_loss: 0.1220 - learning_rate: 0.0035
# Epoch 113/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0553 - val_loss: 0.1215 - learning_rate: 0.0040
# Epoch 114/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0537 - val_loss: 0.1212 - learning_rate: 0.0045
# Epoch 115/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0529 - val_loss: 0.1208 - learning_rate: 0.0050
# Epoch 116/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.0522 - val_loss: 0.1205 - learning_rate: 0.0056
# Epoch 117/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0514 - val_loss: 0.1202 - learning_rate: 0.0063
# Epoch 118/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0506 - val_loss: 0.1196 - learning_rate: 0.0071
# Epoch 119/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0495 - val_loss: 0.1196 - learning_rate: 0.0079
# Epoch 120/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0487 - val_loss: 0.1197 - learning_rate: 0.0089
# Epoch 121/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0476 - val_loss: 0.1198 - learning_rate: 0.0100
# Epoch 122/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0469 - val_loss: 0.1200 - learning_rate: 0.0112
# Epoch 123/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0455 - val_loss: 0.1201 - learning_rate: 0.0126
# Epoch 124/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0450 - val_loss: 0.1202 - learning_rate: 0.0141
# Epoch 125/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0446 - val_loss: 0.1212 - learning_rate: 0.0158
# Epoch 126/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0436 - val_loss: 0.1216 - learning_rate: 0.0178
# Epoch 127/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0442 - val_loss: 0.1233 - learning_rate: 0.0200
# Epoch 128/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0431 - val_loss: 0.1233 - learning_rate: 0.0224
# Epoch 129/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0451 - val_loss: 0.1245 - learning_rate: 0.0251
# Epoch 130/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0465 - val_loss: 0.1436 - learning_rate: 0.0282
# Epoch 131/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0658 - val_loss: 0.1542 - learning_rate: 0.0316
# Epoch 132/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0811 - val_loss: 0.2044 - learning_rate: 0.0355
# Epoch 133/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.1875 - val_loss: 0.1676 - learning_rate: 0.0398
# Epoch 134/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0647 - val_loss: 0.1195 - learning_rate: 0.0447
# Epoch 135/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.0439 - val_loss: 0.1260 - learning_rate: 0.0501
# Epoch 136/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0572 - val_loss: 0.1371 - learning_rate: 0.0562
# Epoch 137/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0744 - val_loss: 0.1317 - learning_rate: 0.0631
# Epoch 138/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0517 - val_loss: 0.1406 - learning_rate: 0.0708
# Epoch 139/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0812 - val_loss: 0.1553 - learning_rate: 0.0794
# Epoch 140/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0734 - val_loss: 0.1733 - learning_rate: 0.0891
# Epoch 141/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1499 - val_loss: 0.2079 - learning_rate: 0.1000
# Epoch 142/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0867 - val_loss: 0.2482 - learning_rate: 0.1122
# Epoch 143/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.1336 - val_loss: 0.1935 - learning_rate: 0.1259
# Epoch 144/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0702 - val_loss: 0.2980 - learning_rate: 0.1413
# Epoch 145/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2096 - val_loss: 0.1531 - learning_rate: 0.1585
# Epoch 146/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1289 - val_loss: 0.2224 - learning_rate: 0.1778
# Epoch 147/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2176 - val_loss: 0.1677 - learning_rate: 0.1995
# Epoch 148/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1784 - val_loss: 0.4428 - learning_rate: 0.2239
# Epoch 149/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.4450 - val_loss: 0.1469 - learning_rate: 0.2512
# Epoch 150/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1587 - val_loss: 0.7794 - learning_rate: 0.2818
# Epoch 151/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.8593 - val_loss: 0.1980 - learning_rate: 0.3162
# Epoch 152/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.1531 - val_loss: 0.3372 - learning_rate: 0.3548
# Epoch 153/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.4166 - val_loss: 0.3419 - learning_rate: 0.3981
# Epoch 154/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.1305 - val_loss: 0.7055 - learning_rate: 0.4467
# Epoch 155/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.7420 - val_loss: 0.9724 - learning_rate: 0.5012
# Epoch 156/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.0161 - val_loss: 2.2745 - learning_rate: 0.5623
# Epoch 157/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.1157 - val_loss: 2.4910 - learning_rate: 0.6310
# Epoch 158/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 2.5617 - val_loss: 1.7797 - learning_rate: 0.7079
# Epoch 159/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.9395 - val_loss: 0.4836 - learning_rate: 0.7943
# Epoch 160/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.6465 - val_loss: 0.4144 - learning_rate: 0.8913
# Epoch 161/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.6281 - val_loss: 0.4303 - learning_rate: 1.0000
# Epoch 162/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.6447 - val_loss: 0.5168 - learning_rate: 1.1220
# Epoch 163/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.8282 - val_loss: 0.4319 - learning_rate: 1.2589
# Epoch 164/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.7021 - val_loss: 0.8397 - learning_rate: 1.4125
# Epoch 165/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 1.3540 - val_loss: 0.7112 - learning_rate: 1.5849
# Epoch 166/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.1112 - val_loss: 1.4768 - learning_rate: 1.7783
# Epoch 167/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.9520 - val_loss: 0.3358 - learning_rate: 1.9953
# Epoch 168/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.4232 - val_loss: 3.0727 - learning_rate: 2.2387
# Epoch 169/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 2.5686 - val_loss: 0.2644 - learning_rate: 2.5119
# Epoch 170/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.3822 - val_loss: 1.6099 - learning_rate: 2.8184
# Epoch 171/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.9780 - val_loss: 2.2112 - learning_rate: 3.1623
# Epoch 172/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.1847 - val_loss: 0.8590 - learning_rate: 3.5481
# Epoch 173/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.9722 - val_loss: 3.6313 - learning_rate: 3.9811
# Epoch 174/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 3.7915 - val_loss: 3.5135 - learning_rate: 4.4668
# Epoch 175/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.4852 - val_loss: 0.8997 - learning_rate: 5.0119
# Epoch 176/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 3.2720 - val_loss: 5.9271 - learning_rate: 5.6234
# Epoch 177/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 6.0707 - val_loss: 4.9643 - learning_rate: 6.3096
# Epoch 178/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.3482 - val_loss: 6.6439 - learning_rate: 7.0795
# Epoch 179/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 7.0322 - val_loss: 1.8684 - learning_rate: 7.9433
# Epoch 180/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3.6617 - val_loss: 2.4668 - learning_rate: 8.9125
# Epoch 181/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.2047 - val_loss: 15.9368 - learning_rate: 10.0000
# Epoch 182/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 17.2813 - val_loss: 11.2674 - learning_rate: 11.2202
# Epoch 183/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 10.9772 - val_loss: 7.2482 - learning_rate: 12.5893
# Epoch 184/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 6.8506 - val_loss: 16.6649 - learning_rate: 14.1254
# Epoch 185/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 13.1434 - val_loss: 5.3118 - learning_rate: 15.8489
# Epoch 186/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.2695 - val_loss: 8.8460 - learning_rate: 17.7828
# Epoch 187/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 12.1780 - val_loss: 15.8088 - learning_rate: 19.9526
# Epoch 188/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 17.9981 - val_loss: 13.1545 - learning_rate: 22.3872
# Epoch 189/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 19.5408 - val_loss: 38.6398 - learning_rate: 25.1189
# Epoch 190/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 32.8287 - val_loss: 22.9686 - learning_rate: 28.1838
# Epoch 191/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 26.4686 - val_loss: 0.2662 - learning_rate: 31.6228
# Epoch 192/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 12.5405 - val_loss: 33.3751 - learning_rate: 35.4813
# Epoch 193/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 39.0589 - val_loss: 94.1831 - learning_rate: 39.8107
# Epoch 194/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 95.7426 - val_loss: 0.4396 - learning_rate: 44.6684
# Epoch 195/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 12.6522 - val_loss: 16.3472 - learning_rate: 50.1187
# Epoch 196/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 36.2527 - val_loss: 18.5305 - learning_rate: 56.2341
# Epoch 197/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 34.8418 - val_loss: 52.0429 - learning_rate: 63.0957
# Epoch 198/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 31.1804 - val_loss: 96.1491 - learning_rate: 70.7946
# Epoch 199/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 86.8530 - val_loss: 70.9130 - learning_rate: 79.4328
# Epoch 200/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 79.6070 - val_loss: 112.6738 - learning_rate: 89.1251

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(200) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the training loss in log scale
plt.semilogx(lrs, history.history["loss"], label="Training Loss")

# Plot the validation loss in log scale
plt.semilogx(lrs, history.history["val_loss"], label="Validation Loss")

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-1, 0, 1])

# Add a legend
plt.legend()

# Add labels and title
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Training and Validation Loss vs. Learning Rate")

# Show the plot
plt.show()

# %% [raw]
# model_LSTM=1

# %%
# Reset states generated by Keras
#tf.keras.backend.clear_session()

# Build the model
model_LSTM = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size, 1)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(1),
])

# Set the learning rate
learning_rate = 1e-3

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model_LSTM.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# EarlyStopping callback with patience
early_stopping = EarlyStopping(
    monitor="val_loss",     # Monitor validation loss
    patience=5,             # Wait 5 epochs for improvement
    mode="min",             # Stop when val_loss is minimized
    verbose=1               # Print when training stops early
)

# Train the model with EarlyStopping
history = model_LSTM.fit(
    x_train_windowed,
    validation_data=x_val_windowed,
    epochs=100,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - loss: 0.2882 - mae: 0.6526 - val_loss: 0.2882 - val_mae: 0.5959
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.2020 - mae: 0.5257 - val_loss: 0.2451 - val_mae: 0.5260
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1393 - mae: 0.4166 - val_loss: 0.2034 - val_mae: 0.4587
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.1058 - mae: 0.3469 - val_loss: 0.1729 - val_mae: 0.4148
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0884 - mae: 0.3060 - val_loss: 0.1540 - val_mae: 0.3914
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0791 - mae: 0.2822 - val_loss: 0.1430 - val_mae: 0.3802
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0737 - mae: 0.2675 - val_loss: 0.1370 - val_mae: 0.3762
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0705 - mae: 0.2577 - val_loss: 0.1338 - val_mae: 0.3760
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0684 - mae: 0.2508 - val_loss: 0.1321 - val_mae: 0.3764
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0668 - mae: 0.2456 - val_loss: 0.1311 - val_mae: 0.3773
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0657 - mae: 0.2414 - val_loss: 0.1305 - val_mae: 0.3781
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0648 - mae: 0.2380 - val_loss: 0.1301 - val_mae: 0.3787
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0641 - mae: 0.2352 - val_loss: 0.1297 - val_mae: 0.3793
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0635 - mae: 0.2328 - val_loss: 0.1294 - val_mae: 0.3797
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.0630 - mae: 0.2309 - val_loss: 0.1292 - val_mae: 0.3799
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.0625 - mae: 0.2291 - val_loss: 0.1289 - val_mae: 0.3801
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0621 - mae: 0.2275 - val_loss: 0.1286 - val_mae: 0.3801
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0617 - mae: 0.2259 - val_loss: 0.1284 - val_mae: 0.3801
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0613 - mae: 0.2244 - val_loss: 0.1281 - val_mae: 0.3800
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0610 - mae: 0.2230 - val_loss: 0.1279 - val_mae: 0.3799
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0606 - mae: 0.2216 - val_loss: 0.1276 - val_mae: 0.3797
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0603 - mae: 0.2203 - val_loss: 0.1274 - val_mae: 0.3794
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0599 - mae: 0.2190 - val_loss: 0.1272 - val_mae: 0.3792
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0596 - mae: 0.2177 - val_loss: 0.1269 - val_mae: 0.3789
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0593 - mae: 0.2164 - val_loss: 0.1267 - val_mae: 0.3786
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0590 - mae: 0.2152 - val_loss: 0.1265 - val_mae: 0.3783
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0587 - mae: 0.2140 - val_loss: 0.1263 - val_mae: 0.3780
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0584 - mae: 0.2128 - val_loss: 0.1261 - val_mae: 0.3778
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0581 - mae: 0.2117 - val_loss: 0.1259 - val_mae: 0.3775
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0579 - mae: 0.2105 - val_loss: 0.1257 - val_mae: 0.3771
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0576 - mae: 0.2094 - val_loss: 0.1255 - val_mae: 0.3768
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0573 - mae: 0.2083 - val_loss: 0.1253 - val_mae: 0.3765
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0570 - mae: 0.2072 - val_loss: 0.1252 - val_mae: 0.3761
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.0568 - mae: 0.2061 - val_loss: 0.1250 - val_mae: 0.3758
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.0565 - mae: 0.2050 - val_loss: 0.1248 - val_mae: 0.3754
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.0563 - mae: 0.2039 - val_loss: 0.1247 - val_mae: 0.3751
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0560 - mae: 0.2028 - val_loss: 0.1245 - val_mae: 0.3747
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0558 - mae: 0.2018 - val_loss: 0.1243 - val_mae: 0.3743
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0555 - mae: 0.2008 - val_loss: 0.1242 - val_mae: 0.3739
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0553 - mae: 0.1998 - val_loss: 0.1240 - val_mae: 0.3735
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0550 - mae: 0.1988 - val_loss: 0.1239 - val_mae: 0.3731
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0548 - mae: 0.1978 - val_loss: 0.1238 - val_mae: 0.3727
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0546 - mae: 0.1968 - val_loss: 0.1236 - val_mae: 0.3723
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0543 - mae: 0.1959 - val_loss: 0.1235 - val_mae: 0.3719
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0541 - mae: 0.1949 - val_loss: 0.1234 - val_mae: 0.3714
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0539 - mae: 0.1939 - val_loss: 0.1232 - val_mae: 0.3710
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0536 - mae: 0.1929 - val_loss: 0.1231 - val_mae: 0.3706
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0534 - mae: 0.1920 - val_loss: 0.1230 - val_mae: 0.3702
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0532 - mae: 0.1910 - val_loss: 0.1229 - val_mae: 0.3698
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0530 - mae: 0.1901 - val_loss: 0.1228 - val_mae: 0.3694
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0528 - mae: 0.1891 - val_loss: 0.1227 - val_mae: 0.3690
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0526 - mae: 0.1882 - val_loss: 0.1226 - val_mae: 0.3685
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0523 - mae: 0.1873 - val_loss: 0.1225 - val_mae: 0.3681
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.0521 - mae: 0.1863 - val_loss: 0.1224 - val_mae: 0.3677
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0519 - mae: 0.1854 - val_loss: 0.1223 - val_mae: 0.3673
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.0517 - mae: 0.1845 - val_loss: 0.1222 - val_mae: 0.3669
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0515 - mae: 0.1836 - val_loss: 0.1222 - val_mae: 0.3666
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0513 - mae: 0.1828 - val_loss: 0.1221 - val_mae: 0.3662
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0511 - mae: 0.1819 - val_loss: 0.1220 - val_mae: 0.3658
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0510 - mae: 0.1811 - val_loss: 0.1219 - val_mae: 0.3654
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0508 - mae: 0.1802 - val_loss: 0.1219 - val_mae: 0.3651
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0506 - mae: 0.1794 - val_loss: 0.1218 - val_mae: 0.3647
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0504 - mae: 0.1786 - val_loss: 0.1218 - val_mae: 0.3643
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0502 - mae: 0.1778 - val_loss: 0.1217 - val_mae: 0.3639
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0500 - mae: 0.1770 - val_loss: 0.1217 - val_mae: 0.3636
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0498 - mae: 0.1762 - val_loss: 0.1216 - val_mae: 0.3632
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0497 - mae: 0.1755 - val_loss: 0.1216 - val_mae: 0.3628
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0495 - mae: 0.1747 - val_loss: 0.1216 - val_mae: 0.3625
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0493 - mae: 0.1740 - val_loss: 0.1215 - val_mae: 0.3621
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0492 - mae: 0.1733 - val_loss: 0.1215 - val_mae: 0.3618
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0490 - mae: 0.1726 - val_loss: 0.1215 - val_mae: 0.3614
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0488 - mae: 0.1719 - val_loss: 0.1215 - val_mae: 0.3611
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0487 - mae: 0.1712 - val_loss: 0.1214 - val_mae: 0.3607
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0485 - mae: 0.1705 - val_loss: 0.1214 - val_mae: 0.3604
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0484 - mae: 0.1698 - val_loss: 0.1214 - val_mae: 0.3600
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0482 - mae: 0.1691 - val_loss: 0.1214 - val_mae: 0.3597
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0481 - mae: 0.1684 - val_loss: 0.1214 - val_mae: 0.3595
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0479 - mae: 0.1678 - val_loss: 0.1214 - val_mae: 0.3592
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0478 - mae: 0.1671 - val_loss: 0.1214 - val_mae: 0.3589
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0476 - mae: 0.1665 - val_loss: 0.1214 - val_mae: 0.3586
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0475 - mae: 0.1658 - val_loss: 0.1214 - val_mae: 0.3583
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0474 - mae: 0.1652 - val_loss: 0.1214 - val_mae: 0.3580
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0472 - mae: 0.1646 - val_loss: 0.1214 - val_mae: 0.3578
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0471 - mae: 0.1640 - val_loss: 0.1214 - val_mae: 0.3575
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0470 - mae: 0.1634 - val_loss: 0.1214 - val_mae: 0.3572
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0468 - mae: 0.1629 - val_loss: 0.1214 - val_mae: 0.3569
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0467 - mae: 0.1623 - val_loss: 0.1214 - val_mae: 0.3566
# Epoch 87: early stopping

# %%
type(x_test_scaled)
# Out:
# numpy.ndarray

# %%
# Initialize a list
forecast = []

# Use the model to predict data points per window size
for time in range(len(grouped_df0)-split2-window_size):
  forecast.append(model_LSTM.predict(x_test_scaled[time:time + window_size][np.newaxis], verbose=0))

# Slice the points that are aligned with the validation set
#forecast = forecast[split_time - window_size:]

# Compare number of elements in the predictions and the validation set
print(f'length of the forecast list: {len(forecast)}')
print(f'shape of the validation set: {x_test.shape}')
# Out:
# length of the forecast list: 574
# shape of the validation set: (604,)

# %%
# Preview shapes after using the conversion and squeeze methods
print(f'shape after converting to numpy array: {np.array(forecast).shape}')
print(f'shape after squeezing: {np.array(forecast).squeeze().shape}')

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()
# Out:
# shape after converting to numpy array: (574, 1, 1)
# shape after squeezing: (574,)

# %%
# Reshape results to be 2D (as scaler.inverse_transform expects a 2D array)
results_reshaped = results.reshape(-1, 1)

# Plot the Modal Price against the Price Date
plt.figure(figsize=(20, 6))  # You can adjust the figure size
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)), label='True Value', color='blue')

# Plot the predicted values (after reshaping)
plt.plot(x_test_scaled_df.index[30:], scaler.inverse_transform(results_reshaped), label='Predicted', color='red')

# Add title and labels
plt.title('Modal Price Over Time', fontsize=16)
plt.xlabel('Price Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
import plotly.express as px
import pandas as pd

# Prepare a DataFrame for Plotly
plot_df = pd.DataFrame({
    'Price Date': x_test_scaled_df.index[30:],
    'True Value': scaler.inverse_transform(x_test_scaled_df.values[30:].reshape(-1, 1)).flatten(),
    'Predicted': scaler.inverse_transform(results.reshape(-1, 1)).flatten()
})

# Create an interactive plot
fig = px.line(
    plot_df,
    x='Price Date',
    y=['True Value', 'Predicted'],
    labels={'value': 'Modal Price (Rs./Quintal)', 'variable': 'Legend'},
    title='Modal Price Over Time'
)

# Update layout for better aesthetics
fig.update_layout(
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="48338ca1-0689-4ab4-8552-272762390639" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48338ca1-0689-4ab4-8552-272762390639")) {                    Plotly.newPlot(                        "48338ca1-0689-4ab4-8552-272762390639",                        [{"hovertemplate":"Legend=True Value\u003cbr\u003ePrice Date=%{x}\u003cbr\u003eModal Price (Rs.\u002fQuintal)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True Value","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"True Value","showlegend":true,"x":["2023-04-07T00:00:00","2023-04-08T00:00:00","2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-04-29T00:00:00","2023-04-30T00:00:00","2023-05-01T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-06T00:00:00","2023-05-07T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-13T00:00:00","2023-05-14T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-20T00:00:00","2023-05-21T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-27T00:00:00","2023-05-28T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-03T00:00:00","2023-06-04T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-10T00:00:00","2023-06-11T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-17T00:00:00","2023-06-18T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-24T00:00:00","2023-06-25T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-29T00:00:00","2023-06-30T00:00:00","2023-07-01T00:00:00","2023-07-02T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00","2023-08-18T00:00:00","2023-08-19T00:00:00","2023-08-20T00:00:00","2023-08-21T00:00:00","2023-08-22T00:00:00","2023-08-23T00:00:00","2023-08-24T00:00:00","2023-08-25T00:00:00","2023-08-26T00:00:00"," ...

# %%
# Instantiate metric objects
mse = tf.keras.metrics.MeanSquaredError()
mae = tf.keras.metrics.MeanAbsoluteError()

# Compute the metrics
true_values = x_test_scaled_df.values[30:].reshape(-1, 1)
predicted_values = results_reshaped

print("MSE:", mse(true_values, predicted_values).numpy())
print("MAE:", mae(true_values, predicted_values).numpy())

lstm_mse = mse(true_values, predicted_values).numpy()
lstm_mae = mae(true_values, predicted_values).numpy()
# Out:
# MSE: 0.08924665
# MAE: 0.20746076

# %%
model_name = ['rnn', 'lstm']
lst_mse = [rnn_mse, lstm_mse]
lst_mae = [rnn_mae, lstm_mae]

for i in range(len(model_name)):
    print(f'MSE dari {model_name[i]} adalah {lst_mse[i]}')
    print(f'MAE dari {model_name[i]} adalah {lst_mae[i]}')

smallest_mse = np.argmin(lst_mse)
smallest_mae = np.argmin(lst_mae)

print(f'Model terbaik adalah {model_name[smallest_mse]} berdasarkan MSE terkecil')
print(f'Model terbaik adalah {model_name[smallest_mae]} berdasarkan MAE terkecil')
# Out:
# MSE dari rnn adalah 0.08131498843431473
# MAE dari rnn adalah 0.18457789719104767
# MSE dari lstm adalah 0.08924665302038193
# MAE dari lstm adalah 0.20746076107025146
# Model terbaik adalah rnn berdasarkan MSE terkecil
# Model terbaik adalah rnn berdasarkan MAE terkecil

# %% [markdown]
# Forecast

# %%
numpy_grouped_df=grouped_df0.to_numpy()

# %%
numpy_grouped_df_scaled = scaler.transform(numpy_grouped_df.reshape(-1,1))

# %%
days = 240

# %%
len(numpy_grouped_df)/240
# Out:
# 5.516666666666667

# %% [markdown]
# Plot ulang RNN

# %%
# Initialize lists for forecast
days = 240
forecast = []
result_forecast = numpy_grouped_df_scaled[-240:].tolist()  # Use the last 30 values as the starting point

# Flatten result_forecast if it contains nested lists
# Assuming numpy_grouped_df_scaled[-30:] is a 2D array or list of lists
result_forecast = [item[0] if isinstance(item, list) else float(item) for item in result_forecast]

# Forecast for 365 days
for _ in range(days):
    # Prepare input for the model
    input_data = np.array(result_forecast[-240:]).reshape(1, 240, 1)  # Reshape correctly

    # Predict and extract the scalar value
    prediksi = model_RNN.predict(input_data)[0][0]  # Extract scalar from prediction array

    # Append the prediction
    forecast.append(prediksi)  # For final forecast output
    result_forecast.append(prediksi)  # For generating subsequent predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
last_30_df = pd.DataFrame(numpy_grouped_df[-240:], columns=[grouped_df0.name],index=grouped_df0[-240:].index)

# %%
# Assume forecast contains the 30 predicted values
import pandas as pd

# Create a new datetime index for the next 30 days
new_dates = pd.date_range(start=last_30_df.index[-1] + pd.Timedelta(days=1), periods=days)

# Create a new DataFrame with the forecasted values
forecast_df = pd.DataFrame({'Modal Price (Rs./Quintal)': (scaler.inverse_transform(np.array(forecast).reshape(-1,1)).flatten())}, index=new_dates)

# Concatenate the existing DataFrame with the forecasted DataFrame
extended_df = pd.concat([last_30_df, forecast_df])

# Display the extended DataFrame
print(len(extended_df))
# Out:
# 480

# %%
import plotly.graph_objects as go
import pandas as pd

# Concatenate the actual and forecast DataFrames into a single DataFrame
combined_df = pd.concat([last_30_df, forecast_df])

# Create a figure
fig = go.Figure()


# Add a trace for the combined actual and forecast data (continuous line)
fig.add_trace(go.Scatter(
    x=extended_df.index,  # Use the combined index of both actual and forecast
    y=extended_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='Predicted Price',  # Label for combined data
    line=dict(color='red')  # Blue color for the forecasted data
))

# Add a trace for the last 30 actual values
fig.add_trace(go.Scatter(
    x=last_30_df.index,  # Only the index for the last 30 actual values
    y=last_30_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='True Price',  # Label for the last 30 actual data
    line=dict(color='blue')  # Green color for actual data
))


# Update layout for better aesthetics
fig.update_layout(
    title='Modal Price Over Time',
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f49a65f6-5ffb-40d5-8f5b-d7ebb0f2227a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f49a65f6-5ffb-40d5-8f5b-d7ebb0f2227a")) {                    Plotly.newPlot(                        "f49a65f6-5ffb-40d5-8f5b-d7ebb0f2227a",                        [{"line":{"color":"red"},"mode":"lines","name":"Predicted Price","x":["2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-24T00:00:00","2024-05-25T00:00:00","2024-05-26T00:00:00","2024-05-27T00:00:00","2024-05-28T00:00:00","2024-05-29T00:00:00","2024-05-30T00:00:00","2024-05-31T00:00:00","2024-06-01T00:00:00","2024-06-02T00:00:00","2024-06-03T00:00:00","2024-06-04T00:00:00","2024-06-05T00:00:00","2024-06-06T00:00:00","2024-06-07T00:00:00","2024-06-08T00:00:00","2024-06-09T00:00:00","2024-06-10T00:00:00","2024-06-11T00:00:00","2024-06-12T00:00:00","2024-06-13T00:00:00","2024-06-14T00:00:00","2024-06-15T00:00:00","2024-06-16T00:00:00","2024-06-17T00:00:00","2024-06-18T00:00:00","2024-06-19T00:00:00","2024-06-20T00:00:00","2024-06-21T00:00:00","2024-06-22T00:00:00","2024-06-23T00:00:00","2024-06-24T00:00:00","2024-06-25T00:00:00","2024-06-26T00:00:00","2024-06-27T00:00:00","2024-06-28T00:00:00","2024-06-29T00:00:00","2024-06-30T00:00:00","2024-07-01T00:00:00","2024-07-02T00:00:00","2024-07-03T00:00:00","2024-07-04T00:00:00","2024-07-05T00:00:00","2024-07-06T00:00:00","2024-07-07T00:00:00","2024-07-08T00:00:00","2024-07-09T00:00:00","2024-07-10T00:00:00","2024-07-11T00:00:00","2024-07-12T00:00:00","2024-07-13T00:00:00","2024-07-14T00:00:00","2024-07-15T00:00:00","2024-07-16T00:00:00","2024-07-17T00:00:00","2024-07-18T00:00:00","2024-07-19T00:00:00","2024-07-20T00:00:00","2024-07-21T00:00:00","2024-07-22T00:00:00","2024-07-23T00:00:00","2024-07-24T00:00:00","2024-07-25T00:00:00","2024-07-26T00:00:00","2024-07-27T00:00:00","2024-07-28T00:00:00","2024-07-29T00:00:00","2024-07-30T00:00:00","2024-07-31T00:00:00","2024-08-01T00:00:00","2024-08-02T00:00:00","2024-08-03T00:00:00","2024-08-04T00:00:00","2024-08-05T00:00:00"," ...

# %% [markdown]
# Plot ulang LSTM

# %%
# Initialize lists for forecast
days = 1*240
forecast = []
result_forecast = numpy_grouped_df_scaled[-1*240:].tolist()  # Use the last 30 values as the starting point

# Flatten result_forecast if it contains nested lists
# Assuming numpy_grouped_df_scaled[-30:] is a 2D array or list of lists
result_forecast = [item[0] if isinstance(item, list) else float(item) for item in result_forecast]

# Forecast for 365 days
for _ in range(days):
    # Prepare input for the model
    input_data = np.array(result_forecast[-1*240:]).reshape(1, 1*240, 1)  # Reshape correctly

    # Predict and extract the scalar value
    prediksi = model_LSTM.predict(input_data)[0][0]  # Extract scalar from prediction array

    # Append the prediction
    forecast.append(prediksi)  # For final forecast output
    result_forecast.append(prediksi)  # For generating subsequent predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
last_30_df = pd.DataFrame(numpy_grouped_df[-240:], columns=[grouped_df0.name],index=grouped_df0[-240:].index)

# %%
# Assume forecast contains the 30 predicted values
import pandas as pd

# Create a new datetime index for the next 30 days
new_dates = pd.date_range(start=last_30_df.index[-1] + pd.Timedelta(days=1), periods=days)

# Create a new DataFrame with the forecasted values
forecast_df = pd.DataFrame({'Modal Price (Rs./Quintal)': (scaler.inverse_transform(np.array(forecast).reshape(-1,1)).flatten())}, index=new_dates)

# Concatenate the existing DataFrame with the forecasted DataFrame
extended_df = pd.concat([last_30_df, forecast_df])

# Display the extended DataFrame
print(len(extended_df))
# Out:
# 480

# %%
import plotly.graph_objects as go
import pandas as pd

# Concatenate the actual and forecast DataFrames into a single DataFrame
combined_df = pd.concat([last_30_df, forecast_df])

# Create a figure
fig = go.Figure()


# Add a trace for the combined actual and forecast data (continuous line)
fig.add_trace(go.Scatter(
    x=extended_df.index,  # Use the combined index of both actual and forecast
    y=extended_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='Predicted Price',  # Label for combined data
    line=dict(color='red')  # Blue color for the forecasted data
))

# Add a trace for the last 30 actual values
fig.add_trace(go.Scatter(
    x=last_30_df.index,  # Only the index for the last 30 actual values
    y=last_30_df['Modal Price (Rs./Quintal)'],
    mode='lines',  # Line plot
    name='True Price',  # Label for the last 30 actual data
    line=dict(color='blue')  # Green color for actual data
))


# Update layout for better aesthetics
fig.update_layout(
    title='Modal Price Over Time',
    title_font_size=16,
    xaxis_title='Price Date',
    yaxis_title='Modal Price (Rs./Quintal)',
    legend_title='Legend',
    xaxis=dict(tickangle=45),  # Rotate x-axis labels
    template='plotly_white'   # Clean white background
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4d37bc23-bcb8-414d-a0d3-351c8bba4bef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d37bc23-bcb8-414d-a0d3-351c8bba4bef")) {                    Plotly.newPlot(                        "4d37bc23-bcb8-414d-a0d3-351c8bba4bef",                        [{"line":{"color":"red"},"mode":"lines","name":"Predicted Price","x":["2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-24T00:00:00","2024-05-25T00:00:00","2024-05-26T00:00:00","2024-05-27T00:00:00","2024-05-28T00:00:00","2024-05-29T00:00:00","2024-05-30T00:00:00","2024-05-31T00:00:00","2024-06-01T00:00:00","2024-06-02T00:00:00","2024-06-03T00:00:00","2024-06-04T00:00:00","2024-06-05T00:00:00","2024-06-06T00:00:00","2024-06-07T00:00:00","2024-06-08T00:00:00","2024-06-09T00:00:00","2024-06-10T00:00:00","2024-06-11T00:00:00","2024-06-12T00:00:00","2024-06-13T00:00:00","2024-06-14T00:00:00","2024-06-15T00:00:00","2024-06-16T00:00:00","2024-06-17T00:00:00","2024-06-18T00:00:00","2024-06-19T00:00:00","2024-06-20T00:00:00","2024-06-21T00:00:00","2024-06-22T00:00:00","2024-06-23T00:00:00","2024-06-24T00:00:00","2024-06-25T00:00:00","2024-06-26T00:00:00","2024-06-27T00:00:00","2024-06-28T00:00:00","2024-06-29T00:00:00","2024-06-30T00:00:00","2024-07-01T00:00:00","2024-07-02T00:00:00","2024-07-03T00:00:00","2024-07-04T00:00:00","2024-07-05T00:00:00","2024-07-06T00:00:00","2024-07-07T00:00:00","2024-07-08T00:00:00","2024-07-09T00:00:00","2024-07-10T00:00:00","2024-07-11T00:00:00","2024-07-12T00:00:00","2024-07-13T00:00:00","2024-07-14T00:00:00","2024-07-15T00:00:00","2024-07-16T00:00:00","2024-07-17T00:00:00","2024-07-18T00:00:00","2024-07-19T00:00:00","2024-07-20T00:00:00","2024-07-21T00:00:00","2024-07-22T00:00:00","2024-07-23T00:00:00","2024-07-24T00:00:00","2024-07-25T00:00:00","2024-07-26T00:00:00","2024-07-27T00:00:00","2024-07-28T00:00:00","2024-07-29T00:00:00","2024-07-30T00:00:00","2024-07-31T00:00:00","2024-08-01T00:00:00","2024-08-02T00:00:00","2024-08-03T00:00:00","2024-08-04T00:00:00","2024-08-05T00:00:00"," ...

# %% [markdown]
# Save model

# %%
import joblib

# Assuming `scaler` is your StandardScaler object
joblib.dump(scaler, 'scaler_mango.pkl')

#save model
model_RNN.save('best_mango_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
grouped_df0.to_excel("mango_avg_price.xlsx")
